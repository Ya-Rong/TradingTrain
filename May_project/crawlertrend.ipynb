# %%
import requests
from bs4 import BeautifulSoup
from pymongo import MongoClient

# %%
# connect pymongo
client = MongoClient("mongodb://localhost:27017")
# client.list_database_names()
# connect Database
db = client["May"]
# connect collection
col = db["trend"]

# %%
# 設定要爬取的網址
url = 'https://flight.eztravel.com.tw/apiv2/lowPrice/list?sig=67989141e6a88d5a'

payload = {
    "head": {
        "clientID": "03168345038911101475",
        "transactionID": "9f9c4541659d13b6",
        "userAgent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/113.0.0.0 Safari/537.36"
    },
    "data": {
        "fromCity": "TPE",
        "toCity": "OSA",
        "direct": False,
        "passengers": [
            {
                "type": "Adult",
                "quantity": 1
            }
        ],
        "journeyType": "OneWay"
    }
}

# 發送 GET 請求並取得 HTML 網頁原始碼
response = requests.post(url=url, json=payload)
html = response.text

# 解析 HTML 網頁原始碼
soup = BeautifulSoup(response.text, 'html.parser')
print(soup.prettify())
# Out:
# {"head":{"code":0,"message":""},"data":[{"outboundDate":"2023-05-21","inboundDate":null,"price":6128,"noRoute":null},{"outboundDate":"2023-05-22","inboundDate":null,"price":6996,"noRoute":null},{"outboundDate":"2023-05-23","inboundDate":null,"price":5799,"noRoute":null},{"outboundDate":"2023-05-24","inboundDate":null,"price":5775,"noRoute":null},{"outboundDate":"2023-05-25","inboundDate":null,"price":6405,"noRoute":null},{"outboundDate":"2023-05-26","inboundDate":null,"price":5073,"noRoute":null},{"outboundDate":"2023-05-27","inboundDate":null,"price":6405,"noRoute":null},{"outboundDate":"2023-05-28","inboundDate":null,"price":5799,"noRoute":null},{"outboundDate":"2023-05-29","inboundDate":null,"price":5145,"noRoute":null},{"outboundDate":"2023-05-30","inboundDate":null,"price":4689,"noRoute":null},{"outboundDate":"2023-05-31","inboundDate":null,"price":4689,"noRoute":null},{"outboundDate":"2023-06-01","inboundDate":null,"price":5799,"noRoute":null},{"outboundDate":"2023-06-02","inboundDate":null,"price":6299,"noRoute":null},{"outboundDate":"2023-06-03","inboundDate":null,"price":6799,"noRoute":null},{"outboundDate":"2023-06-04","inboundDate":null,"price":5073,"noRoute":null},{"outboundDate":"2023-06-05","inboundDate":null,"price":6799,"noRoute":null},{"outboundDate":"2023-06-06","inboundDate":null,"price":5775,"noRoute":null},{"outboundDate":"2023-06-07","inboundDate":null,"price":6299,"noRoute":null},{"outboundDate":"2023-06-08","inboundDate":null,"price":5775,"noRoute":null},{"outboundDate":"2023-06-09","inboundDate":null,"price":6405,"noRoute":null},{"outboundDate":"2023-06-10","inboundDate":null,"price":7036,"noRoute":null},{"outboundDate":"2023-06-11","inboundDate":null,"price":6996,"noRoute":null},{"outboundDate":"2023-06-12","inboundDate":null,"price":6799,"noRoute":null},{"outboundDate":"2023-06-13","inboundDate":null,"price":6996,"noRoute":null},{"outboundDate":"2023-06-14","inboundDate":null,"price":8099,"noRoute":null},{"outboundDate":"2023-06-15","inboundDate":null,"price":7876,"noRoute":null},{"outboundDate":"2023-06-16","inboundDate":null,"price":8717,"noRoute":null},{"outboundDate":"2023-06-17","inboundDate":null,"price":8111,"noRoute":null},{"outboundDate":"2023-06-18","inboundDate":null,"price":6996,"noRoute":null},{"outboundDate":"2023-06-19","inboundDate":null,"price":8717,"noRoute":null},{"outboundDate":"2023-06-20","inboundDate":null,"price":6996,"noRoute":null},{"outboundDate":"2023-06-21","inboundDate":null,"price":9180,"noRoute":null},{"outboundDate":"2023-06-22","inboundDate":null,"price":9811,"noRoute":null},{"outboundDate":"2023-06-23","inboundDate":null,"price":8754,"noRoute":null},{"outboundDate":"2023-06-24","inboundDate":null,"price":8111,"noRoute":null},{"outboundDate":"2023-06-25","inboundDate":null,"price":8811,"noRoute":null},{"outboundDate":"2023-06-26","inboundDate":null,"price":8717,"noRoute":null},{"outboundDate":"2023-06-27","inboundDate":null,"price":7876,"noRoute":null},{"outboundDate":"2023-06-28","inboundDate":null,"price":8095,"noRoute":null},{"outboundDate":"2023-06-29","inboundDate":null,"price":4799,"noRoute":null},{"outboundDate":"2023-06-30","inboundDate":null,"price":8765,"noRoute":null},{"outboundDate":"2023-07-01","inboundDate":null,"price":9811,"noRoute":null},{"outboundDate":"2023-07-02","inboundDate":null,"price":7876,"noRoute":null},{"outboundDate":"2023-07-03","inboundDate":null,"price":7534,"noRoute":null},{"outboundDate":"2023-07-04","inboundDate":null,"price":7056,"noRoute":null},{"outboundDate":"2023-07-05","inboundDate":null,"price":7534,"noRoute":null},{"outboundDate":"2023-07-06","inboundDate":null,"price":4799,"noRoute":null},{"outboundDate":"2023-07-07","inboundDate":null,"price":7534,"noRoute":null},{"outboundDate":"2023-07-08","inboundDate":null,"price":7534,"noRoute":null},{"outboundDate":"2023-07-09","inboundDate":null,"price":7534,"noRoute":null},{"outboundDate":"2023-07-10","inboundDate":null,"price":7534,"noRoute":null},{"outboundDate":"2023-07-11","inb ...

# %%
# url = [
#     'https://flight.eztravel.com.tw/apiv2/flight/list?sig=fc55fef04c20ba7b',
#     'https://flight.eztravel.com.tw/apiv2/flight/list?sig=d8f3ce84e97ab2aa'
# ]

# payload = {
#     "head": {
#         "clientID": "2ee3a8f7-b64a-9ed7-0f41-4954eb57321f",
#         "transactionID": "5ff42a7824d683b9",
#         "userAgent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/112.0.0.0 Safari/537.36"
#     },
#     "data": {
#         "JourneyType": 2,
#         "CabinType": "any",
#         "AirlineCode": "",
#         "AdultCnt": 1,
#         "ChildCnt": 0,
#         "InfantCnt": 0,
#         "IsDirectFlight": False,
#         "OutBoundDate": "05/06/2023",
#         "InBoundDate": "11/06/2023",
#         "FromCityCode": "TPE",
#         "ToCityCode": "OSA",
#         "FromAirportCode": "",
#         "ToAirportCode": "",
#         "ResourceType": "eztravel"
#     }
# }


# def crawler(url):
#     response = requests.post(url=url, json=payload)
#     data = response.json()
#     return data


# for u in url:
#     data = crawler(u)
#     # 在這裡處理獲得的資料
#     # 可以使用data變數來操作資料，例如進行解析、提取需要的資訊等等
#     # print(data)
#     # print(u)

# # print(url)
# print(data)
# # # 發送 GET 請求並取得 HTML 網頁原始碼
# # response = requests.post(url=url, json=payload)
# # html = response.text
# # # 解析 HTML 網頁原始碼
# # soup = BeautifulSoup(response.text, 'html.parser')
# # print(soup.prettify())

# %%
import json
# 將解析結果轉換為JSON格式
json_data = json.loads(str(soup))
print(json_data)
# Out:
# {'head': {'code': 0, 'message': ''}, 'data': [{'outboundDate': '2023-05-21', 'inboundDate': None, 'price': 6128, 'noRoute': None}, {'outboundDate': '2023-05-22', 'inboundDate': None, 'price': 6996, 'noRoute': None}, {'outboundDate': '2023-05-23', 'inboundDate': None, 'price': 5799, 'noRoute': None}, {'outboundDate': '2023-05-24', 'inboundDate': None, 'price': 5775, 'noRoute': None}, {'outboundDate': '2023-05-25', 'inboundDate': None, 'price': 6405, 'noRoute': None}, {'outboundDate': '2023-05-26', 'inboundDate': None, 'price': 5073, 'noRoute': None}, {'outboundDate': '2023-05-27', 'inboundDate': None, 'price': 6405, 'noRoute': None}, {'outboundDate': '2023-05-28', 'inboundDate': None, 'price': 5799, 'noRoute': None}, {'outboundDate': '2023-05-29', 'inboundDate': None, 'price': 5145, 'noRoute': None}, {'outboundDate': '2023-05-30', 'inboundDate': None, 'price': 4689, 'noRoute': None}, {'outboundDate': '2023-05-31', 'inboundDate': None, 'price': 4689, 'noRoute': None}, {'outboundDate': '2023-06-01', 'inboundDate': None, 'price': 5799, 'noRoute': None}, {'outboundDate': '2023-06-02', 'inboundDate': None, 'price': 6299, 'noRoute': None}, {'outboundDate': '2023-06-03', 'inboundDate': None, 'price': 6799, 'noRoute': None}, {'outboundDate': '2023-06-04', 'inboundDate': None, 'price': 5073, 'noRoute': None}, {'outboundDate': '2023-06-05', 'inboundDate': None, 'price': 6799, 'noRoute': None}, {'outboundDate': '2023-06-06', 'inboundDate': None, 'price': 5775, 'noRoute': None}, {'outboundDate': '2023-06-07', 'inboundDate': None, 'price': 6299, 'noRoute': None}, {'outboundDate': '2023-06-08', 'inboundDate': None, 'price': 5775, 'noRoute': None}, {'outboundDate': '2023-06-09', 'inboundDate': None, 'price': 6405, 'noRoute': None}, {'outboundDate': '2023-06-10', 'inboundDate': None, 'price': 7036, 'noRoute': None}, {'outboundDate': '2023-06-11', 'inboundDate': None, 'price': 6996, 'noRoute': None}, {'outboundDate': '2023-06-12', 'inboundDate': None, 'price': 6799, 'noRoute': None}, {'outboundDate': '2023-06-13', 'inboundDate': None, 'price': 6996, 'noRoute': None}, {'outboundDate': '2023-06-14', 'inboundDate': None, 'price': 8099, 'noRoute': None}, {'outboundDate': '2023-06-15', 'inboundDate': None, 'price': 7876, 'noRoute': None}, {'outboundDate': '2023-06-16', 'inboundDate': None, 'price': 8717, 'noRoute': None}, {'outboundDate': '2023-06-17', 'inboundDate': None, 'price': 8111, 'noRoute': None}, {'outboundDate': '2023-06-18', 'inboundDate': None, 'price': 6996, 'noRoute': None}, {'outboundDate': '2023-06-19', 'inboundDate': None, 'price': 8717, 'noRoute': None}, {'outboundDate': '2023-06-20', 'inboundDate': None, 'price': 6996, 'noRoute': None}, {'outboundDate': '2023-06-21', 'inboundDate': None, 'price': 9180, 'noRoute': None}, {'outboundDate': '2023-06-22', 'inboundDate': None, 'price': 9811, 'noRoute': None}, {'outboundDate': '2023-06-23', 'inboundDate': None, 'price': 8754, 'noRoute': None}, {'outboundDate': '2023-06-24', 'inboundDate': None, 'price': 8111, 'noRoute': None}, {'outboundDate': '2023-06-25', 'inboundDate': None, 'price': 8811, 'noRoute': None}, {'outboundDate': '2023-06-26', 'inboundDate': None, 'price': 8717, 'noRoute': None}, {'outboundDate': '2023-06-27', 'inboundDate': None, 'price': 7876, 'noRoute': None}, {'outboundDate': '2023-06-28', 'inboundDate': None, 'price': 8095, 'noRoute': None}, {'outboundDate': '2023-06-29', 'inboundDate': None, 'price': 4799, 'noRoute': None}, {'outboundDate': '2023-06-30', 'inboundDate': None, 'price': 8765, 'noRoute': None}, {'outboundDate': '2023-07-01', 'inboundDate': None, 'price': 9811, 'noRoute': None}, {'outboundDate': '2023-07-02', 'inboundDate': None, 'price': 7876, 'noRoute': None}, {'outboundDate': '2023-07-03', 'inboundDate': None, 'price': 7534, 'noRoute': None}, {'outboundDate': '2023-07-04', 'inboundDate': None, 'price': 7056, 'noRoute': None}, {'outboundDate': '2023-07-05', 'inboundDate': None, 'price': 7534, 'noRoute': None}, {'outboundDate': '2023-07-06', 'inboundDate' ...

# %%
# json_data

# %%
print(json_data["data"])
# Out:
# [{'outboundDate': '2023-05-21', 'inboundDate': None, 'price': 6128, 'noRoute': None}, {'outboundDate': '2023-05-22', 'inboundDate': None, 'price': 6996, 'noRoute': None}, {'outboundDate': '2023-05-23', 'inboundDate': None, 'price': 5799, 'noRoute': None}, {'outboundDate': '2023-05-24', 'inboundDate': None, 'price': 5775, 'noRoute': None}, {'outboundDate': '2023-05-25', 'inboundDate': None, 'price': 6405, 'noRoute': None}, {'outboundDate': '2023-05-26', 'inboundDate': None, 'price': 5073, 'noRoute': None}, {'outboundDate': '2023-05-27', 'inboundDate': None, 'price': 6405, 'noRoute': None}, {'outboundDate': '2023-05-28', 'inboundDate': None, 'price': 5799, 'noRoute': None}, {'outboundDate': '2023-05-29', 'inboundDate': None, 'price': 5145, 'noRoute': None}, {'outboundDate': '2023-05-30', 'inboundDate': None, 'price': 4689, 'noRoute': None}, {'outboundDate': '2023-05-31', 'inboundDate': None, 'price': 4689, 'noRoute': None}, {'outboundDate': '2023-06-01', 'inboundDate': None, 'price': 5799, 'noRoute': None}, {'outboundDate': '2023-06-02', 'inboundDate': None, 'price': 6299, 'noRoute': None}, {'outboundDate': '2023-06-03', 'inboundDate': None, 'price': 6799, 'noRoute': None}, {'outboundDate': '2023-06-04', 'inboundDate': None, 'price': 5073, 'noRoute': None}, {'outboundDate': '2023-06-05', 'inboundDate': None, 'price': 6799, 'noRoute': None}, {'outboundDate': '2023-06-06', 'inboundDate': None, 'price': 5775, 'noRoute': None}, {'outboundDate': '2023-06-07', 'inboundDate': None, 'price': 6299, 'noRoute': None}, {'outboundDate': '2023-06-08', 'inboundDate': None, 'price': 5775, 'noRoute': None}, {'outboundDate': '2023-06-09', 'inboundDate': None, 'price': 6405, 'noRoute': None}, {'outboundDate': '2023-06-10', 'inboundDate': None, 'price': 7036, 'noRoute': None}, {'outboundDate': '2023-06-11', 'inboundDate': None, 'price': 6996, 'noRoute': None}, {'outboundDate': '2023-06-12', 'inboundDate': None, 'price': 6799, 'noRoute': None}, {'outboundDate': '2023-06-13', 'inboundDate': None, 'price': 6996, 'noRoute': None}, {'outboundDate': '2023-06-14', 'inboundDate': None, 'price': 8099, 'noRoute': None}, {'outboundDate': '2023-06-15', 'inboundDate': None, 'price': 7876, 'noRoute': None}, {'outboundDate': '2023-06-16', 'inboundDate': None, 'price': 8717, 'noRoute': None}, {'outboundDate': '2023-06-17', 'inboundDate': None, 'price': 8111, 'noRoute': None}, {'outboundDate': '2023-06-18', 'inboundDate': None, 'price': 6996, 'noRoute': None}, {'outboundDate': '2023-06-19', 'inboundDate': None, 'price': 8717, 'noRoute': None}, {'outboundDate': '2023-06-20', 'inboundDate': None, 'price': 6996, 'noRoute': None}, {'outboundDate': '2023-06-21', 'inboundDate': None, 'price': 9180, 'noRoute': None}, {'outboundDate': '2023-06-22', 'inboundDate': None, 'price': 9811, 'noRoute': None}, {'outboundDate': '2023-06-23', 'inboundDate': None, 'price': 8754, 'noRoute': None}, {'outboundDate': '2023-06-24', 'inboundDate': None, 'price': 8111, 'noRoute': None}, {'outboundDate': '2023-06-25', 'inboundDate': None, 'price': 8811, 'noRoute': None}, {'outboundDate': '2023-06-26', 'inboundDate': None, 'price': 8717, 'noRoute': None}, {'outboundDate': '2023-06-27', 'inboundDate': None, 'price': 7876, 'noRoute': None}, {'outboundDate': '2023-06-28', 'inboundDate': None, 'price': 8095, 'noRoute': None}, {'outboundDate': '2023-06-29', 'inboundDate': None, 'price': 4799, 'noRoute': None}, {'outboundDate': '2023-06-30', 'inboundDate': None, 'price': 8765, 'noRoute': None}, {'outboundDate': '2023-07-01', 'inboundDate': None, 'price': 9811, 'noRoute': None}, {'outboundDate': '2023-07-02', 'inboundDate': None, 'price': 7876, 'noRoute': None}, {'outboundDate': '2023-07-03', 'inboundDate': None, 'price': 7534, 'noRoute': None}, {'outboundDate': '2023-07-04', 'inboundDate': None, 'price': 7056, 'noRoute': None}, {'outboundDate': '2023-07-05', 'inboundDate': None, 'price': 7534, 'noRoute': None}, {'outboundDate': '2023-07-06', 'inboundDate': None, 'price': 4799, 'noRoute': None}, {'ou ...

# %%
json_data
# Out:
# {'head': {'code': 0, 'message': ''},
#  'data': [{'outboundDate': '2023-05-21',
#    'inboundDate': None,
#    'price': 6128,
#    'noRoute': None},
#   {'outboundDate': '2023-05-22',
#    'inboundDate': None,
#    'price': 6996,
#    'noRoute': None},
#   {'outboundDate': '2023-05-23',
#    'inboundDate': None,
#    'price': 5799,
#    'noRoute': None},
#   {'outboundDate': '2023-05-24',
#    'inboundDate': None,
#    'price': 5775,
#    'noRoute': None},
#   {'outboundDate': '2023-05-25',
#    'inboundDate': None,
#    'price': 6405,
#    'noRoute': None},
#   {'outboundDate': '2023-05-26',
#    'inboundDate': None,
#    'price': 5073,
#    'noRoute': None},
#   {'outboundDate': '2023-05-27',
#    'inboundDate': None,
#    'price': 6405,
#    'noRoute': None},
#   {'outboundDate': '2023-05-28',
#    'inboundDate': None,
#    'price': 5799,
#    'noRoute': None},
#   {'outboundDate': '2023-05-29',
#    'inboundDate': None,
#    'price': 5145,
#    'noRoute': None},
#   {'outboundDate': '2023-05-30',
#    'inboundDate': None,
#    'price': 4689,
#    'noRoute': None},
#   {'outboundDate': '2023-05-31',
#    'inboundDate': None,
#    'price': 4689,
#    'noRoute': None},
#   {'outboundDate': '2023-06-01',
#    'inboundDate': None,
#    'price': 5799,
#    'noRoute': None},
#   {'outboundDate': '2023-06-02',
#    'inboundDate': None,
#    'price': 6299,
#    'noRoute': None},
#   {'outboundDate': '2023-06-03',
#    'inboundDate': None,
#    'price': 6799,
#    'noRoute': None},
#   {'outboundDate': '2023-06-04',
#    'inboundDate': None,
#    'price': 5073,
#    'noRoute': None},
#   {'outboundDate': '2023-06-05',
#    'inboundDate': None,
#    'price': 6799,
#    'noRoute': None},
#   {'outboundDate': '2023-06-06',
#    'inboundDate': None,
#    'price': 5775,
#    'noRoute': None},
#   {'outboundDate': '2023-06-07',
#    'inboundDate': None,
#    'price': 6299,
#    'noRoute': None},
#   {'outboundDate': '2023-06-08',
#    'inboundDate': None,
#    'price': 5775,
#    'noRoute': None},
#   {'outboundDate': '2023-06-09',
#    'inboundDate': None,
#    'price': 6405,
#    'noRoute': None},
#   {'outboundDate': '2023-06-10',
#    'inboundDate': None,
#    'price': 7036,
#    'noRoute': None},
#   {'outboundDate': '2023-06-11',
#    'inboundDate': None,
#    'price': 6996,
#    'noRoute': None},
#   {'outboundDate': '2023-06-12',
#    'inboundDate': None,
#    'price': 6799,
#    'noRoute': None},
#   {'outboundDate': '2023-06-13',
#    'inboundDate': None,
#    'price': 6996,
#    'noRoute': None},
#   {'outboundDate': '2023-06-14',
#    'inboundDate': None,
#    'price': 8099,
#    'noRoute': None},
#   {'outboundDate': '2023-06-15',
#    'inboundDate': None,
#    'price': 7876,
#    'noRoute': None},
#   {'outboundDate': '2023-06-16',
#    'inboundDate': None,
#    'price': 8717,
#    'noRoute': None},
#   {'outboundDate': '2023-06-17',
#    'inboundDate': None,
#    'price': 8111,
#    'noRoute': None},
#   {'outboundDate': '2023-06-18',
#    'inboundDate': None,
#    'price': 6996,
#    'noRoute': None},
#   {'outboundDate': '2023-06-19',
#    'inboundDate': None,
#    'price': 8717,
#    'noRoute': None},
#   {'outboundDate': '2023-06-20',
#    'inboundDate': None,
#    'price': 6996,
#    'noRoute': None},
#   {'outboundDate': '2023-06-21',
#    'inboundDate': None,
#    'price': 9180,
#    'noRoute': None},
#   {'outboundDate': '2023-06-22',
#    'inboundDate': None,
#    'price': 9811,
#    'noRoute': None},
#   {'outboundDate': '2023-06-23',
#    'inboundDate': None,
#    'price': 8754,
#    'noRoute': None},
#   {'outboundDate': '2023-06-24',
#    'inboundDate': None,
#    'price': 8111,
#    'noRoute': None},
#   {'outboundDate': '2023-06-25',
#    'inboundDate': None,
#    'price': 8811,
#    'noRoute': None},
#   {'outboundDate': '2023-06-26',
#    'inboundDate': None,
#    'price': 8717,
#    'noRoute': None},
#   {'outboundDate': '2023-06-27',
#    'inboundDate': None,
#    'price': 7876,
#    'noRoute': None},
#   {'outboundDate': '2023-06-28',
#    'inboundDate': None,
#    'price': 8095,
#    'noRoute': None},
#   {'outboundDate': '2023-06-29',
#    'inboundDate': None,
#    'price': 4799,
#    'noRoute': None},
#   {'outboundDate': '2023-06-30',
#    'inboundDate': None,
#    'price': 8765,
#    'noRoute': None},
#   {'outboundDate': '2023-07-01',
#    'inboundDate': None,
#    'price': 9811,
#    'noRoute': None},
#   {'outboundDate': '2023-07-02',
#    'inboundDate': None,
#    'price': 7876,
#    'noRoute': None},
#   {'outboundDate': '2023-07-03',
#    'inboundDate': None,
#    'price': 7534,
#    'noRoute': None},
#   {'outboundDate': '2023-07-04',
#    'inboundDate': None,
#    'price': 7056,
#    'noRoute': None},
#   {'outboundDate': '2023-07-05',
#    'inboundDate': None,
#    'price': 7534,
#    'noRoute': None},
#   {'outboundDate': '2023-07-06',
#    'inboundDate': None,
#    'price': 4799,
#    'noRoute': None},
#   {'outboundDate': '2023-07-07',
#    'inboundDate': None,
#    'price': 7534,
#    'noRoute': None},
#   {'outboundDate': '2023-07-08',
#    'inboundDate': None,
#    'price': 7534,
#    'noRoute': None},
#   {'outboundDate': '2023-07-09',
#    'inboundDate': None,
#    'price': 7534,
#    'noRoute': None},
#   {'outboundDate': '2023-07-10',
#    'inboundDate': None,
#    'price': 7534,
#    'noRoute': None},
#   {'outboundDate': '2023-07-11',
#    'inboundDate': None,
#    'price': 4749,
#    'noRoute': None},
#   {'outboundDate': '2023-07-12',
#    'inboundDate': None,
#    'price': 6838,
#    'noRoute': None},
#   {'outboundDate': '2023-07-13',
#    'inboundDate': None,
#    'price': 6838,
#    'noRoute': None},
#   {'outboundDate': '2023-07-14',
#    'inboundDate': None,
#    'price': 6277,
#    'noRoute': None},
#   {'outboundDate': '2023-07-15',
#    'inboundDate': None,
#    'price': 6838,
#    'noRoute': None},
#   {'outboundDate': '2023-07-16',
#    'inboundDate': None,
#    'price': 8409,
#    'noRoute': None},
#   {'outboundDate': '2023-07-17',
#    'inboundDate': None,
#    'price': 7876,
#    'noRoute': None},
#   {'outboundDate': '2023-07-18',
#    'inboundDate': None,
#    'price': 6325,
#    'noRoute': None},
#   {'outboundDate': '2023-07-19',
#    'inboundDate': None,
#    'price': 7056,
#    'noRoute': None},
#   {'outboundDate': '2023-07-20',
#    'inboundDate': None,
#    'price': 6838,
#    'noRoute': None},
#   {'outboundDate': '2023-07-21',
#    'inboundDate': None,
#    'price': 7876,
#    'noRoute': None},
#   {'outboundDate': '2023-07-22',
#    'inboundDate': None,
#    'price': 9456,
#    'noRoute': None},
#   {'outboundDate': '2023-07-23',
#    'inboundDate': None,
#    'price': 7036,
#    'noRoute': None},
#   {'outboundDate': '2023-07-24',
#    'inboundDate': None,
#    'price': 7876,
#    'noRoute': None},
#   {'outboundDate': '2023-07-25',
#    'inboundDate': None,
#    'price': 8099,
#    'noRoute': None},
#   {'outboundDate': '2023-07-26',
#    'inboundDate': None,
#    'price': 7399,
#    'noRoute': None},
#   {'outboundDate': '2023-07-27',
#    'inboundDate': None,
#    'price': 7399,
#    'noRoute': None},
#   {'outboundDate': '2023-07-28',
#    'inboundDate': None,
#    'price': 5775,
#    'noRoute': None},
#   {'outboundDate': '2023-07-29',
#    'inboundDate': None,
#    'price': 8099,
#    'noRoute': None},
#   {'outboundDate': '2023-07-30',
#    'inboundDate': None,
#    'price': 7036,
#    'noRoute': None},
#   {'outboundDate': '2023-07-31',
#    'inboundDate': None,
#    'price': 6147,
#    'noRoute': None},
#   {'outboundDate': '2023-08-01',
#    'inboundDate': None,
#    'price': 7399,
#    'noRoute': None},
#   {'outboundDate': '2023-08-03',
#    'inboundDate': None,
#    'price': 6405,
#    'noRoute': None},
#   {'outboundDate': '2023-08-04',
#    'inboundDate': None,
#    'price': 5775,
#    'noRoute': None},
#   {'outboundDate': '2023-08-05',
#    'inboundDate': None,
#    'price': 7399,
#    'noRoute': None},
#   {'outboundDate': '2023-08-06',
#    'inboundDate': None,
#    'price': 6405,
#    'noRoute': None},
#   {'outboundDate': '2023-08-07',
#    'inboundDate': None,
#    'price': 7035,
#    'noRoute': None},
#   {'outboundDate': '2023-08-08',
#    'inboundDate': None,
#    'price': 5775,
#    'noRoute': None},
#   {'outboundDate': '2023-08-09',
#    'inboundDate': None,
#    'price': 5775,
#    'noRoute': None},
#   {'outboundDate': '2023-08-10',
#    'inboundDate': None,
#    'price': 5775,
#    'noRoute': None},
#   {'outboundDate': '2023-08-11',
#    'inboundDate': None,
#    'price': 6799,
#    'noRoute': None},
#   {'outboundDate': '2023-08-12',
#    'inboundDate': None,
#    'price': 7399,
#    'noRoute': None},
#   {'outboundDate': '2023-08-13',
#    'inboundDate': None,
#    'price': 7175,
#    'noRoute': None},
#   {'outboundDate': '2023-08-14',
#    'inboundDate': None,
#    'price': 6147,
#    'noRoute': None},
#   {'outboundDate': '2023-08-15',
#    'inboundDate': None,
#    'price': 6799,
#    'noRoute': None},
#   {'outboundDate': '2023-08-16',
#    'inboundDate': None,
#    'price': 7056,
#    'noRoute': None},
#   {'outboundDate': '2023-08-17',
#    'inboundDate': None,
#    'price': 7035,
#    'noRoute': None},
#   {'outboundDate': '2023-08-18',
#    'inboundDate': None,
#    'price': 7175,
#    'noRoute': None}]}

# %%
a = json_data
print(a.values())
# Out:
# dict_values([{'code': 0, 'message': ''}, [{'outboundDate': '2023-05-21', 'inboundDate': None, 'price': 6128, 'noRoute': None}, {'outboundDate': '2023-05-22', 'inboundDate': None, 'price': 6996, 'noRoute': None}, {'outboundDate': '2023-05-23', 'inboundDate': None, 'price': 5799, 'noRoute': None}, {'outboundDate': '2023-05-24', 'inboundDate': None, 'price': 5775, 'noRoute': None}, {'outboundDate': '2023-05-25', 'inboundDate': None, 'price': 6405, 'noRoute': None}, {'outboundDate': '2023-05-26', 'inboundDate': None, 'price': 5073, 'noRoute': None}, {'outboundDate': '2023-05-27', 'inboundDate': None, 'price': 6405, 'noRoute': None}, {'outboundDate': '2023-05-28', 'inboundDate': None, 'price': 5799, 'noRoute': None}, {'outboundDate': '2023-05-29', 'inboundDate': None, 'price': 5145, 'noRoute': None}, {'outboundDate': '2023-05-30', 'inboundDate': None, 'price': 4689, 'noRoute': None}, {'outboundDate': '2023-05-31', 'inboundDate': None, 'price': 4689, 'noRoute': None}, {'outboundDate': '2023-06-01', 'inboundDate': None, 'price': 5799, 'noRoute': None}, {'outboundDate': '2023-06-02', 'inboundDate': None, 'price': 6299, 'noRoute': None}, {'outboundDate': '2023-06-03', 'inboundDate': None, 'price': 6799, 'noRoute': None}, {'outboundDate': '2023-06-04', 'inboundDate': None, 'price': 5073, 'noRoute': None}, {'outboundDate': '2023-06-05', 'inboundDate': None, 'price': 6799, 'noRoute': None}, {'outboundDate': '2023-06-06', 'inboundDate': None, 'price': 5775, 'noRoute': None}, {'outboundDate': '2023-06-07', 'inboundDate': None, 'price': 6299, 'noRoute': None}, {'outboundDate': '2023-06-08', 'inboundDate': None, 'price': 5775, 'noRoute': None}, {'outboundDate': '2023-06-09', 'inboundDate': None, 'price': 6405, 'noRoute': None}, {'outboundDate': '2023-06-10', 'inboundDate': None, 'price': 7036, 'noRoute': None}, {'outboundDate': '2023-06-11', 'inboundDate': None, 'price': 6996, 'noRoute': None}, {'outboundDate': '2023-06-12', 'inboundDate': None, 'price': 6799, 'noRoute': None}, {'outboundDate': '2023-06-13', 'inboundDate': None, 'price': 6996, 'noRoute': None}, {'outboundDate': '2023-06-14', 'inboundDate': None, 'price': 8099, 'noRoute': None}, {'outboundDate': '2023-06-15', 'inboundDate': None, 'price': 7876, 'noRoute': None}, {'outboundDate': '2023-06-16', 'inboundDate': None, 'price': 8717, 'noRoute': None}, {'outboundDate': '2023-06-17', 'inboundDate': None, 'price': 8111, 'noRoute': None}, {'outboundDate': '2023-06-18', 'inboundDate': None, 'price': 6996, 'noRoute': None}, {'outboundDate': '2023-06-19', 'inboundDate': None, 'price': 8717, 'noRoute': None}, {'outboundDate': '2023-06-20', 'inboundDate': None, 'price': 6996, 'noRoute': None}, {'outboundDate': '2023-06-21', 'inboundDate': None, 'price': 9180, 'noRoute': None}, {'outboundDate': '2023-06-22', 'inboundDate': None, 'price': 9811, 'noRoute': None}, {'outboundDate': '2023-06-23', 'inboundDate': None, 'price': 8754, 'noRoute': None}, {'outboundDate': '2023-06-24', 'inboundDate': None, 'price': 8111, 'noRoute': None}, {'outboundDate': '2023-06-25', 'inboundDate': None, 'price': 8811, 'noRoute': None}, {'outboundDate': '2023-06-26', 'inboundDate': None, 'price': 8717, 'noRoute': None}, {'outboundDate': '2023-06-27', 'inboundDate': None, 'price': 7876, 'noRoute': None}, {'outboundDate': '2023-06-28', 'inboundDate': None, 'price': 8095, 'noRoute': None}, {'outboundDate': '2023-06-29', 'inboundDate': None, 'price': 4799, 'noRoute': None}, {'outboundDate': '2023-06-30', 'inboundDate': None, 'price': 8765, 'noRoute': None}, {'outboundDate': '2023-07-01', 'inboundDate': None, 'price': 9811, 'noRoute': None}, {'outboundDate': '2023-07-02', 'inboundDate': None, 'price': 7876, 'noRoute': None}, {'outboundDate': '2023-07-03', 'inboundDate': None, 'price': 7534, 'noRoute': None}, {'outboundDate': '2023-07-04', 'inboundDate': None, 'price': 7056, 'noRoute': None}, {'outboundDate': '2023-07-05', 'inboundDate': None, 'price': 7534, 'noRoute': None}, {'outboundDate': '2023-07-06', 'inboundDate': No ...

# %%
b = a.values()
b
# Out:
# dict_values([{'code': 0, 'message': ''}, [{'outboundDate': '2023-05-21', 'inboundDate': None, 'price': 6128, 'noRoute': None}, {'outboundDate': '2023-05-22', 'inboundDate': None, 'price': 6996, 'noRoute': None}, {'outboundDate': '2023-05-23', 'inboundDate': None, 'price': 5799, 'noRoute': None}, {'outboundDate': '2023-05-24', 'inboundDate': None, 'price': 5775, 'noRoute': None}, {'outboundDate': '2023-05-25', 'inboundDate': None, 'price': 6405, 'noRoute': None}, {'outboundDate': '2023-05-26', 'inboundDate': None, 'price': 5073, 'noRoute': None}, {'outboundDate': '2023-05-27', 'inboundDate': None, 'price': 6405, 'noRoute': None}, {'outboundDate': '2023-05-28', 'inboundDate': None, 'price': 5799, 'noRoute': None}, {'outboundDate': '2023-05-29', 'inboundDate': None, 'price': 5145, 'noRoute': None}, {'outboundDate': '2023-05-30', 'inboundDate': None, 'price': 4689, 'noRoute': None}, {'outboundDate': '2023-05-31', 'inboundDate': None, 'price': 4689, 'noRoute': None}, {'outboundDate': '2023-06-01', 'inboundDate': None, 'price': 5799, 'noRoute': None}, {'outboundDate': '2023-06-02', 'inboundDate': None, 'price': 6299, 'noRoute': None}, {'outboundDate': '2023-06-03', 'inboundDate': None, 'price': 6799, 'noRoute': None}, {'outboundDate': '2023-06-04', 'inboundDate': None, 'price': 5073, 'noRoute': None}, {'outboundDate': '2023-06-05', 'inboundDate': None, 'price': 6799, 'noRoute': None}, {'outboundDate': '2023-06-06', 'inboundDate': None, 'price': 5775, 'noRoute': None}, {'outboundDate': '2023-06-07', 'inboundDate': None, 'price': 6299, 'noRoute': None}, {'outboundDate': '2023-06-08', 'inboundDate': None, 'price': 5775, 'noRoute': None}, {'outboundDate': '2023-06-09', 'inboundDate': None, 'price': 6405, 'noRoute': None}, {'outboundDate': '2023-06-10', 'inboundDate': None, 'price': 7036, 'noRoute': None}, {'outboundDate': '2023-06-11', 'inboundDate': None, 'price': 6996, 'noRoute': None}, {'outboundDate': '2023-06-12', 'inboundDate': None, 'price': 6799, 'noRoute': None}, {'outboundDate': '2023-06-13', 'inboundDate': None, 'price': 6996, 'noRoute': None}, {'outboundDate': '2023-06-14', 'inboundDate': None, 'price': 8099, 'noRoute': None}, {'outboundDate': '2023-06-15', 'inboundDate': None, 'price': 7876, 'noRoute': None}, {'outboundDate': '2023-06-16', 'inboundDate': None, 'price': 8717, 'noRoute': None}, {'outboundDate': '2023-06-17', 'inboundDate': None, 'price': 8111, 'noRoute': None}, {'outboundDate': '2023-06-18', 'inboundDate': None, 'price': 6996, 'noRoute': None}, {'outboundDate': '2023-06-19', 'inboundDate': None, 'price': 8717, 'noRoute': None}, {'outboundDate': '2023-06-20', 'inboundDate': None, 'price': 6996, 'noRoute': None}, {'outboundDate': '2023-06-21', 'inboundDate': None, 'price': 9180, 'noRoute': None}, {'outboundDate': '2023-06-22', 'inboundDate': None, 'price': 9811, 'noRoute': None}, {'outboundDate': '2023-06-23', 'inboundDate': None, 'price': 8754, 'noRoute': None}, {'outboundDate': '2023-06-24', 'inboundDate': None, 'price': 8111, 'noRoute': None}, {'outboundDate': '2023-06-25', 'inboundDate': None, 'price': 8811, 'noRoute': None}, {'outboundDate': '2023-06-26', 'inboundDate': None, 'price': 8717, 'noRoute': None}, {'outboundDate': '2023-06-27', 'inboundDate': None, 'price': 7876, 'noRoute': None}, {'outboundDate': '2023-06-28', 'inboundDate': None, 'price': 8095, 'noRoute': None}, {'outboundDate': '2023-06-29', 'inboundDate': None, 'price': 4799, 'noRoute': None}, {'outboundDate': '2023-06-30', 'inboundDate': None, 'price': 8765, 'noRoute': None}, {'outboundDate': '2023-07-01', 'inboundDate': None, 'price': 9811, 'noRoute': None}, {'outboundDate': '2023-07-02', 'inboundDate': None, 'price': 7876, 'noRoute': None}, {'outboundDate': '2023-07-03', 'inboundDate': None, 'price': 7534, 'noRoute': None}, {'outboundDate': '2023-07-04', 'inboundDate': None, 'price': 7056, 'noRoute': None}, {'outboundDate': '2023-07-05', 'inboundDate': None, 'price': 7534, 'noRoute': None}, {'outboundDate': '2023-07-06', 'inboundDate': No ...

# %%
def flatten_list(_2d_list):
    flat_list = []
    # Iterate through the outer list
    for element in _2d_list:
        if type(element) is list:
            # If the element is of type list, iterate through the sublist
            for item in element:
                flat_list.append(item)
        else:
            flat_list.append(element)
    return flat_list

# %%
new_datas = flatten_list(b)
# new_datas

# %%
# print(len(new_datas))

# %%
new_datas
# Out:
# [{'code': 0, 'message': ''},
#  {'outboundDate': '2023-05-21',
#   'inboundDate': None,
#   'price': 6128,
#   'noRoute': None},
#  {'outboundDate': '2023-05-22',
#   'inboundDate': None,
#   'price': 6996,
#   'noRoute': None},
#  {'outboundDate': '2023-05-23',
#   'inboundDate': None,
#   'price': 5799,
#   'noRoute': None},
#  {'outboundDate': '2023-05-24',
#   'inboundDate': None,
#   'price': 5775,
#   'noRoute': None},
#  {'outboundDate': '2023-05-25',
#   'inboundDate': None,
#   'price': 6405,
#   'noRoute': None},
#  {'outboundDate': '2023-05-26',
#   'inboundDate': None,
#   'price': 5073,
#   'noRoute': None},
#  {'outboundDate': '2023-05-27',
#   'inboundDate': None,
#   'price': 6405,
#   'noRoute': None},
#  {'outboundDate': '2023-05-28',
#   'inboundDate': None,
#   'price': 5799,
#   'noRoute': None},
#  {'outboundDate': '2023-05-29',
#   'inboundDate': None,
#   'price': 5145,
#   'noRoute': None},
#  {'outboundDate': '2023-05-30',
#   'inboundDate': None,
#   'price': 4689,
#   'noRoute': None},
#  {'outboundDate': '2023-05-31',
#   'inboundDate': None,
#   'price': 4689,
#   'noRoute': None},
#  {'outboundDate': '2023-06-01',
#   'inboundDate': None,
#   'price': 5799,
#   'noRoute': None},
#  {'outboundDate': '2023-06-02',
#   'inboundDate': None,
#   'price': 6299,
#   'noRoute': None},
#  {'outboundDate': '2023-06-03',
#   'inboundDate': None,
#   'price': 6799,
#   'noRoute': None},
#  {'outboundDate': '2023-06-04',
#   'inboundDate': None,
#   'price': 5073,
#   'noRoute': None},
#  {'outboundDate': '2023-06-05',
#   'inboundDate': None,
#   'price': 6799,
#   'noRoute': None},
#  {'outboundDate': '2023-06-06',
#   'inboundDate': None,
#   'price': 5775,
#   'noRoute': None},
#  {'outboundDate': '2023-06-07',
#   'inboundDate': None,
#   'price': 6299,
#   'noRoute': None},
#  {'outboundDate': '2023-06-08',
#   'inboundDate': None,
#   'price': 5775,
#   'noRoute': None},
#  {'outboundDate': '2023-06-09',
#   'inboundDate': None,
#   'price': 6405,
#   'noRoute': None},
#  {'outboundDate': '2023-06-10',
#   'inboundDate': None,
#   'price': 7036,
#   'noRoute': None},
#  {'outboundDate': '2023-06-11',
#   'inboundDate': None,
#   'price': 6996,
#   'noRoute': None},
#  {'outboundDate': '2023-06-12',
#   'inboundDate': None,
#   'price': 6799,
#   'noRoute': None},
#  {'outboundDate': '2023-06-13',
#   'inboundDate': None,
#   'price': 6996,
#   'noRoute': None},
#  {'outboundDate': '2023-06-14',
#   'inboundDate': None,
#   'price': 8099,
#   'noRoute': None},
#  {'outboundDate': '2023-06-15',
#   'inboundDate': None,
#   'price': 7876,
#   'noRoute': None},
#  {'outboundDate': '2023-06-16',
#   'inboundDate': None,
#   'price': 8717,
#   'noRoute': None},
#  {'outboundDate': '2023-06-17',
#   'inboundDate': None,
#   'price': 8111,
#   'noRoute': None},
#  {'outboundDate': '2023-06-18',
#   'inboundDate': None,
#   'price': 6996,
#   'noRoute': None},
#  {'outboundDate': '2023-06-19',
#   'inboundDate': None,
#   'price': 8717,
#   'noRoute': None},
#  {'outboundDate': '2023-06-20',
#   'inboundDate': None,
#   'price': 6996,
#   'noRoute': None},
#  {'outboundDate': '2023-06-21',
#   'inboundDate': None,
#   'price': 9180,
#   'noRoute': None},
#  {'outboundDate': '2023-06-22',
#   'inboundDate': None,
#   'price': 9811,
#   'noRoute': None},
#  {'outboundDate': '2023-06-23',
#   'inboundDate': None,
#   'price': 8754,
#   'noRoute': None},
#  {'outboundDate': '2023-06-24',
#   'inboundDate': None,
#   'price': 8111,
#   'noRoute': None},
#  {'outboundDate': '2023-06-25',
#   'inboundDate': None,
#   'price': 8811,
#   'noRoute': None},
#  {'outboundDate': '2023-06-26',
#   'inboundDate': None,
#   'price': 8717,
#   'noRoute': None},
#  {'outboundDate': '2023-06-27',
#   'inboundDate': None,
#   'price': 7876,
#   'noRoute': None},
#  {'outboundDate': '2023-06-28',
#   'inboundDate': None,
#   'price': 8095,
#   'noRoute': None},
#  {'outboundDate': '2023-06-29',
#   'inboundDate': None,
#   'price': 4799,
#   'noRoute': None},
#  {'outboundDate': '2023-06-30',
#   'inboundDate': None,
#   'price': 8765,
#   'noRoute': None},
#  {'outboundDate': '2023-07-01',
#   'inboundDate': None,
#   'price': 9811,
#   'noRoute': None},
#  {'outboundDate': '2023-07-02',
#   'inboundDate': None,
#   'price': 7876,
#   'noRoute': None},
#  {'outboundDate': '2023-07-03',
#   'inboundDate': None,
#   'price': 7534,
#   'noRoute': None},
#  {'outboundDate': '2023-07-04',
#   'inboundDate': None,
#   'price': 7056,
#   'noRoute': None},
#  {'outboundDate': '2023-07-05',
#   'inboundDate': None,
#   'price': 7534,
#   'noRoute': None},
#  {'outboundDate': '2023-07-06',
#   'inboundDate': None,
#   'price': 4799,
#   'noRoute': None},
#  {'outboundDate': '2023-07-07',
#   'inboundDate': None,
#   'price': 7534,
#   'noRoute': None},
#  {'outboundDate': '2023-07-08',
#   'inboundDate': None,
#   'price': 7534,
#   'noRoute': None},
#  {'outboundDate': '2023-07-09',
#   'inboundDate': None,
#   'price': 7534,
#   'noRoute': None},
#  {'outboundDate': '2023-07-10',
#   'inboundDate': None,
#   'price': 7534,
#   'noRoute': None},
#  {'outboundDate': '2023-07-11',
#   'inboundDate': None,
#   'price': 4749,
#   'noRoute': None},
#  {'outboundDate': '2023-07-12',
#   'inboundDate': None,
#   'price': 6838,
#   'noRoute': None},
#  {'outboundDate': '2023-07-13',
#   'inboundDate': None,
#   'price': 6838,
#   'noRoute': None},
#  {'outboundDate': '2023-07-14',
#   'inboundDate': None,
#   'price': 6277,
#   'noRoute': None},
#  {'outboundDate': '2023-07-15',
#   'inboundDate': None,
#   'price': 6838,
#   'noRoute': None},
#  {'outboundDate': '2023-07-16',
#   'inboundDate': None,
#   'price': 8409,
#   'noRoute': None},
#  {'outboundDate': '2023-07-17',
#   'inboundDate': None,
#   'price': 7876,
#   'noRoute': None},
#  {'outboundDate': '2023-07-18',
#   'inboundDate': None,
#   'price': 6325,
#   'noRoute': None},
#  {'outboundDate': '2023-07-19',
#   'inboundDate': None,
#   'price': 7056,
#   'noRoute': None},
#  {'outboundDate': '2023-07-20',
#   'inboundDate': None,
#   'price': 6838,
#   'noRoute': None},
#  {'outboundDate': '2023-07-21',
#   'inboundDate': None,
#   'price': 7876,
#   'noRoute': None},
#  {'outboundDate': '2023-07-22',
#   'inboundDate': None,
#   'price': 9456,
#   'noRoute': None},
#  {'outboundDate': '2023-07-23',
#   'inboundDate': None,
#   'price': 7036,
#   'noRoute': None},
#  {'outboundDate': '2023-07-24',
#   'inboundDate': None,
#   'price': 7876,
#   'noRoute': None},
#  {'outboundDate': '2023-07-25',
#   'inboundDate': None,
#   'price': 8099,
#   'noRoute': None},
#  {'outboundDate': '2023-07-26',
#   'inboundDate': None,
#   'price': 7399,
#   'noRoute': None},
#  {'outboundDate': '2023-07-27',
#   'inboundDate': None,
#   'price': 7399,
#   'noRoute': None},
#  {'outboundDate': '2023-07-28',
#   'inboundDate': None,
#   'price': 5775,
#   'noRoute': None},
#  {'outboundDate': '2023-07-29',
#   'inboundDate': None,
#   'price': 8099,
#   'noRoute': None},
#  {'outboundDate': '2023-07-30',
#   'inboundDate': None,
#   'price': 7036,
#   'noRoute': None},
#  {'outboundDate': '2023-07-31',
#   'inboundDate': None,
#   'price': 6147,
#   'noRoute': None},
#  {'outboundDate': '2023-08-01',
#   'inboundDate': None,
#   'price': 7399,
#   'noRoute': None},
#  {'outboundDate': '2023-08-03',
#   'inboundDate': None,
#   'price': 6405,
#   'noRoute': None},
#  {'outboundDate': '2023-08-04',
#   'inboundDate': None,
#   'price': 5775,
#   'noRoute': None},
#  {'outboundDate': '2023-08-05',
#   'inboundDate': None,
#   'price': 7399,
#   'noRoute': None},
#  {'outboundDate': '2023-08-06',
#   'inboundDate': None,
#   'price': 6405,
#   'noRoute': None},
#  {'outboundDate': '2023-08-07',
#   'inboundDate': None,
#   'price': 7035,
#   'noRoute': None},
#  {'outboundDate': '2023-08-08',
#   'inboundDate': None,
#   'price': 5775,
#   'noRoute': None},
#  {'outboundDate': '2023-08-09',
#   'inboundDate': None,
#   'price': 5775,
#   'noRoute': None},
#  {'outboundDate': '2023-08-10',
#   'inboundDate': None,
#   'price': 5775,
#   'noRoute': None},
#  {'outboundDate': '2023-08-11',
#   'inboundDate': None,
#   'price': 6799,
#   'noRoute': None},
#  {'outboundDate': '2023-08-12',
#   'inboundDate': None,
#   'price': 7399,
#   'noRoute': None},
#  {'outboundDate': '2023-08-13',
#   'inboundDate': None,
#   'price': 7175,
#   'noRoute': None},
#  {'outboundDate': '2023-08-14',
#   'inboundDate': None,
#   'price': 6147,
#   'noRoute': None},
#  {'outboundDate': '2023-08-15',
#   'inboundDate': None,
#   'price': 6799,
#   'noRoute': None},
#  {'outboundDate': '2023-08-16',
#   'inboundDate': None,
#   'price': 7056,
#   'noRoute': None},
#  {'outboundDate': '2023-08-17',
#   'inboundDate': None,
#   'price': 7035,
#   'noRoute': None},
#  {'outboundDate': '2023-08-18',
#   'inboundDate': None,
#   'price': 7175,
#   'noRoute': None}]

# %%
new_datas.pop(0)
# Out:
# {'code': 0, 'message': ''}

# %%
new_datas
# Out:
# [{'outboundDate': '2023-05-21',
#   'inboundDate': None,
#   'price': 6128,
#   'noRoute': None},
#  {'outboundDate': '2023-05-22',
#   'inboundDate': None,
#   'price': 6996,
#   'noRoute': None},
#  {'outboundDate': '2023-05-23',
#   'inboundDate': None,
#   'price': 5799,
#   'noRoute': None},
#  {'outboundDate': '2023-05-24',
#   'inboundDate': None,
#   'price': 5775,
#   'noRoute': None},
#  {'outboundDate': '2023-05-25',
#   'inboundDate': None,
#   'price': 6405,
#   'noRoute': None},
#  {'outboundDate': '2023-05-26',
#   'inboundDate': None,
#   'price': 5073,
#   'noRoute': None},
#  {'outboundDate': '2023-05-27',
#   'inboundDate': None,
#   'price': 6405,
#   'noRoute': None},
#  {'outboundDate': '2023-05-28',
#   'inboundDate': None,
#   'price': 5799,
#   'noRoute': None},
#  {'outboundDate': '2023-05-29',
#   'inboundDate': None,
#   'price': 5145,
#   'noRoute': None},
#  {'outboundDate': '2023-05-30',
#   'inboundDate': None,
#   'price': 4689,
#   'noRoute': None},
#  {'outboundDate': '2023-05-31',
#   'inboundDate': None,
#   'price': 4689,
#   'noRoute': None},
#  {'outboundDate': '2023-06-01',
#   'inboundDate': None,
#   'price': 5799,
#   'noRoute': None},
#  {'outboundDate': '2023-06-02',
#   'inboundDate': None,
#   'price': 6299,
#   'noRoute': None},
#  {'outboundDate': '2023-06-03',
#   'inboundDate': None,
#   'price': 6799,
#   'noRoute': None},
#  {'outboundDate': '2023-06-04',
#   'inboundDate': None,
#   'price': 5073,
#   'noRoute': None},
#  {'outboundDate': '2023-06-05',
#   'inboundDate': None,
#   'price': 6799,
#   'noRoute': None},
#  {'outboundDate': '2023-06-06',
#   'inboundDate': None,
#   'price': 5775,
#   'noRoute': None},
#  {'outboundDate': '2023-06-07',
#   'inboundDate': None,
#   'price': 6299,
#   'noRoute': None},
#  {'outboundDate': '2023-06-08',
#   'inboundDate': None,
#   'price': 5775,
#   'noRoute': None},
#  {'outboundDate': '2023-06-09',
#   'inboundDate': None,
#   'price': 6405,
#   'noRoute': None},
#  {'outboundDate': '2023-06-10',
#   'inboundDate': None,
#   'price': 7036,
#   'noRoute': None},
#  {'outboundDate': '2023-06-11',
#   'inboundDate': None,
#   'price': 6996,
#   'noRoute': None},
#  {'outboundDate': '2023-06-12',
#   'inboundDate': None,
#   'price': 6799,
#   'noRoute': None},
#  {'outboundDate': '2023-06-13',
#   'inboundDate': None,
#   'price': 6996,
#   'noRoute': None},
#  {'outboundDate': '2023-06-14',
#   'inboundDate': None,
#   'price': 8099,
#   'noRoute': None},
#  {'outboundDate': '2023-06-15',
#   'inboundDate': None,
#   'price': 7876,
#   'noRoute': None},
#  {'outboundDate': '2023-06-16',
#   'inboundDate': None,
#   'price': 8717,
#   'noRoute': None},
#  {'outboundDate': '2023-06-17',
#   'inboundDate': None,
#   'price': 8111,
#   'noRoute': None},
#  {'outboundDate': '2023-06-18',
#   'inboundDate': None,
#   'price': 6996,
#   'noRoute': None},
#  {'outboundDate': '2023-06-19',
#   'inboundDate': None,
#   'price': 8717,
#   'noRoute': None},
#  {'outboundDate': '2023-06-20',
#   'inboundDate': None,
#   'price': 6996,
#   'noRoute': None},
#  {'outboundDate': '2023-06-21',
#   'inboundDate': None,
#   'price': 9180,
#   'noRoute': None},
#  {'outboundDate': '2023-06-22',
#   'inboundDate': None,
#   'price': 9811,
#   'noRoute': None},
#  {'outboundDate': '2023-06-23',
#   'inboundDate': None,
#   'price': 8754,
#   'noRoute': None},
#  {'outboundDate': '2023-06-24',
#   'inboundDate': None,
#   'price': 8111,
#   'noRoute': None},
#  {'outboundDate': '2023-06-25',
#   'inboundDate': None,
#   'price': 8811,
#   'noRoute': None},
#  {'outboundDate': '2023-06-26',
#   'inboundDate': None,
#   'price': 8717,
#   'noRoute': None},
#  {'outboundDate': '2023-06-27',
#   'inboundDate': None,
#   'price': 7876,
#   'noRoute': None},
#  {'outboundDate': '2023-06-28',
#   'inboundDate': None,
#   'price': 8095,
#   'noRoute': None},
#  {'outboundDate': '2023-06-29',
#   'inboundDate': None,
#   'price': 4799,
#   'noRoute': None},
#  {'outboundDate': '2023-06-30',
#   'inboundDate': None,
#   'price': 8765,
#   'noRoute': None},
#  {'outboundDate': '2023-07-01',
#   'inboundDate': None,
#   'price': 9811,
#   'noRoute': None},
#  {'outboundDate': '2023-07-02',
#   'inboundDate': None,
#   'price': 7876,
#   'noRoute': None},
#  {'outboundDate': '2023-07-03',
#   'inboundDate': None,
#   'price': 7534,
#   'noRoute': None},
#  {'outboundDate': '2023-07-04',
#   'inboundDate': None,
#   'price': 7056,
#   'noRoute': None},
#  {'outboundDate': '2023-07-05',
#   'inboundDate': None,
#   'price': 7534,
#   'noRoute': None},
#  {'outboundDate': '2023-07-06',
#   'inboundDate': None,
#   'price': 4799,
#   'noRoute': None},
#  {'outboundDate': '2023-07-07',
#   'inboundDate': None,
#   'price': 7534,
#   'noRoute': None},
#  {'outboundDate': '2023-07-08',
#   'inboundDate': None,
#   'price': 7534,
#   'noRoute': None},
#  {'outboundDate': '2023-07-09',
#   'inboundDate': None,
#   'price': 7534,
#   'noRoute': None},
#  {'outboundDate': '2023-07-10',
#   'inboundDate': None,
#   'price': 7534,
#   'noRoute': None},
#  {'outboundDate': '2023-07-11',
#   'inboundDate': None,
#   'price': 4749,
#   'noRoute': None},
#  {'outboundDate': '2023-07-12',
#   'inboundDate': None,
#   'price': 6838,
#   'noRoute': None},
#  {'outboundDate': '2023-07-13',
#   'inboundDate': None,
#   'price': 6838,
#   'noRoute': None},
#  {'outboundDate': '2023-07-14',
#   'inboundDate': None,
#   'price': 6277,
#   'noRoute': None},
#  {'outboundDate': '2023-07-15',
#   'inboundDate': None,
#   'price': 6838,
#   'noRoute': None},
#  {'outboundDate': '2023-07-16',
#   'inboundDate': None,
#   'price': 8409,
#   'noRoute': None},
#  {'outboundDate': '2023-07-17',
#   'inboundDate': None,
#   'price': 7876,
#   'noRoute': None},
#  {'outboundDate': '2023-07-18',
#   'inboundDate': None,
#   'price': 6325,
#   'noRoute': None},
#  {'outboundDate': '2023-07-19',
#   'inboundDate': None,
#   'price': 7056,
#   'noRoute': None},
#  {'outboundDate': '2023-07-20',
#   'inboundDate': None,
#   'price': 6838,
#   'noRoute': None},
#  {'outboundDate': '2023-07-21',
#   'inboundDate': None,
#   'price': 7876,
#   'noRoute': None},
#  {'outboundDate': '2023-07-22',
#   'inboundDate': None,
#   'price': 9456,
#   'noRoute': None},
#  {'outboundDate': '2023-07-23',
#   'inboundDate': None,
#   'price': 7036,
#   'noRoute': None},
#  {'outboundDate': '2023-07-24',
#   'inboundDate': None,
#   'price': 7876,
#   'noRoute': None},
#  {'outboundDate': '2023-07-25',
#   'inboundDate': None,
#   'price': 8099,
#   'noRoute': None},
#  {'outboundDate': '2023-07-26',
#   'inboundDate': None,
#   'price': 7399,
#   'noRoute': None},
#  {'outboundDate': '2023-07-27',
#   'inboundDate': None,
#   'price': 7399,
#   'noRoute': None},
#  {'outboundDate': '2023-07-28',
#   'inboundDate': None,
#   'price': 5775,
#   'noRoute': None},
#  {'outboundDate': '2023-07-29',
#   'inboundDate': None,
#   'price': 8099,
#   'noRoute': None},
#  {'outboundDate': '2023-07-30',
#   'inboundDate': None,
#   'price': 7036,
#   'noRoute': None},
#  {'outboundDate': '2023-07-31',
#   'inboundDate': None,
#   'price': 6147,
#   'noRoute': None},
#  {'outboundDate': '2023-08-01',
#   'inboundDate': None,
#   'price': 7399,
#   'noRoute': None},
#  {'outboundDate': '2023-08-03',
#   'inboundDate': None,
#   'price': 6405,
#   'noRoute': None},
#  {'outboundDate': '2023-08-04',
#   'inboundDate': None,
#   'price': 5775,
#   'noRoute': None},
#  {'outboundDate': '2023-08-05',
#   'inboundDate': None,
#   'price': 7399,
#   'noRoute': None},
#  {'outboundDate': '2023-08-06',
#   'inboundDate': None,
#   'price': 6405,
#   'noRoute': None},
#  {'outboundDate': '2023-08-07',
#   'inboundDate': None,
#   'price': 7035,
#   'noRoute': None},
#  {'outboundDate': '2023-08-08',
#   'inboundDate': None,
#   'price': 5775,
#   'noRoute': None},
#  {'outboundDate': '2023-08-09',
#   'inboundDate': None,
#   'price': 5775,
#   'noRoute': None},
#  {'outboundDate': '2023-08-10',
#   'inboundDate': None,
#   'price': 5775,
#   'noRoute': None},
#  {'outboundDate': '2023-08-11',
#   'inboundDate': None,
#   'price': 6799,
#   'noRoute': None},
#  {'outboundDate': '2023-08-12',
#   'inboundDate': None,
#   'price': 7399,
#   'noRoute': None},
#  {'outboundDate': '2023-08-13',
#   'inboundDate': None,
#   'price': 7175,
#   'noRoute': None},
#  {'outboundDate': '2023-08-14',
#   'inboundDate': None,
#   'price': 6147,
#   'noRoute': None},
#  {'outboundDate': '2023-08-15',
#   'inboundDate': None,
#   'price': 6799,
#   'noRoute': None},
#  {'outboundDate': '2023-08-16',
#   'inboundDate': None,
#   'price': 7056,
#   'noRoute': None},
#  {'outboundDate': '2023-08-17',
#   'inboundDate': None,
#   'price': 7035,
#   'noRoute': None},
#  {'outboundDate': '2023-08-18',
#   'inboundDate': None,
#   'price': 7175,
#   'noRoute': None}]

# %%
# 拆除最外層的列表
# flat_list = new_datas[0]
for i in range(1, len(new_datas)):
    new_data = new_datas[i]
    col.insert_one(new_data)

# %%
# import pandas as pd
# df = pd.read_csv('crawler.csv')
# df
