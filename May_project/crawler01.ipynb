# %%
import requests
from bs4 import BeautifulSoup
from pymongo import MongoClient

# %%
# connect pymongo
client = MongoClient("mongodb://localhost:27017")
# client.list_database_names()
# connect Database
db = client["May"]
# connect collection
col = db["crawler"]

# %%
# 設定要爬取的網址
url = 'https://flight.eztravel.com.tw/apiv2/flight/list?sig=fc55fef04c20ba7b'

payload = {
    "head": {
        "clientID": "2ee3a8f7-b64a-9ed7-0f41-4954eb57321f",
        "transactionID": "5ff42a7824d683b9",
        "userAgent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/112.0.0.0 Safari/537.36"
    },
    "data": {
        "JourneyType": 2,
        "CabinType": "any",
        "AirlineCode": "",
        "AdultCnt": 1,
        "ChildCnt": 0,
        "InfantCnt": 0,
        "IsDirectFlight": False,
        "OutBoundDate": "05/06/2023",
        "InBoundDate": "11/06/2023",
        "FromCityCode": "TPE",
        "ToCityCode": "OSA",
        "FromAirportCode": "",
        "ToAirportCode": "",
        "ResourceType": "eztravel"
    }
}

# 發送 GET 請求並取得 HTML 網頁原始碼
response = requests.post(url=url, json=payload)
html = response.text

# 解析 HTML 網頁原始碼
soup = BeautifulSoup(response.text, 'html.parser')
print(soup.prettify())
# Out:
# {"head":{"code":0,"message":""},"data":{"flightList":[{"flightKey":"MU5008MU747","departureDate":"6月5日","departureTime":"15:30","arrivalDate":"6月6日","arrivalTime":"15:20","crossDays":1,"departureCityCode":"TPE","arrivalCityCode":"OSA","departureCityName":"台北","arrivalCityName":"大阪","departureAirportCode":"TPE","departureAirportName":"桃園國際機場","arrivalAirportCode":"KIX","arrivalAirportName":"關西機場","departureTerminal":"T2","arrivalTerminal":"T1","stopType":1,"transit":{"isCrossday":true,"isChangeAirport":false,"isChangeTerminal":false,"TransitType":1,"TransferCity":"上海","TransferSpan":"18h30m"},"airlineName":"中國東方航空","airlineFlitername":"中國東方航空","airlineCode":"MU","validatingAirlineCode":"MU","seats":[{"seatCount":9,"seatType":"EzTravel","feeConfirm":true,"currencyCode":"TWD","price":17895,"averagePrice":17895,"averagePriceNoTax":12951,"priceWithoutTax":12951,"priceWithTax":17895,"adultPrice":12951,"adultCnt":1,"adultTax":4944,"childPrice":0,"childTax":0,"childCnt":0,"infantPrice":0,"infantTax":0,"infantCnt":0,"selectedFlightParas":"{\"OutBoundToken\":\"fa94ac1d0e1f0d4b\",\"RouteSearchToken\":\"c48e2f99-e0bd-4a2a-8555-4109b209c8da|27|9:5\"}","selectedFlightInfo":"{\"Airline\":{\"Code\":\"MU\",\"Name\":\"中國東方航空\"},\"ArrivalAirport\":{\"Code\":\"KIX\",\"Name\":\"關西機場\",\"Terminal\":\"T1\",\"change\":false,\"country\":\"JP\"},\"ArrivalDate\":1686036000000,\"DepartureAirport\":{\"Code\":\"TPE\",\"Name\":\"桃園國際機場\",\"Terminal\":\"T2\",\"change\":false,\"country\":\"TW\"},\"DepartureDate\":1685950200000,\"FlightNo\":\"MU5008 MU747\",\"FromAirport\":\"桃園國際機場\",\"GoTime\":\"2023年06月05日 15:30\",\"ToAirport\":\"關西機場\",\"ToTime\":\"2023年06月06日 15:20\",\"TransitDesc\":\"1程中轉\"}","displayCategory":99,"classType":"經濟艙","allClassType":null,"engineType":"Amadeus","remarkId":"c48e2f99-e0bd-4a2a-8555-4109b209c8da|27|9:5","fareInfo":null,"planCategory":"EZTRAVEL","resourceName":"易遊優選","resourceDesc":"享快速出票+線上更改/退票申請服務","freeBaggage":3,"productDesc":"","ticketingDesc":"付款後5分鐘出票","ticketingCode":1,"ageRestriction":"","passportTag":"","companionFare":null,"combineTag":null,"FarePenaltiesFlag":2,"FarePenalties":{"baggageFormats":[{"segmentNo":1,"sequenceNo":1,"fromCity":{"code":"TPE","country":null,"lineType":null,"Name":"台北"},"toCity":{"code":"SHA","country":null,"lineType":null,"Name":"上海"},"passengerType":"Adult","checkInBaggage":{"weight":23,"unit":"N","piece":2,"size":null,"sizeType":null,"text":"每人2件，每件23公斤。"},"carryOnBaggage":{"weight":8,"unit":"N","piece":1,"size":null,"sizeType":null,"text":"每人1件，每件8公斤，長寬高不可超過55*40*20公分。"},"route":null},{"segmentNo":1,"sequenceNo":2,"fromCity":{"code":"SHA","country":null,"lineType":null,"Name":"上海"},"toCity":{"code":"OSA","country":null,"lineType":null,"Name":"大阪"},"passengerType":"Adult","checkInBaggage":{"weight":23,"unit":"N","piece":2,"size":null,"sizeType":null,"text":"每人2件，每件23公斤。"},"carryOnBaggage":{"weight":8,"unit":"N","piece":1,"size":null,"sizeType":null,"text":"每人1件，每件8公斤，長寬高不可超過55*40*20公分。"},"route":null},{"segmentNo":2,"sequenceNo":1,"fromCity":{"code":"OSA","country":null,"lineType":null,"Name":"大阪"},"toCity":{"code":"SHA","country":null,"lineType":null,"Name":"上海"},"passengerType":"Adult","checkInBaggage":{"weight":23,"unit":"N","piece":2,"size":null,"sizeType":null,"text":"每人2件，每件23公斤。"},"carryOnBaggage":{"weight":8,"unit":"N","piece":1,"size":null,"sizeType":null,"text":"每人1件，每件8公斤，長寬高不可超過55*40*20公分。"},"route":null},{"segmentNo":2,"sequenceNo":2,"fromCity":{"code":"SHA","country":null,"lineType":null,"Name":"上海"},"toCity":{"code":"TPE","country":null,"lineType":null,"Name":"台北"},"passengerType":"Adult","checkInBaggage":{"weight":23,"unit":"N","piece":2,"size":null,"sizeType":null,"text":"每人2件，每件23公斤。"},"carryOnBaggage":{"weight":8,"unit":"N","piece":1,"size":null,"sizeType":null,"text":"每人1件，每件8公斤，長寬高不可超過55*40*20公分。"},"route":null}],"penaltyFormat":null,"baggageTag":"行李每成人2*23KG","penaltyFlag":1,"penaltyTag":"不可退票","FarePenaltiesFlag":2,"Penalties":null,"Baggages":[{"Segment":"台北-上海","Text": ...

# %%
url = [
    'https://flight.eztravel.com.tw/apiv2/flight/list?sig=fc55fef04c20ba7b',
    'https://flight.eztravel.com.tw/apiv2/flight/list?sig=d8f3ce84e97ab2aa'
]

payload = {
    "head": {
        "clientID": "2ee3a8f7-b64a-9ed7-0f41-4954eb57321f",
        "transactionID": "5ff42a7824d683b9",
        "userAgent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/112.0.0.0 Safari/537.36"
    },
    "data": {
        "JourneyType": 2,
        "CabinType": "any",
        "AirlineCode": "",
        "AdultCnt": 1,
        "ChildCnt": 0,
        "InfantCnt": 0,
        "IsDirectFlight": False,
        "OutBoundDate": "05/06/2023",
        "InBoundDate": "11/06/2023",
        "FromCityCode": "TPE",
        "ToCityCode": "OSA",
        "FromAirportCode": "",
        "ToAirportCode": "",
        "ResourceType": "eztravel"
    }
}


def crawler(url):
    response = requests.post(url=url, json=payload)
    data = response.json()
    return data


for u in url:
    data = crawler(u)
    # 在這裡處理獲得的資料
    # 可以使用data變數來操作資料，例如進行解析、提取需要的資訊等等
    # print(data)

print(url)
print(u)
# # 發送 GET 請求並取得 HTML 網頁原始碼
# response = requests.post(url=url, json=payload)
# html = response.text
# # 解析 HTML 網頁原始碼
# soup = BeautifulSoup(response.text, 'html.parser')
# print(soup.prettify())
# Out:
# ['https://flight.eztravel.com.tw/apiv2/flight/list?sig=fc55fef04c20ba7b', 'https://flight.eztravel.com.tw/apiv2/flight/list?sig=d8f3ce84e97ab2aa']
# https://flight.eztravel.com.tw/apiv2/flight/list?sig=d8f3ce84e97ab2aa

# %%
import json
# 將解析結果轉換為JSON格式
json_data = json.loads(str(soup))
print(json_data)
# Out:
# {'head': {'code': 0, 'message': ''}, 'data': {'flightList': [{'flightKey': 'MU5008MU747', 'departureDate': '6月5日', 'departureTime': '15:30', 'arrivalDate': '6月6日', 'arrivalTime': '15:20', 'crossDays': 1, 'departureCityCode': 'TPE', 'arrivalCityCode': 'OSA', 'departureCityName': '台北', 'arrivalCityName': '大阪', 'departureAirportCode': 'TPE', 'departureAirportName': '桃園國際機場', 'arrivalAirportCode': 'KIX', 'arrivalAirportName': '關西機場', 'departureTerminal': 'T2', 'arrivalTerminal': 'T1', 'stopType': 1, 'transit': {'isCrossday': True, 'isChangeAirport': False, 'isChangeTerminal': False, 'TransitType': 1, 'TransferCity': '上海', 'TransferSpan': '18h30m'}, 'airlineName': '中國東方航空', 'airlineFlitername': '中國東方航空', 'airlineCode': 'MU', 'validatingAirlineCode': 'MU', 'seats': [{'seatCount': 9, 'seatType': 'EzTravel', 'feeConfirm': True, 'currencyCode': 'TWD', 'price': 16978, 'averagePrice': 16978, 'averagePriceNoTax': 12034, 'priceWithoutTax': 12034, 'priceWithTax': 16978, 'adultPrice': 12034, 'adultCnt': 1, 'adultTax': 4944, 'childPrice': 0, 'childTax': 0, 'childCnt': 0, 'infantPrice': 0, 'infantTax': 0, 'infantCnt': 0, 'selectedFlightParas': '{"OutBoundToken":"fa94ac1d0e1f0d4b","RouteSearchToken":"fd0d5130-14b8-4ec1-aa17-2000e438609f|16|6:4"}', 'selectedFlightInfo': '{"Airline":{"Code":"MU","Name":"中國東方航空"},"ArrivalAirport":{"Code":"KIX","Name":"關西機場","Terminal":"T1","change":false,"country":"JP"},"ArrivalDate":1686036000000,"DepartureAirport":{"Code":"TPE","Name":"桃園國際機場","Terminal":"T2","change":false,"country":"TW"},"DepartureDate":1685950200000,"FlightNo":"MU5008 MU747","FromAirport":"桃園國際機場","GoTime":"2023年06月05日 15:30","ToAirport":"關西機場","ToTime":"2023年06月06日 15:20","TransitDesc":"1程中轉"}', 'displayCategory': 99, 'classType': '經濟艙', 'allClassType': None, 'engineType': 'Amadeus', 'remarkId': 'fd0d5130-14b8-4ec1-aa17-2000e438609f|16|6:4', 'fareInfo': None, 'planCategory': 'EZTRAVEL', 'resourceName': '易遊優選', 'resourceDesc': '享快速出票+線上更改/退票申請服務', 'freeBaggage': 3, 'productDesc': '', 'ticketingDesc': '付款後5分鐘出票', 'ticketingCode': 1, 'ageRestriction': '', 'passportTag': '', 'companionFare': None, 'combineTag': None, 'FarePenaltiesFlag': 2, 'FarePenalties': {'baggageFormats': [{'segmentNo': 1, 'sequenceNo': 1, 'fromCity': {'code': 'TPE', 'country': None, 'lineType': None, 'Name': '台北'}, 'toCity': {'code': 'SHA', 'country': None, 'lineType': None, 'Name': '上海'}, 'passengerType': 'Adult', 'checkInBaggage': {'weight': 23, 'unit': 'N', 'piece': 2, 'size': None, 'sizeType': None, 'text': '每人2件，每件23公斤。'}, 'carryOnBaggage': {'weight': 8, 'unit': 'N', 'piece': 1, 'size': None, 'sizeType': None, 'text': '每人1件，每件8公斤，長寬高不可超過55*40*20公分。'}, 'route': None}, {'segmentNo': 1, 'sequenceNo': 2, 'fromCity': {'code': 'SHA', 'country': None, 'lineType': None, 'Name': '上海'}, 'toCity': {'code': 'OSA', 'country': None, 'lineType': None, 'Name': '大阪'}, 'passengerType': 'Adult', 'checkInBaggage': {'weight': 23, 'unit': 'N', 'piece': 2, 'size': None, 'sizeType': None, 'text': '每人2件，每件23公斤。'}, 'carryOnBaggage': {'weight': 8, 'unit': 'N', 'piece': 1, 'size': None, 'sizeType': None, 'text': '每人1件，每件8公斤，長寬高不可超過55*40*20公分。'}, 'route': None}, {'segmentNo': 2, 'sequenceNo': 1, 'fromCity': {'code': 'OSA', 'country': None, 'lineType': None, 'Name': '大阪'}, 'toCity': {'code': 'SHA', 'country': None, 'lineType': None, 'Name': '上海'}, 'passengerType': 'Adult', 'checkInBaggage': {'weight': 23, 'unit': 'N', 'piece': 2, 'size': None, 'sizeType': None, 'text': '每人2件，每件23公斤。'}, 'carryOnBaggage': {'weight': 8, 'unit': 'N', 'piece': 1, 'size': None, 'sizeType': None, 'text': '每人1件，每件8公斤，長寬高不可超過55*40*20公分。'}, 'route': None}, {'segmentNo': 2, 'sequenceNo': 2, 'fromCity': {'code': 'SHA', 'country': None, 'lineType': None, 'Name': '上海'}, 'toCity': {'code': 'TPE', 'country': None, 'lineType': None, 'Name': '台北'}, 'passengerType': 'Adult', 'checkInBaggage': {'weight': 23, 'unit': 'N', 'piece': 2, 'size': None, 'sizeType': None, 'text': '每人2件，每件23公斤。'}, 'carryOnBaggage': {'weight': 8, 'unit': 'N', ' ...

# %%
json_data
# Out:
# {'head': {'code': 0, 'message': ''},
#  'data': {'flightList': [{'flightKey': 'MU5008MU747',
#     'departureDate': '6月5日',
#     'departureTime': '15:30',
#     'arrivalDate': '6月6日',
#     'arrivalTime': '15:20',
#     'crossDays': 1,
#     'departureCityCode': 'TPE',
#     'arrivalCityCode': 'OSA',
#     'departureCityName': '台北',
#     'arrivalCityName': '大阪',
#     'departureAirportCode': 'TPE',
#     'departureAirportName': '桃園國際機場',
#     'arrivalAirportCode': 'KIX',
#     'arrivalAirportName': '關西機場',
#     'departureTerminal': 'T2',
#     'arrivalTerminal': 'T1',
#     'stopType': 1,
#     'transit': {'isCrossday': True,
#      'isChangeAirport': False,
#      'isChangeTerminal': False,
#      'TransitType': 1,
#      'TransferCity': '上海',
#      'TransferSpan': '18h30m'},
#     'airlineName': '中國東方航空',
#     'airlineFlitername': '中國東方航空',
#     'airlineCode': 'MU',
#     'validatingAirlineCode': 'MU',
#     'seats': [{'seatCount': 9,
#       'seatType': 'EzTravel',
#       'feeConfirm': True,
#       'currencyCode': 'TWD',
#       'price': 16978,
#       'averagePrice': 16978,
#       'averagePriceNoTax': 12034,
#       'priceWithoutTax': 12034,
#       'priceWithTax': 16978,
#       'adultPrice': 12034,
#       'adultCnt': 1,
#       'adultTax': 4944,
#       'childPrice': 0,
#       'childTax': 0,
#       'childCnt': 0,
#       'infantPrice': 0,
#       'infantTax': 0,
#       'infantCnt': 0,
#       'selectedFlightParas': '{"OutBoundToken":"fa94ac1d0e1f0d4b","RouteSearchToken":"fd0d5130-14b8-4ec1-aa17-2000e438609f|16|6:4"}',
#       'selectedFlightInfo': '{"Airline":{"Code":"MU","Name":"中國東方航空"},"ArrivalAirport":{"Code":"KIX","Name":"關西機場","Terminal":"T1","change":false,"country":"JP"},"ArrivalDate":1686036000000,"DepartureAirport":{"Code":"TPE","Name":"桃園國際機場","Terminal":"T2","change":false,"country":"TW"},"DepartureDate":1685950200000,"FlightNo":"MU5008 MU747","FromAirport":"桃園國際機場","GoTime":"2023年06月05日 15:30","ToAirport":"關西機場","ToTime":"2023年06月06日 15:20","TransitDesc":"1程中轉"}',
#       'displayCategory': 99,
#       'classType': '經濟艙',
#       'allClassType': None,
#       'engineType': 'Amadeus',
#       'remarkId': 'fd0d5130-14b8-4ec1-aa17-2000e438609f|16|6:4',
#       'fareInfo': None,
#       'planCategory': 'EZTRAVEL',
#       'resourceName': '易遊優選',
#       'resourceDesc': '享快速出票+線上更改/退票申請服務',
#       'freeBaggage': 3,
#       'productDesc': '',
#       'ticketingDesc': '付款後5分鐘出票',
#       'ticketingCode': 1,
#       'ageRestriction': '',
#       'passportTag': '',
#       'companionFare': None,
#       'combineTag': None,
#       'FarePenaltiesFlag': 2,
#       'FarePenalties': {'baggageFormats': [{'segmentNo': 1,
#          'sequenceNo': 1,
#          'fromCity': {'code': 'TPE',
#           'country': None,
#           'lineType': None,
#           'Name': '台北'},
#          'toCity': {'code': 'SHA',
#           'country': None,
#           'lineType': None,
#           'Name': '上海'},
#          'passengerType': 'Adult',
#          'checkInBaggage': {'weight': 23,
#           'unit': 'N',
#           'piece': 2,
#           'size': None,
#           'sizeType': None,
#           'text': '每人2件，每件23公斤。'},
#          'carryOnBaggage': {'weight': 8,
#           'unit': 'N',
#           'piece': 1,
#           'size': None,
#           'sizeType': None,
#           'text': '每人1件，每件8公斤，長寬高不可超過55*40*20公分。'},
#          'route': None},
#         {'segmentNo': 1,
#          'sequenceNo': 2,
#          'fromCity': {'code': 'SHA',
#           'country': None,
#           'lineType': None,
#           'Name': '上海'},
#          'toCity': {'code': 'OSA',
#           'country': None,
#           'lineType': None,
#           'Name': '大阪'},
#          'passengerType': 'Adult',
#          'checkInBaggage': {'weight': 23,
#           'unit': 'N',
#           'piece': 2,
#           'size': None,
#           'sizeType': None,
#           'text': '每人2件，每件23公斤。'},
#          'carryOnBaggage': {'weight': 8,
#           'unit': 'N',
#           'piece': 1,
#           'size': None,
#           'sizeType': None,
#           'text': '每人1件，每件8公斤，長寬高不可超過55*40*20公分。'},
#          'route': None},
#         {'segmentNo': 2,
#          'sequenceNo': 1,
#          'fromCity': {'code': 'OSA',
#           'country': None,
#           'lineType': None,
#           'Name': '大阪'},
#          'toCity': {'code': 'SHA',
#           'country': None,
#           'lineType': None,
#           'Name': '上海'},
#          'passengerType': 'Adult',
#          'checkInBaggage': {'weight': 23,
#           'unit': 'N',
#           'piece': 2,
#           'size': None,
#           'sizeType': None,
#           'text': '每人2件，每件23公斤。'},
#          'carryOnBaggage': {'weight': 8,
#           'unit': 'N',
#           'piece': 1,
#           'size': None,
#           'sizeType': None,
#           'text': '每人1件，每件8公斤，長寬高不可超過55*40*20公分。'},
#          'route': None},
#         {'segmentNo': 2,
#          'sequenceNo': 2,
#          'fromCity': {'code': 'SHA',
#           'country': None,
#           'lineType': None,
#           'Name': '上海'},
#          'toCity': {'code': 'TPE',
#           'country': None,
#           'lineType': None,
#           'Name': '台北'},
#          'passengerType': 'Adult',
#          'checkInBaggage': {'weight': 23,
#           'unit': 'N',
#           'piece': 2,
#           'size': None,
#           'sizeType': None,
#           'text': '每人2件，每件23公斤。'},
#          'carryOnBaggage': {'weight': 8,
#           'unit': 'N',
#           'piece': 1,
#           'size': None,
#           'sizeType': None,
#           'text': '每人1件，每件8公斤，長寬高不可超過55*40*20公分。'},
#          'route': None}],
#        'penaltyFormat': None,
#        'baggageTag': '行李每成人2*23KG',
#        'penaltyFlag': 1,
#        'penaltyTag': '不可退票',
#        'FarePenaltiesFlag': 2,
#        'Penalties': None,
#        'Baggages': [{'Segment': '台北-上海', 'Text': '每人2件，每件23公斤。'},
#         {'Segment': '上海-大阪', 'Text': '每人2件，每件23公斤。'},
#         {'Segment': '大阪-上海', 'Text': '每人2件，每件23公斤。'},
#         {'Segment': '上海-台北', 'Text': '每人2件，每件23公斤。'}],
#        'NationDisallowed': '',
#        'NationAllowed': '',
#        'CityAllowed': '',
#        'Remark': None},
#       'easeTag': None,
#       'ticketType': 'ADULT',
#       'license': None}],
#     'flightDetails': [{'departureFullDate': '20230605',
#       'departureDate': '6月5日',
#       'arrivalDate': '6月5日',
#       'goDate': '2023-06-05',
#       'departureTime': '15:30',
#       'toDate': '2023-06-05',
#       'arrivalTime': '17:30',
#       'isRedEye': False,
#       'durationMinutes': 120,
#       'transferStayMinutes': 1110,
#       'departureCity': 'TPE',
#       'departureCityCode': 'TPE',
#       'departureCityName': '台北',
#       'arrivalCity': 'SHA',
#       'arrivalCityCode': 'SHA',
#       'arrivalCityName': '上海',
#       'airlineCode': 'MU',
#       'airline': '中國東方航空',
#       'flightNo': 'MU5008',
#       'operatingAirlineCode': None,
#       'operatingAirline': None,
#       'operatingFlightNo': None,
#       'craft': {'craftType': '333',
#        'enName': None,
#        'widthLevel': None,
#        'minSeats': 256,
#        'maxSeats': 412,
#        'craftName': '空中巴士 330-300'},
#       'transitType': 1,
#       'departureAirportCode': 'TPE',
#       'departureAirportName': '桃園國際機場',
#       'departureTerminal': 'T2',
#       'arrivalAirportCode': 'PVG',
#       'arrivalAirportName': '上海浦東機場',
#       'arrivalTerminal': 'T1',
#       'cabinType': 'tourist',
#       'cabinDesc': '經濟艙',
#       'bookingClass': 'B',
#       'crossDays': 0,
#       'stopList': [],
#       'transfer': {'isCrossday': True,
#        'isChangeAirport': False,
#        'isChangeTerminal': False,
#        'TransitType': 1,
#        'TransferCity': '上海',
#        'TransferSpan': '18h30m'},
#       'seqNo': 1,
#       'segmentNo': 1,
#       'sequenceNo': 1,
#       'baggageStraight': 0,
#       'dterminal': 'T2',
#       'dport': 'TPE',
#       'aterminal': 'T1',
#       'aport': 'PVG'},
#      {'departureFullDate': '20230606',
#       'departureDate': '6月6日',
#       'arrivalDate': '6月6日',
#       'goDate': '2023-06-06',
#       'departureTime': '12:00',
#       'toDate': '2023-06-06',
#       'arrivalTime': '15:20',
#       'isRedEye': False,
#       'durationMinutes': 140,
#       'transferStayMinutes': None,
#       'departureCity': 'SHA',
#       'departureCityCode': 'SHA',
#       'departureCityName': '上海',
#       'arrivalCity': 'OSA',
#       'arrivalCityCode': 'OSA',
#       'arrivalCityName': '大阪',
#       'airlineCode': 'MU',
#       'airline': '中國東方航空',
#       'flightNo': 'MU747',
#       'operatingAirlineCode': None,
#       'operatingAirline': None,
#       'operatingFlightNo': None,
#       'craft': {'craftType': '321',
#        'enName': None,
#        'widthLevel': None,
#        'minSeats': 174,
#        'maxSeats': 220,
#        'craftName': '空中巴士 A321'},
#       'transitType': 0,
#       'departureAirportCode': 'PVG',
#       'departureAirportName': '上海浦東機場',
#       'departureTerminal': 'T1',
#       'arrivalAirportCode': 'KIX',
#       'arrivalAirportName': '關西機場',
#       'arrivalTerminal': 'T1',
#       'cabinType': 'tourist',
#       'cabinDesc': '經濟艙',
#       'bookingClass': 'V',
#       'crossDays': 0,
#       'stopList': [],
#       'transfer': None,
#       'seqNo': 2,
#       'segmentNo': 1,
#       'sequenceNo': 2,
#       'baggageStraight': 0,
#       'dterminal': 'T1',
#       'dport': 'PVG',
#       'aterminal': 'T1',
#       'aport': 'KIX'}],
#     'stuTicketGrp': False},
#    {'flightKey': 'CX479CX506',
#     'departureDate': '6月5日',
#     'departureTime': '21:15',
#     'arrivalDate': '6月6日',
#     'arrivalTime': '15:15',
#     'crossDays': 1,
#     'departureCityCode': 'TPE',
#     'arrivalCityCode': 'OSA',
#     'departureCityName': '台北',
#     'arrivalCityName': '大阪',
#     'departureAirportCode': 'TPE',
#     'departureAirportName': '桃園國際機場',
#     'arrivalAirportCode': 'KIX',
#     'arrivalAirportName': '關西機場',
#     'departureTerminal': 'T1',
#     'arrivalTerminal': 'T1',
#     'stopType': 1,
#     'transit': {'isCrossday': True,
#      'isChangeAirport': False,
#      'isChangeTerminal': False,
#      'TransitType': 1,
#      'TransferCity': '香港',
#      'TransferSpan': '11h15m'},
#     'airlineName': '國泰航空',
#     'airlineFlitername': '國泰航空',
#     'airlineCode': 'CX',
#     'validatingAirlineCode': 'CX',
#     'seats': [{'seatCount': 9,
#       'seatType': 'EzTravel',
#       'feeConfirm': True,
#       'currencyCode': 'TWD',
#       'price': 21236,
#       'averagePrice': 21236,
#       'averagePriceNoTax': 15083,
#       'priceWithoutTax': 15083,
#       'priceWithTax': 21236,
#       'adultPrice': 15083,
#       'adultCnt': 1,
#       'adultTax': 6153,
#       'childPrice': 0,
#       'childTax': 0,
#       'childCnt': 0,
#       'infantPrice': 0,
#       'infantTax': 0,
#       'infantCnt': 0,
#       'selectedFlightParas': '{"OutBoundToken":"a8534f720c7c1e7f","RouteSearchToken":"fd0d5130-14b8-4ec1-aa17-2000e438609f|52|34:24"}',
#       'selectedFlightInfo': '{"Airline":{"Code":"CX","Name":"國泰航空"},"ArrivalAirport":{"Code":"KIX","Name":"關西機場","Terminal":"T1","change":false,"country":"JP"},"ArrivalDate":1686035700000,"DepartureAirport":{"Code":"TPE","Name":"桃園國際機場","Terminal":"T1","change":false,"country":"TW"},"DepartureDate":1685970900000,"FlightNo":"CX479 CX506","FromAirport":"桃園國際機場","GoTime":"2023年06月05日 21:15","ToAirport":"關西機場","ToTime":"2023年06月06日 15:15","TransitDesc":"1程中轉"}',
#       'displayCategory': 99,
#       'classType': '經濟艙',
#       'allClassType': None,
#       'engineType': 'Abacus',
#       'remarkId': 'fd0d5130-14b8-4ec1-aa17-2000e438609f|52|34:24',
#       'fareInfo': None,
#       'planCategory': 'EZTRAVEL',
#       'resourceName': '易遊優選',
#       'resourceDesc': '享快速出票+線上更改/退票申請服務',
#       'freeBaggage': 3,
#       'productDesc': '',
#       'ticketingDesc': '付款後5分鐘出票',
#       'ticketingCode': 1,
#       'ageRestriction': '',
#       'passportTag': '',
#       'companionFare': None,
#       'combineTag': None,
#       'FarePenaltiesFlag': 2,
#       'FarePenalties': {'baggageFormats': [{'segmentNo': 1,
#          'sequenceNo': 1,
#          'fromCity': {'code': 'TPE',
#           'country': None,
#           'lineType': None,
#           'Name': '台北'},
#          'toCity': {'code': 'HKG',
#           'country': None,
#           'lineType': None,
#           'Name': '香港'},
#          'passengerType': 'Adult',
#          'checkInBaggage': {'weight': 23,
#           'unit': 'N',
#           'piece': 1,
#           'size': None,
#           'sizeType': None,
#           'text': '每人1件，每件23公斤。'},
#          'carryOnBaggage': {'weight': 7,
#           'unit': 'N',
#           'piece': 1,
#           'size': None,
#           'sizeType': None,
#           'text': '每人1件，每件7公斤，長寬高不可超過56*36*23公分。'},
#          'route': None},
#         {'segmentNo': 1,
#          'sequenceNo': 2,
#          'fromCity': {'code': 'HKG',
#           'country': None,
#           'lineType': None,
#           'Name': '香港'},
#          'toCity': {'code': 'OSA',
#           'country': None,
#           'lineType': None,
#           'Name': '大阪'},
#          'passengerType': 'Adult',
#          'checkInBaggage': {'weight': 23,
#           'unit': 'N',
#           'piece': 1,
#           'size': None,
#           'sizeType': None,
#           'text': '每人1件，每件23公斤。'},
#          'carryOnBaggage': {'weight': 7,
#           'unit': 'N',
#           'piece': 1,
#           'size': None,
#           'sizeType': None,
#           'text': '每人1件，每件7公斤，長寬高不可超過56*36*23公分。'},
#          'route': None},
#         {'segmentNo': 2,
#          'sequenceNo': 1,
#          'fromCity': {'code': 'OSA',
#           'country': None,
#           'lineType': None,
#           'Name': '大阪'},
#          'toCity': {'code': 'HKG',
#           'country': None,
#           'lineType': None,
#           'Name': '香港'},
#          'passengerType': 'Adult',
#          'checkInBaggage': {'weight': 23,
#           'unit': 'N',
#           'piece': 1,
#           'size': None,
#           'sizeType': None,
#           'text': '每人1件，每件23公斤。'},
#          'carryOnBaggage': {'weight': 7,
#           'unit': 'N',
#           'piece': 1,
#           'size': None,
#           'sizeType': None,
#           'text': '每人1件，每件7公斤，長寬高不可超過56*36*23公分。'},
#          'route': None},
#         {'segmentNo': 2,
#          'sequenceNo': 2,
#          'fromCity': {'code': 'HKG',
#           'country': None,
#           'lineType': None,
#           'Name': '香港'},
#          'toCity': {'code': 'TPE',
#           'country': None,
#           'lineType': None,
#           'Name': '台北'},
#          'passengerType': 'Adult',
#          'checkInBaggage': {'weight': 23,
#           'unit': 'N',
#           'piece': 1,
#           'size': None,
#           'sizeType': None,
#           'text': '每人1件，每件23公斤。'},
#          'carryOnBaggage': {'weight': 7,
#           'unit': 'N',
#           'piece': 1,
#           'size': None,
#           'sizeType': None,
#           'text': '每人1件，每件7公斤，長寬高不可超過56*36*23公分。'},
#          'route': None}],
#        'penaltyFormat': None,
#        'baggageTag': '行李每成人1*23KG',
#        'penaltyFlag': 2,
#        'penaltyTag': '退票罰金另詢',
#        'FarePenaltiesFlag': 2,
#        'Penalties': None,
#        'Baggages': [{'Segment': '台北-香港', 'Text': '每人1件，每件23公斤。'},
#         {'Segment': '香港-大阪', 'Text': '每人1件，每件23公斤。'},
#         {'Segment': '大阪-香港', 'Text': '每人1件，每件23公斤。'},
#         {'Segment': '香港-台北', 'Text': '每人1件，每件23公斤。'}],
#        'NationDisallowed': '',
#        'NationAllowed': '',
#        'CityAllowed': '',
#        'Remark': None},
#       'easeTag': None,
#       'ticketType': 'ADULT',
#       'license': None}],
#     'flightDetails': [{'departureFullDate': '20230605',
#       'departureDate': '6月5日',
#       'arrivalDate': '6月5日',
#       'goDate': '2023-06-05',
#       'departureTime': '21:15',
#       'toDate': '2023-06-05',
#       'arrivalTime': '23:05',
#       'isRedEye': False,
#       'durationMinutes': 110,
#       'transferStayMinutes': 675,
#       'departureCity': 'TPE',
#       'departureCityCode': 'TPE',
#       'departureCityName': '台北',
#       'arrivalCity': 'HKG',
#       'arrivalCityCode': 'HKG',
#       'arrivalCityName': '香港',
#       'airlineCode': 'CX',
#       'airline': '國泰航空',
#       'flightNo': 'CX479',
#       'operatingAirlineCode': None,
#       'operatingAirline': None,
#       'operatingFlightNo': None,
#       'craft': {'craftType': '351',
#        'enName': None,
#        'widthLevel': None,
#        'minSeats': 350,
#        'maxSeats': 550,
#        'craftName': '空中巴士 A350-1000'},
#       'transitType': 1,
#       'departureAirportCode': 'TPE',
#       'departureAirportName': '桃園國際機場',
#       'departureTerminal': 'T1',
#       'arrivalAirportCode': 'HKG',
#       'arrivalAirportName': '香港國際機場',
#       'arrivalTerminal': 'T1',
#       'cabinType': 'tourist',
#       'cabinDesc': '經濟艙',
#       'bookingClass': 'S',
#       'crossDays': 0,
#       'stopList': [],
#       'transfer': {'isCrossday': True,
#        'isChangeAirport': False,
#        'isChangeTerminal': False,
#        'TransitType': 1,
#        'TransferCity': '香港',
#        'TransferSpan': '11h15m'},
#       'seqNo': 1,
#       'segmentNo': 1,
#       'sequenceNo': 1,
#       'baggageStraight': 0,
#       'dterminal': 'T1',
#       'dport': 'TPE',
#       'aterminal': 'T1',
#       'aport': 'HKG'},
#      {'departureFullDate': '20230606',
#       'departureDate': '6月6日',
#       'arrivalDate': '6月6日',
#       'goDate': '2023-06-06',
#       'departureTime': '10:20',
#       'toDate': '2023-06-06',
#       'arrivalTime': '15:15',
#       'isRedEye': False,
#       'durationMinutes': 235,
#       'transferStayMinutes': None,
#       'departureCity': 'HKG',
#       'departureCityCode': 'HKG',
#       'departureCityName': '香港',
#       'arrivalCity': 'OSA',
#       'arrivalCityCode': 'OSA',
#       'arrivalCityName': '大阪',
#       'airlineCode': 'CX',
#       'airline': '國泰航空',
#       'flightNo': 'CX506',
#       'operatingAirlineCode': None,
#       'operatingAirline': None,
#       'operatingFlightNo': None,
#       'craft': {'craftType': '77W',
#        'enName': None,
#        'widthLevel': None,
#        'minSeats': 339,
#        'maxSeats': 378,
#        'craftName': '波音777'},
#       'transitType': 0,
#       'departureAirportCode': 'HKG',
#       'departureAirportName': '香港國際機場',
#       'departureTerminal': 'T1',
#       'arrivalAirportCode': 'KIX',
#       'arrivalAirportName': '關西機場',
#       'arrivalTerminal': 'T1',
#       'cabinType': 'tourist',
#       'cabinDesc': '經濟艙',
#       'bookingClass': 'S',
#       'crossDays': 0,
#       'stopList': [],
#       'transfer': None,
#       'seqNo': 2,
#       'segmentNo': 1,
#       'sequenceNo': 2,
#       'baggageStraight': 0,
#       'dterminal': 'T1',
#       'dport': 'HKG',
#       'aterminal': 'T1',
#       'aport': 'KIX'}],
#     'stuTicketGrp': True},
#    {'flightKey': 'NH854NH985',
#     'departureDate': '6月5日',
#     'departureTime': '16:50',
#     'arrivalDate': '6月6日',
#     'arrivalTime': '07:30',
#     'crossDays': 1,
#     'departureCityCode': 'TPE',
#     'arrivalCityCode': 'OSA',
#     'departureCityName': '台北',
#     'arrivalCityName': '大阪',
#     'departureAirportCode': 'TSA',
#     'departureAirportName': '松山機場',
#     'arrivalAirportCode': 'ITM',
#     'arrivalAirportName': '大阪伊丹機場',
#     'departureTerminal': 'T1',
#     'arrivalTerminal': None,
#     'stopType': 1,
#     'transit': {'isCrossday': True,
#      'isChangeAirport': False,
#      'isChangeTerminal': True,
#      'TransitType': 1,
#      'TransferCity': '東京',
#      'TransferSpan': '9h35m'},
#     'airlineName': '全日空航空',
#     'airlineFlitername': '全日空航空',
#     'airlineCode': 'NH',
#     'validatingAirlineCode': 'NH',
#     'seats': [{'seatCount': 4,
#       'seatType': 'EzTravel',
#       'feeConfirm': True,
#       'currencyCode': 'TWD',
#       'price': 23490,
#       'averagePrice': 23490,
#       'averagePriceNoTax': 17459,
#       'priceWithoutTax': 17459,
#       'priceWithTax': 23490,
#       'adultPrice': 17459,
#       'adultCnt': 1,
#       'adultTax': 6031,
#       'childPrice': 0,
#       'childTax': 0,
#       'childCnt': 0,
#       'infantPrice': 0,
#       'infantTax': 0,
#       'infantCnt': 0,
#       'selectedFlightParas': '{"OutBoundToken":"114bc7416c6769ed","RouteSearchToken":"fd0d5130-14b8-4ec1-aa17-2000e438609f|74|44:15"}',
#       'selectedFlightInfo': '{"Airline":{"Code":"NH","Name":"全日空航空"},"ArrivalAirport":{"Code":"ITM","Name":"大阪伊丹機場","change":false,"country":"JP"},"ArrivalDate":1686007800000,"DepartureAirport":{"Code":"TSA","Name":"松山機場","Terminal":"T1","change":false,"country":"TW"},"DepartureDate":1685955000000,"FlightNo":"NH854 NH985","FromAirport":"松山機場","GoTime":"2023年06月05日 16:50","ToAirport":"大阪伊丹機場","ToTime":"2023年06月06日 07:30","TransitDesc":"1程中轉"}',
#       'displayCategory': 99,
#       'classType': '經濟艙',
#       'allClassType': None,
#       'engineType': 'Abacus',
#       'remarkId': 'fd0d5130-14b8-4ec1-aa17-2000e438609f|74|44:15',
#       'fareInfo': None,
#       'planCategory': 'EZTRAVEL',
#       'resourceName': '易遊優選',
#       'resourceDesc': '享快速出票+線上更改/退票申請服務',
#       'freeBaggage': 3,
#       'productDesc': '',
#       'ticketingDesc': '付款後5分鐘出票',
#       'ticketingCode': 1,
#       'ageRestriction': '',
#       'passportTag': '',
#       'companionFare': None,
#       'combineTag': None,
#       'FarePenaltiesFlag': 2,
#       'FarePenalties': {'baggageFormats': [{'segmentNo': 1,
#          'sequenceNo': 1,
#          'fromCity': {'code': 'TPE',
#           'country': None,
#           'lineType': None,
#           'Name': '台北'},
#          'toCity': {'code': 'TYO',
#           'country': None,
#           'lineType': None,
#           'Name': '東京'},
#          'passengerType': 'Adult',
#          'checkInBaggage': {'weight': 23,
#           'unit': 'N',
#           'piece': 2,
#           'size': None,
#           'sizeType': None,
#           'text': '每人2件，每件23公斤。'},
#          'carryOnBaggage': {'weight': 10,
#           'unit': 'N',
#           'piece': 1,
#           'size': None,
#           'sizeType': None,
#           'text': '每人1件，每件10公斤，長寬高總和不可超過115公分。'},
#          'route': None},
#         {'segmentNo': 1,
#          'sequenceNo': 2,
#          'fromCity': {'code': 'TYO',
#           'country': None,
#           'lineType': None,
#           'Name': '東京'},
#          'toCity': {'code': 'OSA',
#           'country': None,
#           'lineType': None,
#           'Name': '大阪'},
#          'passengerType': 'Adult',
#          'checkInBaggage': {'weight': 23,
#           'unit': 'N',
#           'piece': 2,
#           'size': None,
#           'sizeType': None,
#           'text': '每人2件，每件23公斤。'},
#          'carryOnBaggage': {'weight': 10,
#           'unit': 'N',
#           'piece': 1,
#           'size': None,
#           'sizeType': None,
#           'text': '每人1件，每件10公斤，長寬高總和不可超過115公分。'},
#          'route': None},
#         {'segmentNo': 2,
#          'sequenceNo': 1,
#          'fromCity': {'code': 'OSA',
#           'country': None,
#           'lineType': None,
#           'Name': '大阪'},
#          'toCity': {'code': 'TPE',
#           'country': None,
#           'lineType': None,
#           'Name': '台北'},
#          'passengerType': 'Adult',
#          'checkInBaggage': {'weight': 23,
#           'unit': 'N',
#           'piece': 2,
#           'size': None,
#           'sizeType': None,
#           'text': '每人2件，每件23公斤。'},
#          'carryOnBaggage': {'weight': 7,
#           'unit': 'N',
#           'piece': 1,
#           'size': None,
#           'sizeType': None,
#           'text': '每人1件，每件7公斤，長寬高不可超過56*36*23公分。'},
#          'route': None}],
#        'penaltyFormat': None,
#        'baggageTag': '行李每成人2*23KG',
#        'penaltyFlag': 2,
#        'penaltyTag': '退票罰金另詢',
#        'FarePenaltiesFlag': 2,
#        'Penalties': None,
#        'Baggages': [{'Segment': '台北-東京', 'Text': '每人2件，每件23公斤。'},
#         {'Segment': '東京-大阪', 'Text': '每人2件，每件23公斤。'},
#         {'Segment': '大阪-台北', 'Text': '每人2件，每件23公斤。'}],
#        'NationDisallowed': '',
#        'NationAllowed': '',
#        'CityAllowed': '',
#        'Remark': None},
#       'easeTag': None,
#       'ticketType': 'ADULT',
#       'license': None}],
#     'flightDetails': [{'departureFullDate': '20230605',
#       'departureDate': '6月5日',
#       'arrivalDate': '6月5日',
#       'goDate': '2023-06-05',
#       'departureTime': '16:50',
#       'toDate': '2023-06-05',
#       'arrivalTime': '20:50',
#       'isRedEye': False,
#       'durationMinutes': 180,
#       'transferStayMinutes': 575,
#       'departureCity': 'TPE',
#       'departureCityCode': 'TPE',
#       'departureCityName': '台北',
#       'arrivalCity': 'TYO',
#       'arrivalCityCode': 'TYO',
#       'arrivalCityName': '東京',
#       'airlineCode': 'NH',
#       'airline': '全日空航空',
#       'flightNo': 'NH854',
#       'operatingAirlineCode': None,
#       'operatingAirline': None,
#       'operatingFlightNo': None,
#       'craft': {'craftType': '788',
#        'enName': None,
#        'widthLevel': None,
#        'minSeats': 210,
#        'maxSeats': 250,
#        'craftName': '波音 787-8'},
#       'transitType': 1,
#       'departureAirportCode': 'TSA',
#       'departureAirportName': '松山機場',
#       'departureTerminal': 'T1',
#       'arrivalAirportCode': 'HND',
#       'arrivalAirportName': '東京羽田機場',
#       'arrivalTerminal': 'T3',
#       'cabinType': 'tourist',
#       'cabinDesc': '經濟艙',
#       'bookingClass': 'Q',
#       'crossDays': 0,
#       'stopList': [],
#       'transfer': {'isCrossday': True,
#        'isChangeAirport': False,
#        'isChangeTerminal': True,
#        'TransitType': 1,
#        'TransferCity': '東京',
#        'TransferSpan': '9h35m'},
#       'seqNo': 1,
#       'segmentNo': 1,
#       'sequenceNo': 1,
#       'baggageStraight': 0,
#       'dterminal': 'T1',
#       'dport': 'TSA',
#       'aterminal': 'T3',
#       'aport': 'HND'},
#      {'departureFullDate': '20230606',
#       'departureDate': '6月6日',
#       'arrivalDate': '6月6日',
#       'goDate': '2023-06-06',
#       'departureTime': '06:25',
#       'toDate': '2023-06-06',
#       'arrivalTime': '07:30',
#       'isRedEye': False,
#       'durationMinutes': 65,
#       'transferStayMinutes': None,
#       'departureCity': 'TYO',
#       'departureCityCode': 'TYO',
#       'departureCityName': '東京',
#       'arrivalCity': 'OSA',
#       'arrivalCityCode': 'OSA',
#       'arrivalCityName': '大阪',
#       'airlineCode': 'NH',
#       'airline': '全日空航空',
#       'flightNo': 'NH985',
#       'operatingAirlineCode': None,
#       'operatingAirline': None,
#       'operatingFlightNo': None,
#       'craft': {'craftType': '772',
#        'enName': None,
#        'widthLevel': None,
#        'minSeats': 281,
#        'maxSeats': 440,
#        'craftName': '波音 777-200'},
#       'transitType': 0,
#       'departureAirportCode': 'HND',
#       'departureAirportName': '東京羽田機場',
#       'departureTerminal': 'T2',
#       'arrivalAirportCode': 'ITM',
#       'arrivalAirportName': '大阪伊丹機場',
#       'arrivalTerminal': None,
#       'cabinType': 'tourist',
#       'cabinDesc': '經濟艙',
#       'bookingClass': 'Q',
#       'crossDays': 0,
#       'stopList': [],
#       'transfer': None,
#       'seqNo': 2,
#       'segmentNo': 1,
#       'sequenceNo': 2,
#       'baggageStraight': 0,
#       'dterminal': 'T2',
#       'dport': 'HND',
#       'aterminal': None,
#       'aport': 'ITM'}],
#     'stuTicketGrp': False},
#    {'flightKey': 'MM030',
#     'departureDate': '6月5日',
#     'departureTime': '02:15',
#     'arrivalDate': '6月5日',
#     'arrivalTime': '06:00',
#     'crossDays': 0,
#     'departureCityCode': 'TPE',
#     'arrivalCityCode': 'OSA',
#     'departureCityName': '台北',
#     'arrivalCityName': '大阪',
#     'departureAirportCode': 'TPE',
#     'departureAirportName': '桃園國際機場',
#     'arrivalAirportCode': 'KIX',
#     'arrivalAirportName': '關西機場',
#     'departureTerminal': 'T1',
#     'arrivalTerminal': 'T2',
#     'stopType': 0,
#     'transit': {'TransitType': 0},
#     'airlineName': '樂桃航空',
#     'airlineFlitername': '樂桃航空',
#     'airlineCode': 'MM',
#     'validatingAirlineCode': 'MM',
#     'seats': [{'seatCount': 9,
#       'seatType': 'EzTravel',
#       'feeConfirm': True,
#       'currencyCode': 'TWD',
#       'price': 12727,
#       'averagePrice': 12727,
#       'averagePriceNoTax': 12023,
#       'priceWithoutTax': 12023,
#       'priceWithTax': 12727,
#       'adultPrice': 12023,
#       'adultCnt': 1,
#       'adultTax': 704,
#       'childPrice': 0,
#       'childTax': 0,
#       'childCnt': 0,
#       'infantPrice': 0,
#       'infantTax': 0,
#       'infantCnt': 0,
#       'selectedFlightParas': '{"OutBoundToken":"42cffda40135e4c5","RouteSearchToken":"fd0d5130-14b8-4ec1-aa17-2000e438609f|1|47:43"}',
#       'selectedFlightInfo': '{"Airline":{"Code":"MM","Name":"樂桃航空"},"ArrivalAirport":{"Code":"KIX","Name":"關西機場","Terminal":"T2","change":false,"country":"JP"},"ArrivalDate":1685916000000,"DepartureAirport":{"Code":"TPE","Name":"桃園國際機場","Terminal":"T1","change":false,"country":"TW"},"DepartureDate":1685902500000,"FlightNo":"MM030","FromAirport":"桃園國際機場","GoTime":"2023年06月05日 02:15","ToAirport":"關西機場","ToTime":"2023年06月05日 06:00","TransitDesc":"直飛"}',
#       'displayCategory': 99,
#       'classType': '經濟艙',
#       'allClassType': None,
#       'engineType': 'TravelFusion',
#       'remarkId': 'fd0d5130-14b8-4ec1-aa17-2000e438609f|1|47:43',
#       'fareInfo': None,
#       'planCategory': 'EZTRAVEL',
#       'resourceName': '易遊優選',
#       'resourceDesc': '享快速出票+線上更改/退票申請服務',
#       'freeBaggage': 1,
#       'productDesc': '',
#       'ticketingDesc': '付款後1小時出票',
#       'ticketingCode': 1,
#       'ageRestriction': '',
#       'passportTag': '',
#       'companionFare': None,
#       'combineTag': '由二至多張機票組成',
#       'FarePenaltiesFlag': 2,
#       'FarePenalties': {'baggageFormats': [{'segmentNo': 1,
#          'sequenceNo': 1,
#          'fromCity': {'code': 'TPE',
#           'country': None,
#           'lineType': None,
#           'Name': '台北'},
#          'toCity': {'code': 'OSA',
#           'country': None,
#           'lineType': None,
#           'Name': '大阪'},
#          'passengerType': 'Adult',
#          'checkInBaggage': {'weight': 0,
#           'unit': 'K',
#           'piece': 0,
#           'size': None,
#           'sizeType': None,
#           'text': '無免費託運行李。'},
#          'carryOnBaggage': {'weight': 7,
#           'unit': 'N',
#           'piece': 1,
#           'size': None,
#           'sizeType': None,
#           'text': '每人1件，每件7公斤，長寬高不可超過50*40*25公分。'},
#          'route': None},
#         {'segmentNo': 2,
#          'sequenceNo': 1,
#          'fromCity': {'code': 'OSA',
#           'country': None,
#           'lineType': None,
#           'Name': '大阪'},
#          'toCity': {'code': 'TPE',
#           'country': None,
#           'lineType': None,
#           'Name': '台北'},
#          'passengerType': 'Adult',
#          'checkInBaggage': {'weight': 0,
#           'unit': 'K',
#           'piece': 0,
#           'size': None,
#           'sizeType': None,
#           'text': '無免費託運行李。'},
#          'carryOnBaggage': {'weight': 10,
#           'unit': 'N',
#           'piece': 1,
#           'size': None,
#           'sizeType': None,
#           'text': '每人1件，每件10公斤，長寬高不可超過54*38*23公分。'},
#          'route': None}],
#        'penaltyFormat': None,
#        'baggageTag': '無免費託運行李',
#        'penaltyFlag': 1,
#        'penaltyTag': '不可退票',
#        'FarePenaltiesFlag': 2,
#        'Penalties': None,
#        'Baggages': [{'Segment': '台北-大阪', 'Text': '無免費託運行李。'},
#         {'Segment': '大阪-台北', 'Text': '無免費託運行李。'}],
#        'NationDisallowed': '',
#        'NationAllowed': '',
#        'CityAllowed': '',
#        'Remark': None},
#       'easeTag': None,
#       'ticketType': None,
#       'license': None}],
#     'flightDetails': [{'departureFullDate': '20230605',
#       'departureDate': '6月5日',
#       'arrivalDate': '6月5日',
#       'goDate': '2023-06-05',
#       'departureTime': '02:15',
#       'toDate': '2023-06-05',
#       'arrivalTime': '06:00',
#       'isRedEye': True,
#       'durationMinutes': 165,
#       'transferStayMinutes': None,
#       'departureCity': 'TPE',
#       'departureCityCode': 'TPE',
#       'departureCityName': '台北',
#       'arrivalCity': 'OSA',
#       'arrivalCityCode': 'OSA',
#       'arrivalCityName': '大阪',
#       'airlineCode': 'MM',
#       'airline': '樂桃航空',
#       'flightNo': 'MM030',
#       'operatingAirlineCode': None,
#       'operatingAirline': None,
#       'operatingFlightNo': None,
#       'craft': {'craftType': None,
#        'enName': None,
#        'widthLevel': None,
#        'minSeats': None,
#        'maxSeats': None,
#        'craftName': None},
#       'transitType': 0,
#       'departureAirportCode': 'TPE',
#       'departureAirportName': '桃園國際機場',
#       'departureTerminal': 'T1',
#       'arrivalAirportCode': 'KIX',
#       'arrivalAirportName': '關西機場',
#       'arrivalTerminal': 'T2',
#       'cabinType': 'tourist',
#       'cabinDesc': '經濟艙',
#       'bookingClass': 'M',
#       'crossDays': 0,
#       'stopList': [],
#       'transfer': None,
#       'seqNo': 1,
#       'segmentNo': 1,
#       'sequenceNo': 1,
#       'baggageStraight': 0,
#       'dterminal': 'T1',
#       'dport': 'TPE',
#       'aterminal': 'T2',
#       'aport': 'KIX'}],
#     'stuTicketGrp': False},
#    {'flightKey': 'NH852NH099',
#     'departureDate': '6月5日',
#     'departureTime': '13:35',
#     'arrivalDate': '6月5日',
#     'arrivalTime': '22:20',
#     'crossDays': 0,
#     'departureCityCode': 'TPE',
#     'arrivalCityCode': 'OSA',
#     'departureCityName': '台北',
#     'arrivalCityName': '大阪',
#     'departureAirportCode': 'TSA',
#     'departureAirportName': '松山機場',
#     'arrivalAirportCode': 'KIX',
#     'arrivalAirportName': '關西機場',
#     'departureTerminal': 'T1',
#     'arrivalTerminal': 'T1',
#     'stopType': 1,
#     'transit': {'isCrossday': False,
#      'isChangeAirport': False,
#      'isChangeTerminal': True,
#      'TransitType': 1,
#      'TransferCity': '東京',
#      'TransferSpan': '3h15m'},
#     'airlineName': '全日空航空',
#     'airlineFlitername': '全日空航空',
#     'airlineCode': 'NH',
#     'validatingAirlineCode': 'NH',
#     'seats': [{'seatCount': 4,
#       'seatType': 'EzTravel',
#       'feeConfirm': True,
#       'currencyCode': 'TWD',
#       'price': 22431,
#       'averagePrice': 22431,
#       'averagePriceNoTax': 16377,
#       'priceWithoutTax': 16377,
#       'priceWithTax': 22431,
#       'adultPrice': 16377,
#       'adultCnt': 1,
#       'adultTax': 6054,
#       'childPrice': 0,
#       'childTax': 0,
#       'childCnt': 0,
#       'infantPrice': 0,
#       'infantTax': 0,
#       'infantCnt': 0,
#       'selectedFlightParas': '{"OutBoundToken":"d663b0fb42756bf6","RouteSearchToken":"fd0d5130-14b8-4ec1-aa17-2000e438609f|67|39:15"}',
#       'selectedFlightInfo': '{"Airline":{"Code":"NH","Name":"全日空航空"},"ArrivalAirport":{"Code":"KIX","Name":"關西機場","Terminal":"T1","change":false,"country":"JP"},"ArrivalDate":1685974800000,"DepartureAirport":{"Code":"TSA","Name":"松山機場","Terminal":"T1","change":false,"country":"TW"},"DepartureDate":1685943300000,"FlightNo":"NH852 NH099","FromAirport":"松山機場","GoTime":"2023年06月05日 13:35","ToAirport":"關西機場","ToTime":"2023年06月05日 22:20","TransitDesc":"1程中轉"}',
#       'displayCategory': 99,
#       'classType': '經濟艙',
#       'allClassType': None,
#       'engineType': 'Abacus',
#       'remarkId': 'fd0d5130-14b8-4ec1-aa17-2000e438609f|67|39:15',
#       'fareInfo': None,
#       'planCategory': 'EZTRAVEL',
#       'resourceName': '易遊優選',
#       'resourceDesc': '享快速出票+線上更改/退票申請服務',
#       'freeBaggage': 3,
#       'productDesc': '',
#       'ticketingDesc': '付款後5分鐘出票',
#       'ticketingCode': 1,
#       'ageRestriction': '',
#       'passportTag': '',
#       'companionFare': None,
#       'combineTag': None,
#       'FarePenaltiesFlag': 2,
#       'FarePenalties': {'baggageFormats': [{'segmentNo': 1,
#          'sequenceNo': 1,
#          'fromCity': {'code': 'TPE',
#           'country': None,
#           'lineType': None,
#           'Name': '台北'},
#          'toCity': {'code': 'TYO',
#           'country': None,
#           'lineType': None,
#           'Name': '東京'},
#          'passengerType': 'Adult',
#          'checkInBaggage': {'weight': 23,
#           'unit': 'N',
#           'piece': 2,
#           'size': None,
#           'sizeType': None,
#           'text': '每人2件，每件23公斤。'},
#          'carryOnBaggage': {'weight': 10,
#           'unit': 'N',
#           'piece': 1,
#           'size': None,
#           'sizeType': None,
#           'text': '每人1件，每件10公斤，長寬高總和不可超過115公分。'},
#          'route': None},
#         {'segmentNo': 1,
#          'sequenceNo': 2,
#          'fromCity': {'code': 'TYO',
#           'country': None,
#           'lineType': None,
#           'Name': '東京'},
#          'toCity': {'code': 'OSA',
#           'country': None,
#           'lineType': None,
#           'Name': '大阪'},
#          'passengerType': 'Adult',
#          'checkInBaggage': {'weight': 23,
#           'unit': 'N',
#           'piece': 2,
#           'size': None,
#           'sizeType': None,
#           'text': '每人2件，每件23公斤。'},
#          'carryOnBaggage': {'weight': 10,
#           'unit': 'N',
#           'piece': 1,
#           'size': None,
#           'sizeType': None,
#           'text': '每人1件，每件10公斤，長寬高總和不可超過115公分。'},
#          'route': None},
#         {'segmentNo': 2,
#          'sequenceNo': 1,
#          'fromCity': {'code': 'OSA',
#           'country': None,
#           'lineType': None,
#           'Name': '大阪'},
#          'toCity': {'code': 'TPE',
#           'country': None,
#           'lineType': None,
#           'Name': '台北'},
#          'passengerType': 'Adult',
#          'checkInBaggage': {'weight': 23,
#           'unit': 'N',
#           'piece': 2,
#           'size': None,
#           'sizeType': None,
#           'text': '每人2件，每件23公斤。'},
#          'carryOnBaggage': {'weight': 7,
#           'unit': 'N',
#           'piece': 1,
#           'size': None,
#           'sizeType': None,
#           'text': '每人1件，每件7公斤，長寬高不可超過56*36*23公分。'},
#          'route': None}],
#        'penaltyFormat': None,
#        'baggageTag': '行李每成人2*23KG',
#        'penaltyFlag': 2,
#        'penaltyTag': '退票罰金另詢',
#        'FarePenaltiesFlag': 2,
#        'Penalties': None,
#        'Baggages': [{'Segment': '台北-東京', 'Text': '每人2件，每件23公斤。'},
#         {'Segment': '東京-大阪', 'Text': '每人2件，每件23公斤。'},
#         {'Segment': '大阪-台北', 'Text': '每人2件，每件23公斤。'}],
#        'NationDisallowed': '',
#        'NationAllowed': '',
#        'CityAllowed': '',
#        'Remark': None},
#       'easeTag': None,
#       'ticketType': 'ADULT',
#       'license': None}],
#     'flightDetails': [{'departureFullDate': '20230605',
#       'departureDate': '6月5日',
#       'arrivalDate': '6月5日',
#       'goDate': '2023-06-05',
#       'departureTime': '13:35',
#       'toDate': '2023-06-05',
#       'arrivalTime': '17:45',
#       'isRedEye': False,
#       'durationMinutes': 190,
#       'transferStayMinutes': 195,
#       'departureCity': 'TPE',
#       'departureCityCode': 'TPE',
#       'departureCityName': '台北',
#       'arrivalCity': 'TYO',
#       'arrivalCityCode': 'TYO',
#       'arrivalCityName': '東京',
#       'airlineCode': 'NH',
#       'airline': '全日空航空',
#       'flightNo': 'NH852',
#       'operatingAirlineCode': None,
#       'operatingAirline': None,
#       'operatingFlightNo': None,
#       'craft': {'craftType': '788',
#        'enName': None,
#        'widthLevel': None,
#        'minSeats': 210,
#        'maxSeats': 250,
#        'craftName': '波音 787-8'},
#       'transitType': 1,
#       'departureAirportCode': 'TSA',
#       'departureAirportName': '松山機場',
#       'departureTerminal': 'T1',
#       'arrivalAirportCode': 'HND',
#       'arrivalAirportName': '東京羽田機場',
#       'arrivalTerminal': 'T3',
#       'cabinType': 'tourist',
#       'cabinDesc': '經濟艙',
#       'bookingClass': 'V',
#       'crossDays': 0,
#       'stopList': [],
#       'transfer': {'isCrossday': False,
#        'isChangeAirport': False,
#        'isChangeTerminal': True,
#        'TransitType': 1,
#        'TransferCity': '東京',
#        'TransferSpan': '3h15m'},
#       'seqNo': 1,
#       'segmentNo': 1,
#       'sequenceNo': 1,
#       'baggageStraight': 0,
#       'dterminal': 'T1',
#       'dport': 'TSA',
#       'aterminal': 'T3',
#       'aport': 'HND'},
#      {'departureFullDate': '20230605',
#       'departureDate': '6月5日',
#       'arrivalDate': '6月5日',
#       'goDate': '2023-06-05',
#       'departureTime': '21:00',
#       'toDate': '2023-06-05',
#       'arrivalTime': '22:20',
#       'isRedEye': False,
#       'durationMinutes': 80,
#       'transferStayMinutes': None,
#       'departureCity': 'TYO',
#       'departureCityCode': 'TYO',
#       'departureCityName': '東京',
#       'arrivalCity': 'OSA',
#       'arrivalCityCode': 'OSA',
#       'arrivalCityName': '大阪',
#       'airlineCode': 'NH',
#       'airline': '全日空航空',
#       'flightNo': 'NH099',
#       'operatingAirlineCode': None,
#       'operatingAirline': None,
#       'operatingFlightNo': None,
#       'craft': {'craftType': '787',
#        'enName': None,
#        'widthLevel': None,
#        'minSeats': 210,
#        'maxSeats': 330,
#        'craftName': '波音 787'},
#       'transitType': 0,
#       'departureAirportCode': 'HND',
#       'departureAirportName': '東京羽田機場',
#       'departureTerminal': 'T2',
#       'arrivalAirportCode': 'KIX',
#       'arrivalAirportName': '關西機場',
#       'arrivalTerminal': 'T1',
#       'cabinType': 'tourist',
#       'cabinDesc': '經濟艙',
#       'bookingClass': 'V',
#       'crossDays': 0,
#       'stopList': [],
#       'transfer': None,
#       'seqNo': 2,
#       'segmentNo': 1,
#       'sequenceNo': 2,
#       'baggageStraight': 0,
#       'dterminal': 'T2',
#       'dport': 'HND',
#       'aterminal': 'T1',
#       'aport': 'KIX'}],
#     'stuTicketGrp': False},
#    {'flightKey': 'VN3587VN330',
#     'departureDate': '6月5日',
#     'departureTime': '14:40',
#     'arrivalDate': '6月6日',
#     'arrivalTime': '06:40',
#     'crossDays': 1,
#     'departureCityCode': 'TPE',
#     'arrivalCityCode': 'OSA',
#     'departureCityName': '台北',
#     'arrivalCityName': '大阪',
#     'departureAirportCode': 'TPE',
#     'departureAirportName': '桃園國際機場',
#     'arrivalAirportCode': 'KIX',
#     'arrivalAirportName': '關西機場',
#     'departureTerminal': 'T1',
#     'arrivalTerminal': 'T1',
#     'stopType': 1,
#     'transit': {'isCrossday': True,
#      'isChangeAirport': False,
#      'isChangeTerminal': False,
#      'TransitType': 1,
#      'TransferCity': '河內',
#      'TransferSpan': '7h40m'},
#     'airlineName': '越南航空',
#     'airlineFlitername': '越南航空',
#     'airlineCode': 'VN',
#     'validatingAirlineCode': 'VN',
#     'seats': [{'seatCount': 3,
#       'seatType': 'EzTravel',
#       'feeConfirm': True,
#       'currencyCode': 'TWD',
#       'price': 30836,
#       'averagePrice': 30836,
#       'averagePriceNoTax': 21830,
#       'priceWithoutTax': 21830,
#       'priceWithTax': 30836,
#       'adultPrice': 21830,
#       'adultCnt': 1,
#       'adultTax': 9006,
#       'childPrice': 0,
#       'childTax': 0,
#       'childCnt': 0,
#       'infantPrice': 0,
#       'infantTax': 0,
#       'infantCnt': 0,
#       'selectedFlightParas': '{"OutBoundToken":"105899e893287ec2","RouteSearchToken":"fd0d5130-14b8-4ec1-aa17-2000e438609f|90|46:40"}',
#       'selectedFlightInfo': '{"Airline":{"Code":"VN","Name":"越南航空"},"ArrivalAirport":{"Code":"KIX","Name":"關西機場","Terminal":"T1","change":false,"country":"JP"},"ArrivalDate":1686004800000,"DepartureAirport":{"Code":"TPE","Name":"桃園國際機場","Terminal":"T1","change":false,"country":"TW"},"DepartureDate":1685947200000,"FlightNo":"VN3587 VN330","FromAirport":"桃園國際機場","GoTime":"2023年06月05日 14:40","ToAirport":"關西機場","ToTime":"2023年06月06日 06:40","TransitDesc":"1程中轉"}',
#       'displayCategory': 99,
#       'classType': '經濟艙',
#       'allClassType': None,
#       'engineType': 'Abacus',
#       'remarkId': 'fd0d5130-14b8-4ec1-aa17-2000e438609f|90|46:40',
#       'fareInfo': None,
#       'planCategory': 'EZTRAVEL',
#       'resourceName': '易遊優選',
#       'resourceDesc': '享快速出票+線上更改/退票申請服務',
#       'freeBaggage': 3,
#       'productDesc': '',
#       'ticketingDesc': '付款後5分鐘出票',
#       'ticketingCode': 1,
#       'ageRestriction': '',
#       'passportTag': '',
#       'companionFare': None,
#       'combineTag': None,
#       'FarePenaltiesFlag': 2,
#       'FarePenalties': {'baggageFormats': [{'segmentNo': 1,
#          'sequenceNo': 1,
#          'fromCity': {'code': 'TPE',
#           'country': None,
#           'lineType': None,
#           'Name': '台北'},
#          'toCity': {'code': 'HAN',
#           'country': None,
#           'lineType': None,
#           'Name': '河內'},
#          'passengerType': 'Adult',
#          'checkInBaggage': {'weight': 23,
#           'unit': 'N',
#           'piece': 1,
#           'size': None,
#           'sizeType': None,
#           'text': '每人1件，每件23公斤。'},
#          'carryOnBaggage': {'weight': 7,
#           'unit': 'N',
#           'piece': 1,
#           'size': None,
#           'sizeType': None,
#           'text': '每人1件，每件7公斤，長寬高不可超過56*36*23公分。'},
#          'route': None},
#         {'segmentNo': 1,
#          'sequenceNo': 2,
#          'fromCity': {'code': 'HAN',
#           'country': None,
#           'lineType': None,
#           'Name': '河內'},
#          'toCity': {'code': 'OSA',
#           'country': None,
#           'lineType': None,
#           'Name': '大阪'},
#          'passengerType': 'Adult',
#          'checkInBaggage': {'weight': 23,
#           'unit': 'N',
#           'piece': 1,
#           'size': None,
#           'sizeType': None,
#           'text': '每人1件，每件23公斤。'},
#          'carryOnBaggage': {'weight': 10,
#           'unit': 'N',
#           'piece': 1,
#           'size': None,
#           'sizeType': None,
#           'text': '每人1件，每件10公斤，長寬高不可超過56*36*23公分。'},
#          'route': None},
#         {'segmentNo': 2,
#          'sequenceNo': 1,
#          'fromCity': {'code': 'OSA',
#           'country': None,
#           'lineType': None,
#           'Name': '大阪'},
#          'toCity': {'code': 'HAN',
#           'country': None,
#           'lineType': None,
#           'Name': '河內'},
#          'passengerType': 'Adult',
#          'checkInBaggage': {'weight': 23,
#           'unit': 'N',
#           'piece': 1,
#           'size': None,
#           'sizeType': None,
#           'text': '每人1件，每件23公斤。'},
#          'carryOnBaggage': {'weight': 10,
#           'unit': 'N',
#           'piece': 1,
#           'size': None,
#           'sizeType': None,
#           'text': '每人1件，每件10公斤，長寬高不可超過56*36*23公分。'},
#          'route': None},
#         {'segmentNo': 2,
#          'sequenceNo': 2,
#          'fromCity': {'code': 'HAN',
#           'country': None,
#           'lineType': None,
#           'Name': '河內'},
#          'toCity': {'code': 'TPE',
#           'country': None,
#           'lineType': None,
#           'Name': '台北'},
#          'passengerType': 'Adult',
#          'checkInBaggage': {'weight': 23,
#           'unit': 'N',
#           'piece': 1,
#           'size': None,
#           'sizeType': None,
#           'text': '每人1件，每件23公斤。'},
#          'carryOnBaggage': {'weight': 10,
#           'unit': 'N',
#           'piece': 1,
#           'size': None,
#           'sizeType': None,
#           'text': '每人1件，每件10公斤，長寬高不可超過56*36*23公分。'},
#          'route': None}],
#        'penaltyFormat': None,
#        'baggageTag': '行李每成人1*23KG',
#        'penaltyFlag': 2,
#        'penaltyTag': '退票罰金另詢',
#        'FarePenaltiesFlag': 2,
#        'Penalties': None,
#        'Baggages': [{'Segment': '台北-河內', 'Text': '每人1件，每件23公斤。'},
#         {'Segment': '河內-大阪', 'Text': '每人1件，每件23公斤。'},
#         {'Segment': '大阪-河內', 'Text': '每人1件，每件23公斤。'},
#         {'Segment': '河內-台北', 'Text': '每人1件，每件23公斤。'}],
#        'NationDisallowed': '',
#        'NationAllowed': '',
#        'CityAllowed': '',
#        'Remark': None},
#       'easeTag': None,
#       'ticketType': 'ADULT',
#       'license': None}],
#     'flightDetails': [{'departureFullDate': '20230605',
#       'departureDate': '6月5日',
#       'arrivalDate': '6月5日',
#       'goDate': '2023-06-05',
#       'departureTime': '14:40',
#       'toDate': '2023-06-05',
#       'arrivalTime': '16:50',
#       'isRedEye': False,
#       'durationMinutes': 190,
#       'transferStayMinutes': 460,
#       'departureCity': 'TPE',
#       'departureCityCode': 'TPE',
#       'departureCityName': '台北',
#       'arrivalCity': 'HAN',
#       'arrivalCityCode': 'HAN',
#       'arrivalCityName': '河內',
#       'airlineCode': 'VN',
#       'airline': '越南航空',
#       'flightNo': 'VN3587',
#       'operatingAirlineCode': 'CI',
#       'operatingAirline': '中華航空',
#       'operatingFlightNo': None,
#       'craft': {'craftType': '32Q',
#        'enName': None,
#        'widthLevel': None,
#        'minSeats': None,
#        'maxSeats': None,
#        'craftName': None},
#       'transitType': 1,
#       'departureAirportCode': 'TPE',
#       'departureAirportName': '桃園國際機場',
#       'departureTerminal': 'T1',
#       'arrivalAirportCode': 'HAN',
#       'arrivalAirportName': '河內機場',
#       'arrivalTerminal': 'T2',
#       'cabinType': 'tourist',
#       'cabinDesc': '經濟艙',
#       'bookingClass': 'M',
#       'crossDays': 0,
#       'stopList': [],
#       'transfer': {'isCrossday': True,
#        'isChangeAirport': False,
#        'isChangeTerminal': False,
#        'TransitType': 1,
#        'TransferCity': '河內',
#        'TransferSpan': '7h40m'},
#       'seqNo': 1,
#       'segmentNo': 1,
#       'sequenceNo': 1,
#       'baggageStraight': 0,
#       'dterminal': 'T1',
#       'dport': 'TPE',
#       'aterminal': 'T2',
#       'aport': 'HAN'},
#      {'departureFullDate': '20230606',
#       'departureDate': '6月6日',
#       'arrivalDate': '6月6日',
#       'goDate': '2023-06-06',
#       'departureTime': '00:30',
#       'toDate': '2023-06-06',
#       'arrivalTime': '06:40',
#       'isRedEye': True,
#       'durationMinutes': 250,
#       'transferStayMinutes': None,
#       'departureCity': 'HAN',
#       'departureCityCode': 'HAN',
#       'departureCityName': '河內',
#       'arrivalCity': 'OSA',
#       'arrivalCityCode': 'OSA',
#       'arrivalCityName': '大阪',
#       'airlineCode': 'VN',
# ...
#     'arrivalAirportCode': 'KIX',
#     'arrivalAirportName': '關西機場',
#     'departureTerminal': 'T1',
#     'arrivalTerminal': 'T1',
#     'stopType': 1,
#     'transit': {'isCrossday': False,
#      'isChangeAirport': False,
#      'isChangeTerminal': False,
#      'TransitType': 1,
#      'TransferCity': '上海',
#      'TransferSpan': '2h30m'},
#     'airlineName': '中國東方航空',
#     'airlineFlitername': '中國東方航空',
#     'airlineCode': 'MU',
#     'validatingAirlineCode': 'MU',
#     'seats': [{'seatCount': 4,
#       'seatType': 'EzTravel',
#       'feeConfirm': True,
#       'currencyCode': 'TWD',
#       'price': 48770,
#       'averagePrice': 48770,
#       'averagePriceNoTax': 43364,
#       'priceWithoutTax': 43364,
#       'priceWithTax': 48770,
#       'adultPrice': 43364,
#       'adultCnt': 1,
#       'adultTax': 5406,
#       'childPrice': 0,
#       'childTax': 0,
#       'childCnt': 0,
#       'infantPrice': 0,
#       'infantTax': 0,
#       'infantCnt': 0,
#       'selectedFlightParas': '{"OutBoundToken":"18efdf64194fdb7e","RouteSearchToken":"fd0d5130-14b8-4ec1-aa17-2000e438609f|103|24:15"}',
#       'selectedFlightInfo': '{"Airline":{"Code":"MU","Name":"中國東方航空"},"ArrivalAirport":{"Code":"KIX","Name":"關西機場","Terminal":"T1","change":false,"country":"JP"},"ArrivalDate":1685967300000,"DepartureAirport":{"Code":"TPE","Name":"桃園國際機場","Terminal":"T1","change":false,"country":"TW"},"DepartureDate":1685939100000,"FlightNo":"MU3546 MU3567","FromAirport":"桃園國際機場","GoTime":"2023年06月05日 12:25","ToAirport":"關西機場","ToTime":"2023年06月05日 20:15","TransitDesc":"1程中轉"}',
#       'displayCategory': 99,
#       'classType': '經濟艙',
#       'allClassType': None,
#       'engineType': 'Amadeus',
#       'remarkId': 'fd0d5130-14b8-4ec1-aa17-2000e438609f|103|24:15',
#       'fareInfo': None,
#       'planCategory': 'EZTRAVEL',
#       'resourceName': '易遊優選',
#       'resourceDesc': '享快速出票+線上更改/退票申請服務',
#       'freeBaggage': 3,
#       'productDesc': '',
#       'ticketingDesc': '付款後5分鐘出票',
#       'ticketingCode': 1,
#       'ageRestriction': '',
#       'passportTag': '',
#       'companionFare': None,
#       'combineTag': None,
#       'FarePenaltiesFlag': 2,
#       'FarePenalties': {'baggageFormats': [{'segmentNo': 1,
#          'sequenceNo': 1,
#          'fromCity': {'code': 'TPE',
#           'country': None,
#           'lineType': None,
#           'Name': '台北'},
#          'toCity': {'code': 'SHA',
#           'country': None,
#           'lineType': None,
#           'Name': '上海'},
#          'passengerType': 'Adult',
#          'checkInBaggage': {'weight': 23,
#           'unit': 'N',
#           'piece': 2,
#           'size': None,
#           'sizeType': None,
#           'text': '每人2件，每件23公斤。'},
#          'carryOnBaggage': {'weight': None,
#           'unit': None,
#           'piece': 0,
#           'size': None,
#           'sizeType': None,
#           'text': '依航空公司規定。'},
#          'route': None},
#         {'segmentNo': 1,
#          'sequenceNo': 2,
#          'fromCity': {'code': 'SHA',
#           'country': None,
#           'lineType': None,
#           'Name': '上海'},
#          'toCity': {'code': 'OSA',
#           'country': None,
#           'lineType': None,
#           'Name': '大阪'},
#          'passengerType': 'Adult',
#          'checkInBaggage': {'weight': 23,
#           'unit': 'N',
#           'piece': 2,
#           'size': None,
#           'sizeType': None,
#           'text': '每人2件，每件23公斤。'},
#          'carryOnBaggage': {'weight': None,
#           'unit': None,
#           'piece': 0,
#           'size': None,
#           'sizeType': None,
#           'text': '依航空公司規定。'},
#          'route': None},
#         {'segmentNo': 2,
#          'sequenceNo': 1,
#          'fromCity': {'code': 'OSA',
#           'country': None,
#           'lineType': None,
#           'Name': '大阪'},
#          'toCity': {'code': 'TPE',
#           'country': None,
#           'lineType': None,
#           'Name': '台北'},
#          'passengerType': 'Adult',
#          'checkInBaggage': {'weight': 23,
#           'unit': 'N',
#           'piece': 2,
#           'size': None,
#           'sizeType': None,
#           'text': '每人2件，每件23公斤。'},
#          'carryOnBaggage': {'weight': 7,
#           'unit': 'N',
#           'piece': 1,
#           'size': None,
#           'sizeType': None,
#           'text': '每人1件，每件7公斤，長寬高不可超過56*36*23公分。'},
#          'route': None}],
#        'penaltyFormat': None,
#        'baggageTag': '行李每成人2*23KG',
#        'penaltyFlag': 2,
#        'penaltyTag': '退票罰金另詢',
#        'FarePenaltiesFlag': 2,
#        'Penalties': None,
#        'Baggages': [{'Segment': '台北-上海', 'Text': '每人2件，每件23公斤。'},
#         {'Segment': '上海-大阪', 'Text': '每人2件，每件23公斤。'},
#         {'Segment': '大阪-台北', 'Text': '每人2件，每件23公斤。'}],
#        'NationDisallowed': '',
#        'NationAllowed': '',
#        'CityAllowed': '',
#        'Remark': None},
#       'easeTag': None,
#       'ticketType': 'ADULT',
#       'license': None}],
#     'flightDetails': [{'departureFullDate': '20230605',
#       'departureDate': '6月5日',
#       'arrivalDate': '6月5日',
#       'goDate': '2023-06-05',
#       'departureTime': '12:25',
#       'toDate': '2023-06-05',
#       'arrivalTime': '14:30',
#       'isRedEye': False,
#       'durationMinutes': 125,
#       'transferStayMinutes': 150,
#       'departureCity': 'TPE',
#       'departureCityCode': 'TPE',
#       'departureCityName': '台北',
#       'arrivalCity': 'SHA',
#       'arrivalCityCode': 'SHA',
#       'arrivalCityName': '上海',
#       'airlineCode': 'MU',
#       'airline': '中國東方航空',
#       'flightNo': 'MU3546',
#       'operatingAirlineCode': 'HO',
#       'operatingAirline': '上海吉祥航空',
#       'operatingFlightNo': None,
#       'craft': {'craftType': '32S',
#        'enName': None,
#        'widthLevel': None,
#        'minSeats': 107,
#        'maxSeats': 220,
#        'craftName': '空中巴士 A319'},
#       'transitType': 1,
#       'departureAirportCode': 'TPE',
#       'departureAirportName': '桃園國際機場',
#       'departureTerminal': 'T1',
#       'arrivalAirportCode': 'PVG',
#       'arrivalAirportName': '上海浦東機場',
#       'arrivalTerminal': 'T2',
#       'cabinType': 'tourist',
#       'cabinDesc': '經濟艙',
#       'bookingClass': 'N',
#       'crossDays': 0,
#       'stopList': [],
#       'transfer': {'isCrossday': False,
#        'isChangeAirport': False,
#        'isChangeTerminal': False,
#        'TransitType': 1,
#        'TransferCity': '上海',
#        'TransferSpan': '2h30m'},
#       'seqNo': 1,
#       'segmentNo': 1,
#       'sequenceNo': 1,
#       'baggageStraight': 0,
#       'dterminal': 'T1',
#       'dport': 'TPE',
#       'aterminal': 'T2',
#       'aport': 'PVG'},
#      {'departureFullDate': '20230605',
#       'departureDate': '6月5日',
#       'arrivalDate': '6月5日',
#       'goDate': '2023-06-05',
#       'departureTime': '17:00',
#       'toDate': '2023-06-05',
#       'arrivalTime': '20:15',
#       'isRedEye': False,
#       'durationMinutes': 135,
#       'transferStayMinutes': None,
#       'departureCity': 'SHA',
#       'departureCityCode': 'SHA',
#       'departureCityName': '上海',
#       'arrivalCity': 'OSA',
#       'arrivalCityCode': 'OSA',
#       'arrivalCityName': '大阪',
#       'airlineCode': 'MU',
#       'airline': '中國東方航空',
#       'flightNo': 'MU3567',
#       'operatingAirlineCode': 'HO',
#       'operatingAirline': '上海吉祥航空',
#       'operatingFlightNo': None,
#       'craft': {'craftType': '789',
#        'enName': None,
#        'widthLevel': None,
#        'minSeats': 250,
#        'maxSeats': 290,
#        'craftName': '波音 787-9'},
#       'transitType': 0,
#       'departureAirportCode': 'PVG',
#       'departureAirportName': '上海浦東機場',
#       'departureTerminal': 'T2',
#       'arrivalAirportCode': 'KIX',
#       'arrivalAirportName': '關西機場',
#       'arrivalTerminal': 'T1',
#       'cabinType': 'tourist',
#       'cabinDesc': '經濟艙',
#       'bookingClass': 'S',
#       'crossDays': 0,
#       'stopList': [],
#       'transfer': None,
#       'seqNo': 2,
#       'segmentNo': 1,
#       'sequenceNo': 2,
#       'baggageStraight': 0,
#       'dterminal': 'T2',
#       'dport': 'PVG',
#       'aterminal': 'T1',
#       'aport': 'KIX'}],
#     'stuTicketGrp': False},
#    {'flightKey': 'CX489CX566',
#     'departureDate': '6月5日',
#     'departureTime': '10:55',
#     'arrivalDate': '6月6日',
#     'arrivalTime': '06:35',
#     'crossDays': 1,
#     'departureCityCode': 'TPE',
#     'arrivalCityCode': 'OSA',
#     'departureCityName': '台北',
#     'arrivalCityName': '大阪',
#     'departureAirportCode': 'TPE',
#     'departureAirportName': '桃園國際機場',
#     'arrivalAirportCode': 'KIX',
#     'arrivalAirportName': '關西機場',
#     'departureTerminal': 'T1',
#     'arrivalTerminal': 'T1',
#     'stopType': 1,
#     'transit': {'isCrossday': True,
#      'isChangeAirport': False,
#      'isChangeTerminal': False,
#      'TransitType': 1,
#      'TransferCity': '香港',
#      'TransferSpan': '12h55m'},
#     'airlineName': '國泰航空',
#     'airlineFlitername': '國泰航空',
#     'airlineCode': 'CX',
#     'validatingAirlineCode': 'CX',
#     'seats': [{'seatCount': 5,
#       'seatType': 'EzTravel',
#       'feeConfirm': True,
#       'currencyCode': 'TWD',
#       'price': 19137,
#       'averagePrice': 19137,
#       'averagePriceNoTax': 14724,
#       'priceWithoutTax': 14724,
#       'priceWithTax': 19137,
#       'adultPrice': 14724,
#       'adultCnt': 1,
#       'adultTax': 4413,
#       'childPrice': 0,
#       'childTax': 0,
#       'childCnt': 0,
#       'infantPrice': 0,
#       'infantTax': 0,
#       'infantCnt': 0,
#       'selectedFlightParas': '{"OutBoundToken":"7a7ad0a7cf460df4","RouteSearchToken":"fd0d5130-14b8-4ec1-aa17-2000e438609f|35|28:3"}',
#       'selectedFlightInfo': '{"Airline":{"Code":"CX","Name":"國泰航空"},"ArrivalAirport":{"Code":"KIX","Name":"關西機場","Terminal":"T1","change":false,"country":"JP"},"ArrivalDate":1686004500000,"DepartureAirport":{"Code":"TPE","Name":"桃園國際機場","Terminal":"T1","change":false,"country":"TW"},"DepartureDate":1685933700000,"FlightNo":"CX489 CX566","FromAirport":"桃園國際機場","GoTime":"2023年06月05日 10:55","ToAirport":"關西機場","ToTime":"2023年06月06日 06:35","TransitDesc":"1程中轉"}',
#       'displayCategory': 99,
#       'classType': '經濟艙',
#       'allClassType': None,
#       'engineType': 'Abacus',
#       'remarkId': 'fd0d5130-14b8-4ec1-aa17-2000e438609f|35|28:3',
#       'fareInfo': None,
#       'planCategory': 'EZTRAVEL',
#       'resourceName': '易遊優選',
#       'resourceDesc': '享快速出票+線上更改/退票申請服務',
#       'freeBaggage': 3,
#       'productDesc': '',
#       'ticketingDesc': '付款後5分鐘出票',
#       'ticketingCode': 1,
#       'ageRestriction': '',
#       'passportTag': '',
#       'companionFare': None,
#       'combineTag': None,
#       'FarePenaltiesFlag': 2,
#       'FarePenalties': {'baggageFormats': [{'segmentNo': 1,
#          'sequenceNo': 1,
#          'fromCity': {'code': 'TPE',
#           'country': None,
#           'lineType': None,
#           'Name': '台北'},
#          'toCity': {'code': 'HKG',
#           'country': None,
#           'lineType': None,
#           'Name': '香港'},
#          'passengerType': 'Adult',
#          'checkInBaggage': {'weight': 23,
#           'unit': 'N',
#           'piece': 1,
#           'size': None,
#           'sizeType': None,
#           'text': '每人1件，每件23公斤。'},
#          'carryOnBaggage': {'weight': 7,
#           'unit': 'N',
#           'piece': 1,
#           'size': None,
#           'sizeType': None,
#           'text': '每人1件，每件7公斤，長寬高不可超過56*36*23公分。'},
#          'route': None},
#         {'segmentNo': 1,
#          'sequenceNo': 2,
#          'fromCity': {'code': 'HKG',
#           'country': None,
#           'lineType': None,
#           'Name': '香港'},
#          'toCity': {'code': 'OSA',
#           'country': None,
#           'lineType': None,
#           'Name': '大阪'},
#          'passengerType': 'Adult',
#          'checkInBaggage': {'weight': 23,
#           'unit': 'N',
#           'piece': 1,
#           'size': None,
#           'sizeType': None,
#           'text': '每人1件，每件23公斤。'},
#          'carryOnBaggage': {'weight': 7,
#           'unit': 'N',
#           'piece': 1,
#           'size': None,
#           'sizeType': None,
#           'text': '每人1件，每件7公斤，長寬高不可超過56*36*23公分。'},
#          'route': None},
#         {'segmentNo': 2,
#          'sequenceNo': 1,
#          'fromCity': {'code': 'OSA',
#           'country': None,
#           'lineType': None,
#           'Name': '大阪'},
#          'toCity': {'code': 'TPE',
#           'country': None,
#           'lineType': None,
#           'Name': '台北'},
#          'passengerType': 'Adult',
#          'checkInBaggage': {'weight': 23,
#           'unit': 'N',
#           'piece': 1,
#           'size': None,
#           'sizeType': None,
#           'text': '每人1件，每件23公斤。'},
#          'carryOnBaggage': {'weight': 7,
#           'unit': 'N',
#           'piece': 1,
#           'size': None,
#           'sizeType': None,
#           'text': '每人1件，每件7公斤，長寬高不可超過56*36*23公分。'},
#          'route': None}],
#        'penaltyFormat': None,
#        'baggageTag': '行李每成人1*23KG',
#        'penaltyFlag': 2,
#        'penaltyTag': '退票罰金另詢',
#        'FarePenaltiesFlag': 2,
#        'Penalties': None,
#        'Baggages': [{'Segment': '台北-香港', 'Text': '每人1件，每件23公斤。'},
#         {'Segment': '香港-大阪', 'Text': '每人1件，每件23公斤。'},
#         {'Segment': '大阪-台北', 'Text': '每人1件，每件23公斤。'}],
#        'NationDisallowed': '',
#        'NationAllowed': '',
#        'CityAllowed': '',
#        'Remark': None},
#       'easeTag': None,
#       'ticketType': 'ADULT',
#       'license': None}],
#     'flightDetails': [{'departureFullDate': '20230605',
#       'departureDate': '6月5日',
#       'arrivalDate': '6月5日',
#       'goDate': '2023-06-05',
#       'departureTime': '10:55',
#       'toDate': '2023-06-05',
#       'arrivalTime': '12:55',
#       'isRedEye': False,
#       'durationMinutes': 120,
#       'transferStayMinutes': 775,
#       'departureCity': 'TPE',
#       'departureCityCode': 'TPE',
#       'departureCityName': '台北',
#       'arrivalCity': 'HKG',
#       'arrivalCityCode': 'HKG',
#       'arrivalCityName': '香港',
#       'airlineCode': 'CX',
#       'airline': '國泰航空',
#       'flightNo': 'CX489',
#       'operatingAirlineCode': None,
#       'operatingAirline': None,
#       'operatingFlightNo': None,
#       'craft': {'craftType': '32Q',
#        'enName': None,
#        'widthLevel': None,
#        'minSeats': None,
#        'maxSeats': None,
#        'craftName': None},
#       'transitType': 1,
#       'departureAirportCode': 'TPE',
#       'departureAirportName': '桃園國際機場',
#       'departureTerminal': 'T1',
#       'arrivalAirportCode': 'HKG',
#       'arrivalAirportName': '香港國際機場',
#       'arrivalTerminal': 'T1',
#       'cabinType': 'tourist',
#       'cabinDesc': '經濟艙',
#       'bookingClass': 'S',
#       'crossDays': 0,
#       'stopList': [],
#       'transfer': {'isCrossday': True,
#        'isChangeAirport': False,
#        'isChangeTerminal': False,
#        'TransitType': 1,
#        'TransferCity': '香港',
#        'TransferSpan': '12h55m'},
#       'seqNo': 1,
#       'segmentNo': 1,
#       'sequenceNo': 1,
#       'baggageStraight': 0,
#       'dterminal': 'T1',
#       'dport': 'TPE',
#       'aterminal': 'T1',
#       'aport': 'HKG'},
#      {'departureFullDate': '20230606',
#       'departureDate': '6月6日',
#       'arrivalDate': '6月6日',
#       'goDate': '2023-06-06',
#       'departureTime': '01:50',
#       'toDate': '2023-06-06',
#       'arrivalTime': '06:35',
#       'isRedEye': True,
#       'durationMinutes': 225,
#       'transferStayMinutes': None,
#       'departureCity': 'HKG',
#       'departureCityCode': 'HKG',
#       'departureCityName': '香港',
#       'arrivalCity': 'OSA',
#       'arrivalCityCode': 'OSA',
#       'arrivalCityName': '大阪',
#       'airlineCode': 'CX',
#       'airline': '國泰航空',
#       'flightNo': 'CX566',
#       'operatingAirlineCode': None,
#       'operatingAirline': None,
#       'operatingFlightNo': None,
#       'craft': {'craftType': '359',
#        'enName': None,
#        'widthLevel': None,
#        'minSeats': 314,
#        'maxSeats': 475,
#        'craftName': '空中巴士 A359'},
#       'transitType': 0,
#       'departureAirportCode': 'HKG',
#       'departureAirportName': '香港國際機場',
#       'departureTerminal': 'T1',
#       'arrivalAirportCode': 'KIX',
#       'arrivalAirportName': '關西機場',
#       'arrivalTerminal': 'T1',
#       'cabinType': 'tourist',
#       'cabinDesc': '經濟艙',
#       'bookingClass': 'S',
#       'crossDays': 0,
#       'stopList': [],
#       'transfer': None,
#       'seqNo': 2,
#       'segmentNo': 1,
#       'sequenceNo': 2,
#       'baggageStraight': 0,
#       'dterminal': 'T1',
#       'dport': 'HKG',
#       'aterminal': 'T1',
#       'aport': 'KIX'}],
#     'stuTicketGrp': False}]}}

# %%
print(json_data["data"])
# Out:
# {'flightList': [{'flightKey': 'MU5008MU747', 'departureDate': '6月5日', 'departureTime': '15:30', 'arrivalDate': '6月6日', 'arrivalTime': '15:20', 'crossDays': 1, 'departureCityCode': 'TPE', 'arrivalCityCode': 'OSA', 'departureCityName': '台北', 'arrivalCityName': '大阪', 'departureAirportCode': 'TPE', 'departureAirportName': '桃園國際機場', 'arrivalAirportCode': 'KIX', 'arrivalAirportName': '關西機場', 'departureTerminal': 'T2', 'arrivalTerminal': 'T1', 'stopType': 1, 'transit': {'isCrossday': True, 'isChangeAirport': False, 'isChangeTerminal': False, 'TransitType': 1, 'TransferCity': '上海', 'TransferSpan': '18h30m'}, 'airlineName': '中國東方航空', 'airlineFlitername': '中國東方航空', 'airlineCode': 'MU', 'validatingAirlineCode': 'MU', 'seats': [{'seatCount': 9, 'seatType': 'EzTravel', 'feeConfirm': True, 'currencyCode': 'TWD', 'price': 16978, 'averagePrice': 16978, 'averagePriceNoTax': 12034, 'priceWithoutTax': 12034, 'priceWithTax': 16978, 'adultPrice': 12034, 'adultCnt': 1, 'adultTax': 4944, 'childPrice': 0, 'childTax': 0, 'childCnt': 0, 'infantPrice': 0, 'infantTax': 0, 'infantCnt': 0, 'selectedFlightParas': '{"OutBoundToken":"fa94ac1d0e1f0d4b","RouteSearchToken":"fd0d5130-14b8-4ec1-aa17-2000e438609f|16|6:4"}', 'selectedFlightInfo': '{"Airline":{"Code":"MU","Name":"中國東方航空"},"ArrivalAirport":{"Code":"KIX","Name":"關西機場","Terminal":"T1","change":false,"country":"JP"},"ArrivalDate":1686036000000,"DepartureAirport":{"Code":"TPE","Name":"桃園國際機場","Terminal":"T2","change":false,"country":"TW"},"DepartureDate":1685950200000,"FlightNo":"MU5008 MU747","FromAirport":"桃園國際機場","GoTime":"2023年06月05日 15:30","ToAirport":"關西機場","ToTime":"2023年06月06日 15:20","TransitDesc":"1程中轉"}', 'displayCategory': 99, 'classType': '經濟艙', 'allClassType': None, 'engineType': 'Amadeus', 'remarkId': 'fd0d5130-14b8-4ec1-aa17-2000e438609f|16|6:4', 'fareInfo': None, 'planCategory': 'EZTRAVEL', 'resourceName': '易遊優選', 'resourceDesc': '享快速出票+線上更改/退票申請服務', 'freeBaggage': 3, 'productDesc': '', 'ticketingDesc': '付款後5分鐘出票', 'ticketingCode': 1, 'ageRestriction': '', 'passportTag': '', 'companionFare': None, 'combineTag': None, 'FarePenaltiesFlag': 2, 'FarePenalties': {'baggageFormats': [{'segmentNo': 1, 'sequenceNo': 1, 'fromCity': {'code': 'TPE', 'country': None, 'lineType': None, 'Name': '台北'}, 'toCity': {'code': 'SHA', 'country': None, 'lineType': None, 'Name': '上海'}, 'passengerType': 'Adult', 'checkInBaggage': {'weight': 23, 'unit': 'N', 'piece': 2, 'size': None, 'sizeType': None, 'text': '每人2件，每件23公斤。'}, 'carryOnBaggage': {'weight': 8, 'unit': 'N', 'piece': 1, 'size': None, 'sizeType': None, 'text': '每人1件，每件8公斤，長寬高不可超過55*40*20公分。'}, 'route': None}, {'segmentNo': 1, 'sequenceNo': 2, 'fromCity': {'code': 'SHA', 'country': None, 'lineType': None, 'Name': '上海'}, 'toCity': {'code': 'OSA', 'country': None, 'lineType': None, 'Name': '大阪'}, 'passengerType': 'Adult', 'checkInBaggage': {'weight': 23, 'unit': 'N', 'piece': 2, 'size': None, 'sizeType': None, 'text': '每人2件，每件23公斤。'}, 'carryOnBaggage': {'weight': 8, 'unit': 'N', 'piece': 1, 'size': None, 'sizeType': None, 'text': '每人1件，每件8公斤，長寬高不可超過55*40*20公分。'}, 'route': None}, {'segmentNo': 2, 'sequenceNo': 1, 'fromCity': {'code': 'OSA', 'country': None, 'lineType': None, 'Name': '大阪'}, 'toCity': {'code': 'SHA', 'country': None, 'lineType': None, 'Name': '上海'}, 'passengerType': 'Adult', 'checkInBaggage': {'weight': 23, 'unit': 'N', 'piece': 2, 'size': None, 'sizeType': None, 'text': '每人2件，每件23公斤。'}, 'carryOnBaggage': {'weight': 8, 'unit': 'N', 'piece': 1, 'size': None, 'sizeType': None, 'text': '每人1件，每件8公斤，長寬高不可超過55*40*20公分。'}, 'route': None}, {'segmentNo': 2, 'sequenceNo': 2, 'fromCity': {'code': 'SHA', 'country': None, 'lineType': None, 'Name': '上海'}, 'toCity': {'code': 'TPE', 'country': None, 'lineType': None, 'Name': '台北'}, 'passengerType': 'Adult', 'checkInBaggage': {'weight': 23, 'unit': 'N', 'piece': 2, 'size': None, 'sizeType': None, 'text': '每人2件，每件23公斤。'}, 'carryOnBaggage': {'weight': 8, 'unit': 'N', 'piece': 1, 'size': None, 'sizeType': None, 't ...

# %%
a = json_data["data"]
print(a.values())
# Out:
# dict_values([[{'flightKey': 'MU5008MU747', 'departureDate': '6月5日', 'departureTime': '15:30', 'arrivalDate': '6月6日', 'arrivalTime': '15:20', 'crossDays': 1, 'departureCityCode': 'TPE', 'arrivalCityCode': 'OSA', 'departureCityName': '台北', 'arrivalCityName': '大阪', 'departureAirportCode': 'TPE', 'departureAirportName': '桃園國際機場', 'arrivalAirportCode': 'KIX', 'arrivalAirportName': '關西機場', 'departureTerminal': 'T2', 'arrivalTerminal': 'T1', 'stopType': 1, 'transit': {'isCrossday': True, 'isChangeAirport': False, 'isChangeTerminal': False, 'TransitType': 1, 'TransferCity': '上海', 'TransferSpan': '18h30m'}, 'airlineName': '中國東方航空', 'airlineFlitername': '中國東方航空', 'airlineCode': 'MU', 'validatingAirlineCode': 'MU', 'seats': [{'seatCount': 9, 'seatType': 'EzTravel', 'feeConfirm': True, 'currencyCode': 'TWD', 'price': 16978, 'averagePrice': 16978, 'averagePriceNoTax': 12034, 'priceWithoutTax': 12034, 'priceWithTax': 16978, 'adultPrice': 12034, 'adultCnt': 1, 'adultTax': 4944, 'childPrice': 0, 'childTax': 0, 'childCnt': 0, 'infantPrice': 0, 'infantTax': 0, 'infantCnt': 0, 'selectedFlightParas': '{"OutBoundToken":"fa94ac1d0e1f0d4b","RouteSearchToken":"fd0d5130-14b8-4ec1-aa17-2000e438609f|16|6:4"}', 'selectedFlightInfo': '{"Airline":{"Code":"MU","Name":"中國東方航空"},"ArrivalAirport":{"Code":"KIX","Name":"關西機場","Terminal":"T1","change":false,"country":"JP"},"ArrivalDate":1686036000000,"DepartureAirport":{"Code":"TPE","Name":"桃園國際機場","Terminal":"T2","change":false,"country":"TW"},"DepartureDate":1685950200000,"FlightNo":"MU5008 MU747","FromAirport":"桃園國際機場","GoTime":"2023年06月05日 15:30","ToAirport":"關西機場","ToTime":"2023年06月06日 15:20","TransitDesc":"1程中轉"}', 'displayCategory': 99, 'classType': '經濟艙', 'allClassType': None, 'engineType': 'Amadeus', 'remarkId': 'fd0d5130-14b8-4ec1-aa17-2000e438609f|16|6:4', 'fareInfo': None, 'planCategory': 'EZTRAVEL', 'resourceName': '易遊優選', 'resourceDesc': '享快速出票+線上更改/退票申請服務', 'freeBaggage': 3, 'productDesc': '', 'ticketingDesc': '付款後5分鐘出票', 'ticketingCode': 1, 'ageRestriction': '', 'passportTag': '', 'companionFare': None, 'combineTag': None, 'FarePenaltiesFlag': 2, 'FarePenalties': {'baggageFormats': [{'segmentNo': 1, 'sequenceNo': 1, 'fromCity': {'code': 'TPE', 'country': None, 'lineType': None, 'Name': '台北'}, 'toCity': {'code': 'SHA', 'country': None, 'lineType': None, 'Name': '上海'}, 'passengerType': 'Adult', 'checkInBaggage': {'weight': 23, 'unit': 'N', 'piece': 2, 'size': None, 'sizeType': None, 'text': '每人2件，每件23公斤。'}, 'carryOnBaggage': {'weight': 8, 'unit': 'N', 'piece': 1, 'size': None, 'sizeType': None, 'text': '每人1件，每件8公斤，長寬高不可超過55*40*20公分。'}, 'route': None}, {'segmentNo': 1, 'sequenceNo': 2, 'fromCity': {'code': 'SHA', 'country': None, 'lineType': None, 'Name': '上海'}, 'toCity': {'code': 'OSA', 'country': None, 'lineType': None, 'Name': '大阪'}, 'passengerType': 'Adult', 'checkInBaggage': {'weight': 23, 'unit': 'N', 'piece': 2, 'size': None, 'sizeType': None, 'text': '每人2件，每件23公斤。'}, 'carryOnBaggage': {'weight': 8, 'unit': 'N', 'piece': 1, 'size': None, 'sizeType': None, 'text': '每人1件，每件8公斤，長寬高不可超過55*40*20公分。'}, 'route': None}, {'segmentNo': 2, 'sequenceNo': 1, 'fromCity': {'code': 'OSA', 'country': None, 'lineType': None, 'Name': '大阪'}, 'toCity': {'code': 'SHA', 'country': None, 'lineType': None, 'Name': '上海'}, 'passengerType': 'Adult', 'checkInBaggage': {'weight': 23, 'unit': 'N', 'piece': 2, 'size': None, 'sizeType': None, 'text': '每人2件，每件23公斤。'}, 'carryOnBaggage': {'weight': 8, 'unit': 'N', 'piece': 1, 'size': None, 'sizeType': None, 'text': '每人1件，每件8公斤，長寬高不可超過55*40*20公分。'}, 'route': None}, {'segmentNo': 2, 'sequenceNo': 2, 'fromCity': {'code': 'SHA', 'country': None, 'lineType': None, 'Name': '上海'}, 'toCity': {'code': 'TPE', 'country': None, 'lineType': None, 'Name': '台北'}, 'passengerType': 'Adult', 'checkInBaggage': {'weight': 23, 'unit': 'N', 'piece': 2, 'size': None, 'sizeType': None, 'text': '每人2件，每件23公斤。'}, 'carryOnBaggage': {'weight': 8, 'unit': 'N', 'piece': 1, 'size': None, 'sizeType': None, 'tex ...

# %%
b = a.values()
b
# Out:
# dict_values([[{'flightKey': 'MU5008MU747', 'departureDate': '6月5日', 'departureTime': '15:30', 'arrivalDate': '6月6日', 'arrivalTime': '15:20', 'crossDays': 1, 'departureCityCode': 'TPE', 'arrivalCityCode': 'OSA', 'departureCityName': '台北', 'arrivalCityName': '大阪', 'departureAirportCode': 'TPE', 'departureAirportName': '桃園國際機場', 'arrivalAirportCode': 'KIX', 'arrivalAirportName': '關西機場', 'departureTerminal': 'T2', 'arrivalTerminal': 'T1', 'stopType': 1, 'transit': {'isCrossday': True, 'isChangeAirport': False, 'isChangeTerminal': False, 'TransitType': 1, 'TransferCity': '上海', 'TransferSpan': '18h30m'}, 'airlineName': '中國東方航空', 'airlineFlitername': '中國東方航空', 'airlineCode': 'MU', 'validatingAirlineCode': 'MU', 'seats': [{'seatCount': 9, 'seatType': 'EzTravel', 'feeConfirm': True, 'currencyCode': 'TWD', 'price': 16978, 'averagePrice': 16978, 'averagePriceNoTax': 12034, 'priceWithoutTax': 12034, 'priceWithTax': 16978, 'adultPrice': 12034, 'adultCnt': 1, 'adultTax': 4944, 'childPrice': 0, 'childTax': 0, 'childCnt': 0, 'infantPrice': 0, 'infantTax': 0, 'infantCnt': 0, 'selectedFlightParas': '{"OutBoundToken":"fa94ac1d0e1f0d4b","RouteSearchToken":"fd0d5130-14b8-4ec1-aa17-2000e438609f|16|6:4"}', 'selectedFlightInfo': '{"Airline":{"Code":"MU","Name":"中國東方航空"},"ArrivalAirport":{"Code":"KIX","Name":"關西機場","Terminal":"T1","change":false,"country":"JP"},"ArrivalDate":1686036000000,"DepartureAirport":{"Code":"TPE","Name":"桃園國際機場","Terminal":"T2","change":false,"country":"TW"},"DepartureDate":1685950200000,"FlightNo":"MU5008 MU747","FromAirport":"桃園國際機場","GoTime":"2023年06月05日 15:30","ToAirport":"關西機場","ToTime":"2023年06月06日 15:20","TransitDesc":"1程中轉"}', 'displayCategory': 99, 'classType': '經濟艙', 'allClassType': None, 'engineType': 'Amadeus', 'remarkId': 'fd0d5130-14b8-4ec1-aa17-2000e438609f|16|6:4', 'fareInfo': None, 'planCategory': 'EZTRAVEL', 'resourceName': '易遊優選', 'resourceDesc': '享快速出票+線上更改/退票申請服務', 'freeBaggage': 3, 'productDesc': '', 'ticketingDesc': '付款後5分鐘出票', 'ticketingCode': 1, 'ageRestriction': '', 'passportTag': '', 'companionFare': None, 'combineTag': None, 'FarePenaltiesFlag': 2, 'FarePenalties': {'baggageFormats': [{'segmentNo': 1, 'sequenceNo': 1, 'fromCity': {'code': 'TPE', 'country': None, 'lineType': None, 'Name': '台北'}, 'toCity': {'code': 'SHA', 'country': None, 'lineType': None, 'Name': '上海'}, 'passengerType': 'Adult', 'checkInBaggage': {'weight': 23, 'unit': 'N', 'piece': 2, 'size': None, 'sizeType': None, 'text': '每人2件，每件23公斤。'}, 'carryOnBaggage': {'weight': 8, 'unit': 'N', 'piece': 1, 'size': None, 'sizeType': None, 'text': '每人1件，每件8公斤，長寬高不可超過55*40*20公分。'}, 'route': None}, {'segmentNo': 1, 'sequenceNo': 2, 'fromCity': {'code': 'SHA', 'country': None, 'lineType': None, 'Name': '上海'}, 'toCity': {'code': 'OSA', 'country': None, 'lineType': None, 'Name': '大阪'}, 'passengerType': 'Adult', 'checkInBaggage': {'weight': 23, 'unit': 'N', 'piece': 2, 'size': None, 'sizeType': None, 'text': '每人2件，每件23公斤。'}, 'carryOnBaggage': {'weight': 8, 'unit': 'N', 'piece': 1, 'size': None, 'sizeType': None, 'text': '每人1件，每件8公斤，長寬高不可超過55*40*20公分。'}, 'route': None}, {'segmentNo': 2, 'sequenceNo': 1, 'fromCity': {'code': 'OSA', 'country': None, 'lineType': None, 'Name': '大阪'}, 'toCity': {'code': 'SHA', 'country': None, 'lineType': None, 'Name': '上海'}, 'passengerType': 'Adult', 'checkInBaggage': {'weight': 23, 'unit': 'N', 'piece': 2, 'size': None, 'sizeType': None, 'text': '每人2件，每件23公斤。'}, 'carryOnBaggage': {'weight': 8, 'unit': 'N', 'piece': 1, 'size': None, 'sizeType': None, 'text': '每人1件，每件8公斤，長寬高不可超過55*40*20公分。'}, 'route': None}, {'segmentNo': 2, 'sequenceNo': 2, 'fromCity': {'code': 'SHA', 'country': None, 'lineType': None, 'Name': '上海'}, 'toCity': {'code': 'TPE', 'country': None, 'lineType': None, 'Name': '台北'}, 'passengerType': 'Adult', 'checkInBaggage': {'weight': 23, 'unit': 'N', 'piece': 2, 'size': None, 'sizeType': None, 'text': '每人2件，每件23公斤。'}, 'carryOnBaggage': {'weight': 8, 'unit': 'N', 'piece': 1, 'size': None, 'sizeType': None, 'tex ...

# %%
def flatten_list(_2d_list):
    flat_list = []
    # Iterate through the outer list
    for element in _2d_list:
        if type(element) is list:
            # If the element is of type list, iterate through the sublist
            for item in element:
                flat_list.append(item)
        else:
            flat_list.append(element)
    return flat_list

# %%
new_datas = flatten_list(b)
new_datas
# Out:
# [{'flightKey': 'MU5008MU747',
#   'departureDate': '6月5日',
#   'departureTime': '15:30',
#   'arrivalDate': '6月6日',
#   'arrivalTime': '15:20',
#   'crossDays': 1,
#   'departureCityCode': 'TPE',
#   'arrivalCityCode': 'OSA',
#   'departureCityName': '台北',
#   'arrivalCityName': '大阪',
#   'departureAirportCode': 'TPE',
#   'departureAirportName': '桃園國際機場',
#   'arrivalAirportCode': 'KIX',
#   'arrivalAirportName': '關西機場',
#   'departureTerminal': 'T2',
#   'arrivalTerminal': 'T1',
#   'stopType': 1,
#   'transit': {'isCrossday': True,
#    'isChangeAirport': False,
#    'isChangeTerminal': False,
#    'TransitType': 1,
#    'TransferCity': '上海',
#    'TransferSpan': '18h30m'},
#   'airlineName': '中國東方航空',
#   'airlineFlitername': '中國東方航空',
#   'airlineCode': 'MU',
#   'validatingAirlineCode': 'MU',
#   'seats': [{'seatCount': 9,
#     'seatType': 'EzTravel',
#     'feeConfirm': True,
#     'currencyCode': 'TWD',
#     'price': 16978,
#     'averagePrice': 16978,
#     'averagePriceNoTax': 12034,
#     'priceWithoutTax': 12034,
#     'priceWithTax': 16978,
#     'adultPrice': 12034,
#     'adultCnt': 1,
#     'adultTax': 4944,
#     'childPrice': 0,
#     'childTax': 0,
#     'childCnt': 0,
#     'infantPrice': 0,
#     'infantTax': 0,
#     'infantCnt': 0,
#     'selectedFlightParas': '{"OutBoundToken":"fa94ac1d0e1f0d4b","RouteSearchToken":"fd0d5130-14b8-4ec1-aa17-2000e438609f|16|6:4"}',
#     'selectedFlightInfo': '{"Airline":{"Code":"MU","Name":"中國東方航空"},"ArrivalAirport":{"Code":"KIX","Name":"關西機場","Terminal":"T1","change":false,"country":"JP"},"ArrivalDate":1686036000000,"DepartureAirport":{"Code":"TPE","Name":"桃園國際機場","Terminal":"T2","change":false,"country":"TW"},"DepartureDate":1685950200000,"FlightNo":"MU5008 MU747","FromAirport":"桃園國際機場","GoTime":"2023年06月05日 15:30","ToAirport":"關西機場","ToTime":"2023年06月06日 15:20","TransitDesc":"1程中轉"}',
#     'displayCategory': 99,
#     'classType': '經濟艙',
#     'allClassType': None,
#     'engineType': 'Amadeus',
#     'remarkId': 'fd0d5130-14b8-4ec1-aa17-2000e438609f|16|6:4',
#     'fareInfo': None,
#     'planCategory': 'EZTRAVEL',
#     'resourceName': '易遊優選',
#     'resourceDesc': '享快速出票+線上更改/退票申請服務',
#     'freeBaggage': 3,
#     'productDesc': '',
#     'ticketingDesc': '付款後5分鐘出票',
#     'ticketingCode': 1,
#     'ageRestriction': '',
#     'passportTag': '',
#     'companionFare': None,
#     'combineTag': None,
#     'FarePenaltiesFlag': 2,
#     'FarePenalties': {'baggageFormats': [{'segmentNo': 1,
#        'sequenceNo': 1,
#        'fromCity': {'code': 'TPE',
#         'country': None,
#         'lineType': None,
#         'Name': '台北'},
#        'toCity': {'code': 'SHA',
#         'country': None,
#         'lineType': None,
#         'Name': '上海'},
#        'passengerType': 'Adult',
#        'checkInBaggage': {'weight': 23,
#         'unit': 'N',
#         'piece': 2,
#         'size': None,
#         'sizeType': None,
#         'text': '每人2件，每件23公斤。'},
#        'carryOnBaggage': {'weight': 8,
#         'unit': 'N',
#         'piece': 1,
#         'size': None,
#         'sizeType': None,
#         'text': '每人1件，每件8公斤，長寬高不可超過55*40*20公分。'},
#        'route': None},
#       {'segmentNo': 1,
#        'sequenceNo': 2,
#        'fromCity': {'code': 'SHA',
#         'country': None,
#         'lineType': None,
#         'Name': '上海'},
#        'toCity': {'code': 'OSA',
#         'country': None,
#         'lineType': None,
#         'Name': '大阪'},
#        'passengerType': 'Adult',
#        'checkInBaggage': {'weight': 23,
#         'unit': 'N',
#         'piece': 2,
#         'size': None,
#         'sizeType': None,
#         'text': '每人2件，每件23公斤。'},
#        'carryOnBaggage': {'weight': 8,
#         'unit': 'N',
#         'piece': 1,
#         'size': None,
#         'sizeType': None,
#         'text': '每人1件，每件8公斤，長寬高不可超過55*40*20公分。'},
#        'route': None},
#       {'segmentNo': 2,
#        'sequenceNo': 1,
#        'fromCity': {'code': 'OSA',
#         'country': None,
#         'lineType': None,
#         'Name': '大阪'},
#        'toCity': {'code': 'SHA',
#         'country': None,
#         'lineType': None,
#         'Name': '上海'},
#        'passengerType': 'Adult',
#        'checkInBaggage': {'weight': 23,
#         'unit': 'N',
#         'piece': 2,
#         'size': None,
#         'sizeType': None,
#         'text': '每人2件，每件23公斤。'},
#        'carryOnBaggage': {'weight': 8,
#         'unit': 'N',
#         'piece': 1,
#         'size': None,
#         'sizeType': None,
#         'text': '每人1件，每件8公斤，長寬高不可超過55*40*20公分。'},
#        'route': None},
#       {'segmentNo': 2,
#        'sequenceNo': 2,
#        'fromCity': {'code': 'SHA',
#         'country': None,
#         'lineType': None,
#         'Name': '上海'},
#        'toCity': {'code': 'TPE',
#         'country': None,
#         'lineType': None,
#         'Name': '台北'},
#        'passengerType': 'Adult',
#        'checkInBaggage': {'weight': 23,
#         'unit': 'N',
#         'piece': 2,
#         'size': None,
#         'sizeType': None,
#         'text': '每人2件，每件23公斤。'},
#        'carryOnBaggage': {'weight': 8,
#         'unit': 'N',
#         'piece': 1,
#         'size': None,
#         'sizeType': None,
#         'text': '每人1件，每件8公斤，長寬高不可超過55*40*20公分。'},
#        'route': None}],
#      'penaltyFormat': None,
#      'baggageTag': '行李每成人2*23KG',
#      'penaltyFlag': 1,
#      'penaltyTag': '不可退票',
#      'FarePenaltiesFlag': 2,
#      'Penalties': None,
#      'Baggages': [{'Segment': '台北-上海', 'Text': '每人2件，每件23公斤。'},
#       {'Segment': '上海-大阪', 'Text': '每人2件，每件23公斤。'},
#       {'Segment': '大阪-上海', 'Text': '每人2件，每件23公斤。'},
#       {'Segment': '上海-台北', 'Text': '每人2件，每件23公斤。'}],
#      'NationDisallowed': '',
#      'NationAllowed': '',
#      'CityAllowed': '',
#      'Remark': None},
#     'easeTag': None,
#     'ticketType': 'ADULT',
#     'license': None}],
#   'flightDetails': [{'departureFullDate': '20230605',
#     'departureDate': '6月5日',
#     'arrivalDate': '6月5日',
#     'goDate': '2023-06-05',
#     'departureTime': '15:30',
#     'toDate': '2023-06-05',
#     'arrivalTime': '17:30',
#     'isRedEye': False,
#     'durationMinutes': 120,
#     'transferStayMinutes': 1110,
#     'departureCity': 'TPE',
#     'departureCityCode': 'TPE',
#     'departureCityName': '台北',
#     'arrivalCity': 'SHA',
#     'arrivalCityCode': 'SHA',
#     'arrivalCityName': '上海',
#     'airlineCode': 'MU',
#     'airline': '中國東方航空',
#     'flightNo': 'MU5008',
#     'operatingAirlineCode': None,
#     'operatingAirline': None,
#     'operatingFlightNo': None,
#     'craft': {'craftType': '333',
#      'enName': None,
#      'widthLevel': None,
#      'minSeats': 256,
#      'maxSeats': 412,
#      'craftName': '空中巴士 330-300'},
#     'transitType': 1,
#     'departureAirportCode': 'TPE',
#     'departureAirportName': '桃園國際機場',
#     'departureTerminal': 'T2',
#     'arrivalAirportCode': 'PVG',
#     'arrivalAirportName': '上海浦東機場',
#     'arrivalTerminal': 'T1',
#     'cabinType': 'tourist',
#     'cabinDesc': '經濟艙',
#     'bookingClass': 'B',
#     'crossDays': 0,
#     'stopList': [],
#     'transfer': {'isCrossday': True,
#      'isChangeAirport': False,
#      'isChangeTerminal': False,
#      'TransitType': 1,
#      'TransferCity': '上海',
#      'TransferSpan': '18h30m'},
#     'seqNo': 1,
#     'segmentNo': 1,
#     'sequenceNo': 1,
#     'baggageStraight': 0,
#     'dterminal': 'T2',
#     'dport': 'TPE',
#     'aterminal': 'T1',
#     'aport': 'PVG'},
#    {'departureFullDate': '20230606',
#     'departureDate': '6月6日',
#     'arrivalDate': '6月6日',
#     'goDate': '2023-06-06',
#     'departureTime': '12:00',
#     'toDate': '2023-06-06',
#     'arrivalTime': '15:20',
#     'isRedEye': False,
#     'durationMinutes': 140,
#     'transferStayMinutes': None,
#     'departureCity': 'SHA',
#     'departureCityCode': 'SHA',
#     'departureCityName': '上海',
#     'arrivalCity': 'OSA',
#     'arrivalCityCode': 'OSA',
#     'arrivalCityName': '大阪',
#     'airlineCode': 'MU',
#     'airline': '中國東方航空',
#     'flightNo': 'MU747',
#     'operatingAirlineCode': None,
#     'operatingAirline': None,
#     'operatingFlightNo': None,
#     'craft': {'craftType': '321',
#      'enName': None,
#      'widthLevel': None,
#      'minSeats': 174,
#      'maxSeats': 220,
#      'craftName': '空中巴士 A321'},
#     'transitType': 0,
#     'departureAirportCode': 'PVG',
#     'departureAirportName': '上海浦東機場',
#     'departureTerminal': 'T1',
#     'arrivalAirportCode': 'KIX',
#     'arrivalAirportName': '關西機場',
#     'arrivalTerminal': 'T1',
#     'cabinType': 'tourist',
#     'cabinDesc': '經濟艙',
#     'bookingClass': 'V',
#     'crossDays': 0,
#     'stopList': [],
#     'transfer': None,
#     'seqNo': 2,
#     'segmentNo': 1,
#     'sequenceNo': 2,
#     'baggageStraight': 0,
#     'dterminal': 'T1',
#     'dport': 'PVG',
#     'aterminal': 'T1',
#     'aport': 'KIX'}],
#   'stuTicketGrp': False},
#  {'flightKey': 'CX479CX506',
#   'departureDate': '6月5日',
#   'departureTime': '21:15',
#   'arrivalDate': '6月6日',
#   'arrivalTime': '15:15',
#   'crossDays': 1,
#   'departureCityCode': 'TPE',
#   'arrivalCityCode': 'OSA',
#   'departureCityName': '台北',
#   'arrivalCityName': '大阪',
#   'departureAirportCode': 'TPE',
#   'departureAirportName': '桃園國際機場',
#   'arrivalAirportCode': 'KIX',
#   'arrivalAirportName': '關西機場',
#   'departureTerminal': 'T1',
#   'arrivalTerminal': 'T1',
#   'stopType': 1,
#   'transit': {'isCrossday': True,
#    'isChangeAirport': False,
#    'isChangeTerminal': False,
#    'TransitType': 1,
#    'TransferCity': '香港',
#    'TransferSpan': '11h15m'},
#   'airlineName': '國泰航空',
#   'airlineFlitername': '國泰航空',
#   'airlineCode': 'CX',
#   'validatingAirlineCode': 'CX',
#   'seats': [{'seatCount': 9,
#     'seatType': 'EzTravel',
#     'feeConfirm': True,
#     'currencyCode': 'TWD',
#     'price': 21236,
#     'averagePrice': 21236,
#     'averagePriceNoTax': 15083,
#     'priceWithoutTax': 15083,
#     'priceWithTax': 21236,
#     'adultPrice': 15083,
#     'adultCnt': 1,
#     'adultTax': 6153,
#     'childPrice': 0,
#     'childTax': 0,
#     'childCnt': 0,
#     'infantPrice': 0,
#     'infantTax': 0,
#     'infantCnt': 0,
#     'selectedFlightParas': '{"OutBoundToken":"a8534f720c7c1e7f","RouteSearchToken":"fd0d5130-14b8-4ec1-aa17-2000e438609f|52|34:24"}',
#     'selectedFlightInfo': '{"Airline":{"Code":"CX","Name":"國泰航空"},"ArrivalAirport":{"Code":"KIX","Name":"關西機場","Terminal":"T1","change":false,"country":"JP"},"ArrivalDate":1686035700000,"DepartureAirport":{"Code":"TPE","Name":"桃園國際機場","Terminal":"T1","change":false,"country":"TW"},"DepartureDate":1685970900000,"FlightNo":"CX479 CX506","FromAirport":"桃園國際機場","GoTime":"2023年06月05日 21:15","ToAirport":"關西機場","ToTime":"2023年06月06日 15:15","TransitDesc":"1程中轉"}',
#     'displayCategory': 99,
#     'classType': '經濟艙',
#     'allClassType': None,
#     'engineType': 'Abacus',
#     'remarkId': 'fd0d5130-14b8-4ec1-aa17-2000e438609f|52|34:24',
#     'fareInfo': None,
#     'planCategory': 'EZTRAVEL',
#     'resourceName': '易遊優選',
#     'resourceDesc': '享快速出票+線上更改/退票申請服務',
#     'freeBaggage': 3,
#     'productDesc': '',
#     'ticketingDesc': '付款後5分鐘出票',
#     'ticketingCode': 1,
#     'ageRestriction': '',
#     'passportTag': '',
#     'companionFare': None,
#     'combineTag': None,
#     'FarePenaltiesFlag': 2,
#     'FarePenalties': {'baggageFormats': [{'segmentNo': 1,
#        'sequenceNo': 1,
#        'fromCity': {'code': 'TPE',
#         'country': None,
#         'lineType': None,
#         'Name': '台北'},
#        'toCity': {'code': 'HKG',
#         'country': None,
#         'lineType': None,
#         'Name': '香港'},
#        'passengerType': 'Adult',
#        'checkInBaggage': {'weight': 23,
#         'unit': 'N',
#         'piece': 1,
#         'size': None,
#         'sizeType': None,
#         'text': '每人1件，每件23公斤。'},
#        'carryOnBaggage': {'weight': 7,
#         'unit': 'N',
#         'piece': 1,
#         'size': None,
#         'sizeType': None,
#         'text': '每人1件，每件7公斤，長寬高不可超過56*36*23公分。'},
#        'route': None},
#       {'segmentNo': 1,
#        'sequenceNo': 2,
#        'fromCity': {'code': 'HKG',
#         'country': None,
#         'lineType': None,
#         'Name': '香港'},
#        'toCity': {'code': 'OSA',
#         'country': None,
#         'lineType': None,
#         'Name': '大阪'},
#        'passengerType': 'Adult',
#        'checkInBaggage': {'weight': 23,
#         'unit': 'N',
#         'piece': 1,
#         'size': None,
#         'sizeType': None,
#         'text': '每人1件，每件23公斤。'},
#        'carryOnBaggage': {'weight': 7,
#         'unit': 'N',
#         'piece': 1,
#         'size': None,
#         'sizeType': None,
#         'text': '每人1件，每件7公斤，長寬高不可超過56*36*23公分。'},
#        'route': None},
#       {'segmentNo': 2,
#        'sequenceNo': 1,
#        'fromCity': {'code': 'OSA',
#         'country': None,
#         'lineType': None,
#         'Name': '大阪'},
#        'toCity': {'code': 'HKG',
#         'country': None,
#         'lineType': None,
#         'Name': '香港'},
#        'passengerType': 'Adult',
#        'checkInBaggage': {'weight': 23,
#         'unit': 'N',
#         'piece': 1,
#         'size': None,
#         'sizeType': None,
#         'text': '每人1件，每件23公斤。'},
#        'carryOnBaggage': {'weight': 7,
#         'unit': 'N',
#         'piece': 1,
#         'size': None,
#         'sizeType': None,
#         'text': '每人1件，每件7公斤，長寬高不可超過56*36*23公分。'},
#        'route': None},
#       {'segmentNo': 2,
#        'sequenceNo': 2,
#        'fromCity': {'code': 'HKG',
#         'country': None,
#         'lineType': None,
#         'Name': '香港'},
#        'toCity': {'code': 'TPE',
#         'country': None,
#         'lineType': None,
#         'Name': '台北'},
#        'passengerType': 'Adult',
#        'checkInBaggage': {'weight': 23,
#         'unit': 'N',
#         'piece': 1,
#         'size': None,
#         'sizeType': None,
#         'text': '每人1件，每件23公斤。'},
#        'carryOnBaggage': {'weight': 7,
#         'unit': 'N',
#         'piece': 1,
#         'size': None,
#         'sizeType': None,
#         'text': '每人1件，每件7公斤，長寬高不可超過56*36*23公分。'},
#        'route': None}],
#      'penaltyFormat': None,
#      'baggageTag': '行李每成人1*23KG',
#      'penaltyFlag': 2,
#      'penaltyTag': '退票罰金另詢',
#      'FarePenaltiesFlag': 2,
#      'Penalties': None,
#      'Baggages': [{'Segment': '台北-香港', 'Text': '每人1件，每件23公斤。'},
#       {'Segment': '香港-大阪', 'Text': '每人1件，每件23公斤。'},
#       {'Segment': '大阪-香港', 'Text': '每人1件，每件23公斤。'},
#       {'Segment': '香港-台北', 'Text': '每人1件，每件23公斤。'}],
#      'NationDisallowed': '',
#      'NationAllowed': '',
#      'CityAllowed': '',
#      'Remark': None},
#     'easeTag': None,
#     'ticketType': 'ADULT',
#     'license': None}],
#   'flightDetails': [{'departureFullDate': '20230605',
#     'departureDate': '6月5日',
#     'arrivalDate': '6月5日',
#     'goDate': '2023-06-05',
#     'departureTime': '21:15',
#     'toDate': '2023-06-05',
#     'arrivalTime': '23:05',
#     'isRedEye': False,
#     'durationMinutes': 110,
#     'transferStayMinutes': 675,
#     'departureCity': 'TPE',
#     'departureCityCode': 'TPE',
#     'departureCityName': '台北',
#     'arrivalCity': 'HKG',
#     'arrivalCityCode': 'HKG',
#     'arrivalCityName': '香港',
#     'airlineCode': 'CX',
#     'airline': '國泰航空',
#     'flightNo': 'CX479',
#     'operatingAirlineCode': None,
#     'operatingAirline': None,
#     'operatingFlightNo': None,
#     'craft': {'craftType': '351',
#      'enName': None,
#      'widthLevel': None,
#      'minSeats': 350,
#      'maxSeats': 550,
#      'craftName': '空中巴士 A350-1000'},
#     'transitType': 1,
#     'departureAirportCode': 'TPE',
#     'departureAirportName': '桃園國際機場',
#     'departureTerminal': 'T1',
#     'arrivalAirportCode': 'HKG',
#     'arrivalAirportName': '香港國際機場',
#     'arrivalTerminal': 'T1',
#     'cabinType': 'tourist',
#     'cabinDesc': '經濟艙',
#     'bookingClass': 'S',
#     'crossDays': 0,
#     'stopList': [],
#     'transfer': {'isCrossday': True,
#      'isChangeAirport': False,
#      'isChangeTerminal': False,
#      'TransitType': 1,
#      'TransferCity': '香港',
#      'TransferSpan': '11h15m'},
#     'seqNo': 1,
#     'segmentNo': 1,
#     'sequenceNo': 1,
#     'baggageStraight': 0,
#     'dterminal': 'T1',
#     'dport': 'TPE',
#     'aterminal': 'T1',
#     'aport': 'HKG'},
#    {'departureFullDate': '20230606',
#     'departureDate': '6月6日',
#     'arrivalDate': '6月6日',
#     'goDate': '2023-06-06',
#     'departureTime': '10:20',
#     'toDate': '2023-06-06',
#     'arrivalTime': '15:15',
#     'isRedEye': False,
#     'durationMinutes': 235,
#     'transferStayMinutes': None,
#     'departureCity': 'HKG',
#     'departureCityCode': 'HKG',
#     'departureCityName': '香港',
#     'arrivalCity': 'OSA',
#     'arrivalCityCode': 'OSA',
#     'arrivalCityName': '大阪',
#     'airlineCode': 'CX',
#     'airline': '國泰航空',
#     'flightNo': 'CX506',
#     'operatingAirlineCode': None,
#     'operatingAirline': None,
#     'operatingFlightNo': None,
#     'craft': {'craftType': '77W',
#      'enName': None,
#      'widthLevel': None,
#      'minSeats': 339,
#      'maxSeats': 378,
#      'craftName': '波音777'},
#     'transitType': 0,
#     'departureAirportCode': 'HKG',
#     'departureAirportName': '香港國際機場',
#     'departureTerminal': 'T1',
#     'arrivalAirportCode': 'KIX',
#     'arrivalAirportName': '關西機場',
#     'arrivalTerminal': 'T1',
#     'cabinType': 'tourist',
#     'cabinDesc': '經濟艙',
#     'bookingClass': 'S',
#     'crossDays': 0,
#     'stopList': [],
#     'transfer': None,
#     'seqNo': 2,
#     'segmentNo': 1,
#     'sequenceNo': 2,
#     'baggageStraight': 0,
#     'dterminal': 'T1',
#     'dport': 'HKG',
#     'aterminal': 'T1',
#     'aport': 'KIX'}],
#   'stuTicketGrp': True},
#  {'flightKey': 'NH854NH985',
#   'departureDate': '6月5日',
#   'departureTime': '16:50',
#   'arrivalDate': '6月6日',
#   'arrivalTime': '07:30',
#   'crossDays': 1,
#   'departureCityCode': 'TPE',
#   'arrivalCityCode': 'OSA',
#   'departureCityName': '台北',
#   'arrivalCityName': '大阪',
#   'departureAirportCode': 'TSA',
#   'departureAirportName': '松山機場',
#   'arrivalAirportCode': 'ITM',
#   'arrivalAirportName': '大阪伊丹機場',
#   'departureTerminal': 'T1',
#   'arrivalTerminal': None,
#   'stopType': 1,
#   'transit': {'isCrossday': True,
#    'isChangeAirport': False,
#    'isChangeTerminal': True,
#    'TransitType': 1,
#    'TransferCity': '東京',
#    'TransferSpan': '9h35m'},
#   'airlineName': '全日空航空',
#   'airlineFlitername': '全日空航空',
#   'airlineCode': 'NH',
#   'validatingAirlineCode': 'NH',
#   'seats': [{'seatCount': 4,
#     'seatType': 'EzTravel',
#     'feeConfirm': True,
#     'currencyCode': 'TWD',
#     'price': 23490,
#     'averagePrice': 23490,
#     'averagePriceNoTax': 17459,
#     'priceWithoutTax': 17459,
#     'priceWithTax': 23490,
#     'adultPrice': 17459,
#     'adultCnt': 1,
#     'adultTax': 6031,
#     'childPrice': 0,
#     'childTax': 0,
#     'childCnt': 0,
#     'infantPrice': 0,
#     'infantTax': 0,
#     'infantCnt': 0,
#     'selectedFlightParas': '{"OutBoundToken":"114bc7416c6769ed","RouteSearchToken":"fd0d5130-14b8-4ec1-aa17-2000e438609f|74|44:15"}',
#     'selectedFlightInfo': '{"Airline":{"Code":"NH","Name":"全日空航空"},"ArrivalAirport":{"Code":"ITM","Name":"大阪伊丹機場","change":false,"country":"JP"},"ArrivalDate":1686007800000,"DepartureAirport":{"Code":"TSA","Name":"松山機場","Terminal":"T1","change":false,"country":"TW"},"DepartureDate":1685955000000,"FlightNo":"NH854 NH985","FromAirport":"松山機場","GoTime":"2023年06月05日 16:50","ToAirport":"大阪伊丹機場","ToTime":"2023年06月06日 07:30","TransitDesc":"1程中轉"}',
#     'displayCategory': 99,
#     'classType': '經濟艙',
#     'allClassType': None,
#     'engineType': 'Abacus',
#     'remarkId': 'fd0d5130-14b8-4ec1-aa17-2000e438609f|74|44:15',
#     'fareInfo': None,
#     'planCategory': 'EZTRAVEL',
#     'resourceName': '易遊優選',
#     'resourceDesc': '享快速出票+線上更改/退票申請服務',
#     'freeBaggage': 3,
#     'productDesc': '',
#     'ticketingDesc': '付款後5分鐘出票',
#     'ticketingCode': 1,
#     'ageRestriction': '',
#     'passportTag': '',
#     'companionFare': None,
#     'combineTag': None,
#     'FarePenaltiesFlag': 2,
#     'FarePenalties': {'baggageFormats': [{'segmentNo': 1,
#        'sequenceNo': 1,
#        'fromCity': {'code': 'TPE',
#         'country': None,
#         'lineType': None,
#         'Name': '台北'},
#        'toCity': {'code': 'TYO',
#         'country': None,
#         'lineType': None,
#         'Name': '東京'},
#        'passengerType': 'Adult',
#        'checkInBaggage': {'weight': 23,
#         'unit': 'N',
#         'piece': 2,
#         'size': None,
#         'sizeType': None,
#         'text': '每人2件，每件23公斤。'},
#        'carryOnBaggage': {'weight': 10,
#         'unit': 'N',
#         'piece': 1,
#         'size': None,
#         'sizeType': None,
#         'text': '每人1件，每件10公斤，長寬高總和不可超過115公分。'},
#        'route': None},
#       {'segmentNo': 1,
#        'sequenceNo': 2,
#        'fromCity': {'code': 'TYO',
#         'country': None,
#         'lineType': None,
#         'Name': '東京'},
#        'toCity': {'code': 'OSA',
#         'country': None,
#         'lineType': None,
#         'Name': '大阪'},
#        'passengerType': 'Adult',
#        'checkInBaggage': {'weight': 23,
#         'unit': 'N',
#         'piece': 2,
#         'size': None,
#         'sizeType': None,
#         'text': '每人2件，每件23公斤。'},
#        'carryOnBaggage': {'weight': 10,
#         'unit': 'N',
#         'piece': 1,
#         'size': None,
#         'sizeType': None,
#         'text': '每人1件，每件10公斤，長寬高總和不可超過115公分。'},
#        'route': None},
#       {'segmentNo': 2,
#        'sequenceNo': 1,
#        'fromCity': {'code': 'OSA',
#         'country': None,
#         'lineType': None,
#         'Name': '大阪'},
#        'toCity': {'code': 'TPE',
#         'country': None,
#         'lineType': None,
#         'Name': '台北'},
#        'passengerType': 'Adult',
#        'checkInBaggage': {'weight': 23,
#         'unit': 'N',
#         'piece': 2,
#         'size': None,
#         'sizeType': None,
#         'text': '每人2件，每件23公斤。'},
#        'carryOnBaggage': {'weight': 7,
#         'unit': 'N',
#         'piece': 1,
#         'size': None,
#         'sizeType': None,
#         'text': '每人1件，每件7公斤，長寬高不可超過56*36*23公分。'},
#        'route': None}],
#      'penaltyFormat': None,
#      'baggageTag': '行李每成人2*23KG',
#      'penaltyFlag': 2,
#      'penaltyTag': '退票罰金另詢',
#      'FarePenaltiesFlag': 2,
#      'Penalties': None,
#      'Baggages': [{'Segment': '台北-東京', 'Text': '每人2件，每件23公斤。'},
#       {'Segment': '東京-大阪', 'Text': '每人2件，每件23公斤。'},
#       {'Segment': '大阪-台北', 'Text': '每人2件，每件23公斤。'}],
#      'NationDisallowed': '',
#      'NationAllowed': '',
#      'CityAllowed': '',
#      'Remark': None},
#     'easeTag': None,
#     'ticketType': 'ADULT',
#     'license': None}],
#   'flightDetails': [{'departureFullDate': '20230605',
#     'departureDate': '6月5日',
#     'arrivalDate': '6月5日',
#     'goDate': '2023-06-05',
#     'departureTime': '16:50',
#     'toDate': '2023-06-05',
#     'arrivalTime': '20:50',
#     'isRedEye': False,
#     'durationMinutes': 180,
#     'transferStayMinutes': 575,
#     'departureCity': 'TPE',
#     'departureCityCode': 'TPE',
#     'departureCityName': '台北',
#     'arrivalCity': 'TYO',
#     'arrivalCityCode': 'TYO',
#     'arrivalCityName': '東京',
#     'airlineCode': 'NH',
#     'airline': '全日空航空',
#     'flightNo': 'NH854',
#     'operatingAirlineCode': None,
#     'operatingAirline': None,
#     'operatingFlightNo': None,
#     'craft': {'craftType': '788',
#      'enName': None,
#      'widthLevel': None,
#      'minSeats': 210,
#      'maxSeats': 250,
#      'craftName': '波音 787-8'},
#     'transitType': 1,
#     'departureAirportCode': 'TSA',
#     'departureAirportName': '松山機場',
#     'departureTerminal': 'T1',
#     'arrivalAirportCode': 'HND',
#     'arrivalAirportName': '東京羽田機場',
#     'arrivalTerminal': 'T3',
#     'cabinType': 'tourist',
#     'cabinDesc': '經濟艙',
#     'bookingClass': 'Q',
#     'crossDays': 0,
#     'stopList': [],
#     'transfer': {'isCrossday': True,
#      'isChangeAirport': False,
#      'isChangeTerminal': True,
#      'TransitType': 1,
#      'TransferCity': '東京',
#      'TransferSpan': '9h35m'},
#     'seqNo': 1,
#     'segmentNo': 1,
#     'sequenceNo': 1,
#     'baggageStraight': 0,
#     'dterminal': 'T1',
#     'dport': 'TSA',
#     'aterminal': 'T3',
#     'aport': 'HND'},
#    {'departureFullDate': '20230606',
#     'departureDate': '6月6日',
#     'arrivalDate': '6月6日',
#     'goDate': '2023-06-06',
#     'departureTime': '06:25',
#     'toDate': '2023-06-06',
#     'arrivalTime': '07:30',
#     'isRedEye': False,
#     'durationMinutes': 65,
#     'transferStayMinutes': None,
#     'departureCity': 'TYO',
#     'departureCityCode': 'TYO',
#     'departureCityName': '東京',
#     'arrivalCity': 'OSA',
#     'arrivalCityCode': 'OSA',
#     'arrivalCityName': '大阪',
#     'airlineCode': 'NH',
#     'airline': '全日空航空',
#     'flightNo': 'NH985',
#     'operatingAirlineCode': None,
#     'operatingAirline': None,
#     'operatingFlightNo': None,
#     'craft': {'craftType': '772',
#      'enName': None,
#      'widthLevel': None,
#      'minSeats': 281,
#      'maxSeats': 440,
#      'craftName': '波音 777-200'},
#     'transitType': 0,
#     'departureAirportCode': 'HND',
#     'departureAirportName': '東京羽田機場',
#     'departureTerminal': 'T2',
#     'arrivalAirportCode': 'ITM',
#     'arrivalAirportName': '大阪伊丹機場',
#     'arrivalTerminal': None,
#     'cabinType': 'tourist',
#     'cabinDesc': '經濟艙',
#     'bookingClass': 'Q',
#     'crossDays': 0,
#     'stopList': [],
#     'transfer': None,
#     'seqNo': 2,
#     'segmentNo': 1,
#     'sequenceNo': 2,
#     'baggageStraight': 0,
#     'dterminal': 'T2',
#     'dport': 'HND',
#     'aterminal': None,
#     'aport': 'ITM'}],
#   'stuTicketGrp': False},
#  {'flightKey': 'MM030',
#   'departureDate': '6月5日',
#   'departureTime': '02:15',
#   'arrivalDate': '6月5日',
#   'arrivalTime': '06:00',
#   'crossDays': 0,
#   'departureCityCode': 'TPE',
#   'arrivalCityCode': 'OSA',
#   'departureCityName': '台北',
#   'arrivalCityName': '大阪',
#   'departureAirportCode': 'TPE',
#   'departureAirportName': '桃園國際機場',
#   'arrivalAirportCode': 'KIX',
#   'arrivalAirportName': '關西機場',
#   'departureTerminal': 'T1',
#   'arrivalTerminal': 'T2',
#   'stopType': 0,
#   'transit': {'TransitType': 0},
#   'airlineName': '樂桃航空',
#   'airlineFlitername': '樂桃航空',
#   'airlineCode': 'MM',
#   'validatingAirlineCode': 'MM',
#   'seats': [{'seatCount': 9,
#     'seatType': 'EzTravel',
#     'feeConfirm': True,
#     'currencyCode': 'TWD',
#     'price': 12727,
#     'averagePrice': 12727,
#     'averagePriceNoTax': 12023,
#     'priceWithoutTax': 12023,
#     'priceWithTax': 12727,
#     'adultPrice': 12023,
#     'adultCnt': 1,
#     'adultTax': 704,
#     'childPrice': 0,
#     'childTax': 0,
#     'childCnt': 0,
#     'infantPrice': 0,
#     'infantTax': 0,
#     'infantCnt': 0,
#     'selectedFlightParas': '{"OutBoundToken":"42cffda40135e4c5","RouteSearchToken":"fd0d5130-14b8-4ec1-aa17-2000e438609f|1|47:43"}',
#     'selectedFlightInfo': '{"Airline":{"Code":"MM","Name":"樂桃航空"},"ArrivalAirport":{"Code":"KIX","Name":"關西機場","Terminal":"T2","change":false,"country":"JP"},"ArrivalDate":1685916000000,"DepartureAirport":{"Code":"TPE","Name":"桃園國際機場","Terminal":"T1","change":false,"country":"TW"},"DepartureDate":1685902500000,"FlightNo":"MM030","FromAirport":"桃園國際機場","GoTime":"2023年06月05日 02:15","ToAirport":"關西機場","ToTime":"2023年06月05日 06:00","TransitDesc":"直飛"}',
#     'displayCategory': 99,
#     'classType': '經濟艙',
#     'allClassType': None,
#     'engineType': 'TravelFusion',
#     'remarkId': 'fd0d5130-14b8-4ec1-aa17-2000e438609f|1|47:43',
#     'fareInfo': None,
#     'planCategory': 'EZTRAVEL',
#     'resourceName': '易遊優選',
#     'resourceDesc': '享快速出票+線上更改/退票申請服務',
#     'freeBaggage': 1,
#     'productDesc': '',
#     'ticketingDesc': '付款後1小時出票',
#     'ticketingCode': 1,
#     'ageRestriction': '',
#     'passportTag': '',
#     'companionFare': None,
#     'combineTag': '由二至多張機票組成',
#     'FarePenaltiesFlag': 2,
#     'FarePenalties': {'baggageFormats': [{'segmentNo': 1,
#        'sequenceNo': 1,
#        'fromCity': {'code': 'TPE',
#         'country': None,
#         'lineType': None,
#         'Name': '台北'},
#        'toCity': {'code': 'OSA',
#         'country': None,
#         'lineType': None,
#         'Name': '大阪'},
#        'passengerType': 'Adult',
#        'checkInBaggage': {'weight': 0,
#         'unit': 'K',
#         'piece': 0,
#         'size': None,
#         'sizeType': None,
#         'text': '無免費託運行李。'},
#        'carryOnBaggage': {'weight': 7,
#         'unit': 'N',
#         'piece': 1,
#         'size': None,
#         'sizeType': None,
#         'text': '每人1件，每件7公斤，長寬高不可超過50*40*25公分。'},
#        'route': None},
#       {'segmentNo': 2,
#        'sequenceNo': 1,
#        'fromCity': {'code': 'OSA',
#         'country': None,
#         'lineType': None,
#         'Name': '大阪'},
#        'toCity': {'code': 'TPE',
#         'country': None,
#         'lineType': None,
#         'Name': '台北'},
#        'passengerType': 'Adult',
#        'checkInBaggage': {'weight': 0,
#         'unit': 'K',
#         'piece': 0,
#         'size': None,
#         'sizeType': None,
#         'text': '無免費託運行李。'},
#        'carryOnBaggage': {'weight': 10,
#         'unit': 'N',
#         'piece': 1,
#         'size': None,
#         'sizeType': None,
#         'text': '每人1件，每件10公斤，長寬高不可超過54*38*23公分。'},
#        'route': None}],
#      'penaltyFormat': None,
#      'baggageTag': '無免費託運行李',
#      'penaltyFlag': 1,
#      'penaltyTag': '不可退票',
#      'FarePenaltiesFlag': 2,
#      'Penalties': None,
#      'Baggages': [{'Segment': '台北-大阪', 'Text': '無免費託運行李。'},
#       {'Segment': '大阪-台北', 'Text': '無免費託運行李。'}],
#      'NationDisallowed': '',
#      'NationAllowed': '',
#      'CityAllowed': '',
#      'Remark': None},
#     'easeTag': None,
#     'ticketType': None,
#     'license': None}],
#   'flightDetails': [{'departureFullDate': '20230605',
#     'departureDate': '6月5日',
#     'arrivalDate': '6月5日',
#     'goDate': '2023-06-05',
#     'departureTime': '02:15',
#     'toDate': '2023-06-05',
#     'arrivalTime': '06:00',
#     'isRedEye': True,
#     'durationMinutes': 165,
#     'transferStayMinutes': None,
#     'departureCity': 'TPE',
#     'departureCityCode': 'TPE',
#     'departureCityName': '台北',
#     'arrivalCity': 'OSA',
#     'arrivalCityCode': 'OSA',
#     'arrivalCityName': '大阪',
#     'airlineCode': 'MM',
#     'airline': '樂桃航空',
#     'flightNo': 'MM030',
#     'operatingAirlineCode': None,
#     'operatingAirline': None,
#     'operatingFlightNo': None,
#     'craft': {'craftType': None,
#      'enName': None,
#      'widthLevel': None,
#      'minSeats': None,
#      'maxSeats': None,
#      'craftName': None},
#     'transitType': 0,
#     'departureAirportCode': 'TPE',
#     'departureAirportName': '桃園國際機場',
#     'departureTerminal': 'T1',
#     'arrivalAirportCode': 'KIX',
#     'arrivalAirportName': '關西機場',
#     'arrivalTerminal': 'T2',
#     'cabinType': 'tourist',
#     'cabinDesc': '經濟艙',
#     'bookingClass': 'M',
#     'crossDays': 0,
#     'stopList': [],
#     'transfer': None,
#     'seqNo': 1,
#     'segmentNo': 1,
#     'sequenceNo': 1,
#     'baggageStraight': 0,
#     'dterminal': 'T1',
#     'dport': 'TPE',
#     'aterminal': 'T2',
#     'aport': 'KIX'}],
#   'stuTicketGrp': False},
#  {'flightKey': 'NH852NH099',
#   'departureDate': '6月5日',
#   'departureTime': '13:35',
#   'arrivalDate': '6月5日',
#   'arrivalTime': '22:20',
#   'crossDays': 0,
#   'departureCityCode': 'TPE',
#   'arrivalCityCode': 'OSA',
#   'departureCityName': '台北',
#   'arrivalCityName': '大阪',
#   'departureAirportCode': 'TSA',
#   'departureAirportName': '松山機場',
#   'arrivalAirportCode': 'KIX',
#   'arrivalAirportName': '關西機場',
#   'departureTerminal': 'T1',
#   'arrivalTerminal': 'T1',
#   'stopType': 1,
#   'transit': {'isCrossday': False,
#    'isChangeAirport': False,
#    'isChangeTerminal': True,
#    'TransitType': 1,
#    'TransferCity': '東京',
#    'TransferSpan': '3h15m'},
#   'airlineName': '全日空航空',
#   'airlineFlitername': '全日空航空',
#   'airlineCode': 'NH',
#   'validatingAirlineCode': 'NH',
#   'seats': [{'seatCount': 4,
#     'seatType': 'EzTravel',
#     'feeConfirm': True,
#     'currencyCode': 'TWD',
#     'price': 22431,
#     'averagePrice': 22431,
#     'averagePriceNoTax': 16377,
#     'priceWithoutTax': 16377,
#     'priceWithTax': 22431,
#     'adultPrice': 16377,
#     'adultCnt': 1,
#     'adultTax': 6054,
#     'childPrice': 0,
#     'childTax': 0,
#     'childCnt': 0,
#     'infantPrice': 0,
#     'infantTax': 0,
#     'infantCnt': 0,
#     'selectedFlightParas': '{"OutBoundToken":"d663b0fb42756bf6","RouteSearchToken":"fd0d5130-14b8-4ec1-aa17-2000e438609f|67|39:15"}',
#     'selectedFlightInfo': '{"Airline":{"Code":"NH","Name":"全日空航空"},"ArrivalAirport":{"Code":"KIX","Name":"關西機場","Terminal":"T1","change":false,"country":"JP"},"ArrivalDate":1685974800000,"DepartureAirport":{"Code":"TSA","Name":"松山機場","Terminal":"T1","change":false,"country":"TW"},"DepartureDate":1685943300000,"FlightNo":"NH852 NH099","FromAirport":"松山機場","GoTime":"2023年06月05日 13:35","ToAirport":"關西機場","ToTime":"2023年06月05日 22:20","TransitDesc":"1程中轉"}',
#     'displayCategory': 99,
#     'classType': '經濟艙',
#     'allClassType': None,
#     'engineType': 'Abacus',
#     'remarkId': 'fd0d5130-14b8-4ec1-aa17-2000e438609f|67|39:15',
#     'fareInfo': None,
#     'planCategory': 'EZTRAVEL',
#     'resourceName': '易遊優選',
#     'resourceDesc': '享快速出票+線上更改/退票申請服務',
#     'freeBaggage': 3,
#     'productDesc': '',
#     'ticketingDesc': '付款後5分鐘出票',
#     'ticketingCode': 1,
#     'ageRestriction': '',
#     'passportTag': '',
#     'companionFare': None,
#     'combineTag': None,
#     'FarePenaltiesFlag': 2,
#     'FarePenalties': {'baggageFormats': [{'segmentNo': 1,
#        'sequenceNo': 1,
#        'fromCity': {'code': 'TPE',
#         'country': None,
#         'lineType': None,
#         'Name': '台北'},
#        'toCity': {'code': 'TYO',
#         'country': None,
#         'lineType': None,
#         'Name': '東京'},
#        'passengerType': 'Adult',
#        'checkInBaggage': {'weight': 23,
#         'unit': 'N',
#         'piece': 2,
#         'size': None,
#         'sizeType': None,
#         'text': '每人2件，每件23公斤。'},
#        'carryOnBaggage': {'weight': 10,
#         'unit': 'N',
#         'piece': 1,
#         'size': None,
#         'sizeType': None,
#         'text': '每人1件，每件10公斤，長寬高總和不可超過115公分。'},
#        'route': None},
#       {'segmentNo': 1,
#        'sequenceNo': 2,
#        'fromCity': {'code': 'TYO',
#         'country': None,
#         'lineType': None,
#         'Name': '東京'},
#        'toCity': {'code': 'OSA',
#         'country': None,
#         'lineType': None,
#         'Name': '大阪'},
#        'passengerType': 'Adult',
#        'checkInBaggage': {'weight': 23,
#         'unit': 'N',
#         'piece': 2,
#         'size': None,
#         'sizeType': None,
#         'text': '每人2件，每件23公斤。'},
#        'carryOnBaggage': {'weight': 10,
#         'unit': 'N',
#         'piece': 1,
#         'size': None,
#         'sizeType': None,
#         'text': '每人1件，每件10公斤，長寬高總和不可超過115公分。'},
#        'route': None},
#       {'segmentNo': 2,
#        'sequenceNo': 1,
#        'fromCity': {'code': 'OSA',
#         'country': None,
#         'lineType': None,
#         'Name': '大阪'},
#        'toCity': {'code': 'TPE',
#         'country': None,
#         'lineType': None,
#         'Name': '台北'},
#        'passengerType': 'Adult',
#        'checkInBaggage': {'weight': 23,
#         'unit': 'N',
#         'piece': 2,
#         'size': None,
#         'sizeType': None,
#         'text': '每人2件，每件23公斤。'},
#        'carryOnBaggage': {'weight': 7,
#         'unit': 'N',
#         'piece': 1,
#         'size': None,
#         'sizeType': None,
#         'text': '每人1件，每件7公斤，長寬高不可超過56*36*23公分。'},
#        'route': None}],
#      'penaltyFormat': None,
#      'baggageTag': '行李每成人2*23KG',
#      'penaltyFlag': 2,
#      'penaltyTag': '退票罰金另詢',
#      'FarePenaltiesFlag': 2,
#      'Penalties': None,
#      'Baggages': [{'Segment': '台北-東京', 'Text': '每人2件，每件23公斤。'},
#       {'Segment': '東京-大阪', 'Text': '每人2件，每件23公斤。'},
#       {'Segment': '大阪-台北', 'Text': '每人2件，每件23公斤。'}],
#      'NationDisallowed': '',
#      'NationAllowed': '',
#      'CityAllowed': '',
#      'Remark': None},
#     'easeTag': None,
#     'ticketType': 'ADULT',
#     'license': None}],
#   'flightDetails': [{'departureFullDate': '20230605',
#     'departureDate': '6月5日',
#     'arrivalDate': '6月5日',
#     'goDate': '2023-06-05',
#     'departureTime': '13:35',
#     'toDate': '2023-06-05',
#     'arrivalTime': '17:45',
#     'isRedEye': False,
#     'durationMinutes': 190,
#     'transferStayMinutes': 195,
#     'departureCity': 'TPE',
#     'departureCityCode': 'TPE',
#     'departureCityName': '台北',
#     'arrivalCity': 'TYO',
#     'arrivalCityCode': 'TYO',
#     'arrivalCityName': '東京',
#     'airlineCode': 'NH',
#     'airline': '全日空航空',
#     'flightNo': 'NH852',
#     'operatingAirlineCode': None,
#     'operatingAirline': None,
#     'operatingFlightNo': None,
#     'craft': {'craftType': '788',
#      'enName': None,
#      'widthLevel': None,
#      'minSeats': 210,
#      'maxSeats': 250,
#      'craftName': '波音 787-8'},
#     'transitType': 1,
#     'departureAirportCode': 'TSA',
#     'departureAirportName': '松山機場',
#     'departureTerminal': 'T1',
#     'arrivalAirportCode': 'HND',
#     'arrivalAirportName': '東京羽田機場',
#     'arrivalTerminal': 'T3',
#     'cabinType': 'tourist',
#     'cabinDesc': '經濟艙',
#     'bookingClass': 'V',
#     'crossDays': 0,
#     'stopList': [],
#     'transfer': {'isCrossday': False,
#      'isChangeAirport': False,
#      'isChangeTerminal': True,
#      'TransitType': 1,
#      'TransferCity': '東京',
#      'TransferSpan': '3h15m'},
#     'seqNo': 1,
#     'segmentNo': 1,
#     'sequenceNo': 1,
#     'baggageStraight': 0,
#     'dterminal': 'T1',
#     'dport': 'TSA',
#     'aterminal': 'T3',
#     'aport': 'HND'},
#    {'departureFullDate': '20230605',
#     'departureDate': '6月5日',
#     'arrivalDate': '6月5日',
#     'goDate': '2023-06-05',
#     'departureTime': '21:00',
#     'toDate': '2023-06-05',
#     'arrivalTime': '22:20',
#     'isRedEye': False,
#     'durationMinutes': 80,
#     'transferStayMinutes': None,
#     'departureCity': 'TYO',
#     'departureCityCode': 'TYO',
#     'departureCityName': '東京',
#     'arrivalCity': 'OSA',
#     'arrivalCityCode': 'OSA',
#     'arrivalCityName': '大阪',
#     'airlineCode': 'NH',
#     'airline': '全日空航空',
#     'flightNo': 'NH099',
#     'operatingAirlineCode': None,
#     'operatingAirline': None,
#     'operatingFlightNo': None,
#     'craft': {'craftType': '787',
#      'enName': None,
#      'widthLevel': None,
#      'minSeats': 210,
#      'maxSeats': 330,
#      'craftName': '波音 787'},
#     'transitType': 0,
#     'departureAirportCode': 'HND',
#     'departureAirportName': '東京羽田機場',
#     'departureTerminal': 'T2',
#     'arrivalAirportCode': 'KIX',
#     'arrivalAirportName': '關西機場',
#     'arrivalTerminal': 'T1',
#     'cabinType': 'tourist',
#     'cabinDesc': '經濟艙',
#     'bookingClass': 'V',
#     'crossDays': 0,
#     'stopList': [],
#     'transfer': None,
#     'seqNo': 2,
#     'segmentNo': 1,
#     'sequenceNo': 2,
#     'baggageStraight': 0,
#     'dterminal': 'T2',
#     'dport': 'HND',
#     'aterminal': 'T1',
#     'aport': 'KIX'}],
#   'stuTicketGrp': False},
#  {'flightKey': 'VN3587VN330',
#   'departureDate': '6月5日',
#   'departureTime': '14:40',
#   'arrivalDate': '6月6日',
#   'arrivalTime': '06:40',
#   'crossDays': 1,
#   'departureCityCode': 'TPE',
#   'arrivalCityCode': 'OSA',
#   'departureCityName': '台北',
#   'arrivalCityName': '大阪',
#   'departureAirportCode': 'TPE',
#   'departureAirportName': '桃園國際機場',
#   'arrivalAirportCode': 'KIX',
#   'arrivalAirportName': '關西機場',
#   'departureTerminal': 'T1',
#   'arrivalTerminal': 'T1',
#   'stopType': 1,
#   'transit': {'isCrossday': True,
#    'isChangeAirport': False,
#    'isChangeTerminal': False,
#    'TransitType': 1,
#    'TransferCity': '河內',
#    'TransferSpan': '7h40m'},
#   'airlineName': '越南航空',
#   'airlineFlitername': '越南航空',
#   'airlineCode': 'VN',
#   'validatingAirlineCode': 'VN',
#   'seats': [{'seatCount': 3,
#     'seatType': 'EzTravel',
#     'feeConfirm': True,
#     'currencyCode': 'TWD',
#     'price': 30836,
#     'averagePrice': 30836,
#     'averagePriceNoTax': 21830,
#     'priceWithoutTax': 21830,
#     'priceWithTax': 30836,
#     'adultPrice': 21830,
#     'adultCnt': 1,
#     'adultTax': 9006,
#     'childPrice': 0,
#     'childTax': 0,
#     'childCnt': 0,
#     'infantPrice': 0,
#     'infantTax': 0,
#     'infantCnt': 0,
#     'selectedFlightParas': '{"OutBoundToken":"105899e893287ec2","RouteSearchToken":"fd0d5130-14b8-4ec1-aa17-2000e438609f|90|46:40"}',
#     'selectedFlightInfo': '{"Airline":{"Code":"VN","Name":"越南航空"},"ArrivalAirport":{"Code":"KIX","Name":"關西機場","Terminal":"T1","change":false,"country":"JP"},"ArrivalDate":1686004800000,"DepartureAirport":{"Code":"TPE","Name":"桃園國際機場","Terminal":"T1","change":false,"country":"TW"},"DepartureDate":1685947200000,"FlightNo":"VN3587 VN330","FromAirport":"桃園國際機場","GoTime":"2023年06月05日 14:40","ToAirport":"關西機場","ToTime":"2023年06月06日 06:40","TransitDesc":"1程中轉"}',
#     'displayCategory': 99,
#     'classType': '經濟艙',
#     'allClassType': None,
#     'engineType': 'Abacus',
#     'remarkId': 'fd0d5130-14b8-4ec1-aa17-2000e438609f|90|46:40',
#     'fareInfo': None,
#     'planCategory': 'EZTRAVEL',
#     'resourceName': '易遊優選',
#     'resourceDesc': '享快速出票+線上更改/退票申請服務',
#     'freeBaggage': 3,
#     'productDesc': '',
#     'ticketingDesc': '付款後5分鐘出票',
#     'ticketingCode': 1,
#     'ageRestriction': '',
#     'passportTag': '',
#     'companionFare': None,
#     'combineTag': None,
#     'FarePenaltiesFlag': 2,
#     'FarePenalties': {'baggageFormats': [{'segmentNo': 1,
#        'sequenceNo': 1,
#        'fromCity': {'code': 'TPE',
#         'country': None,
#         'lineType': None,
#         'Name': '台北'},
#        'toCity': {'code': 'HAN',
#         'country': None,
#         'lineType': None,
#         'Name': '河內'},
#        'passengerType': 'Adult',
#        'checkInBaggage': {'weight': 23,
#         'unit': 'N',
#         'piece': 1,
#         'size': None,
#         'sizeType': None,
#         'text': '每人1件，每件23公斤。'},
#        'carryOnBaggage': {'weight': 7,
#         'unit': 'N',
#         'piece': 1,
#         'size': None,
#         'sizeType': None,
#         'text': '每人1件，每件7公斤，長寬高不可超過56*36*23公分。'},
#        'route': None},
#       {'segmentNo': 1,
#        'sequenceNo': 2,
#        'fromCity': {'code': 'HAN',
#         'country': None,
#         'lineType': None,
#         'Name': '河內'},
#        'toCity': {'code': 'OSA',
#         'country': None,
#         'lineType': None,
#         'Name': '大阪'},
#        'passengerType': 'Adult',
#        'checkInBaggage': {'weight': 23,
#         'unit': 'N',
#         'piece': 1,
#         'size': None,
#         'sizeType': None,
#         'text': '每人1件，每件23公斤。'},
#        'carryOnBaggage': {'weight': 10,
#         'unit': 'N',
#         'piece': 1,
#         'size': None,
#         'sizeType': None,
#         'text': '每人1件，每件10公斤，長寬高不可超過56*36*23公分。'},
#        'route': None},
#       {'segmentNo': 2,
#        'sequenceNo': 1,
#        'fromCity': {'code': 'OSA',
#         'country': None,
#         'lineType': None,
#         'Name': '大阪'},
#        'toCity': {'code': 'HAN',
#         'country': None,
#         'lineType': None,
#         'Name': '河內'},
#        'passengerType': 'Adult',
#        'checkInBaggage': {'weight': 23,
#         'unit': 'N',
#         'piece': 1,
#         'size': None,
#         'sizeType': None,
#         'text': '每人1件，每件23公斤。'},
#        'carryOnBaggage': {'weight': 10,
#         'unit': 'N',
#         'piece': 1,
#         'size': None,
#         'sizeType': None,
#         'text': '每人1件，每件10公斤，長寬高不可超過56*36*23公分。'},
#        'route': None},
#       {'segmentNo': 2,
#        'sequenceNo': 2,
#        'fromCity': {'code': 'HAN',
#         'country': None,
#         'lineType': None,
#         'Name': '河內'},
#        'toCity': {'code': 'TPE',
#         'country': None,
#         'lineType': None,
#         'Name': '台北'},
#        'passengerType': 'Adult',
#        'checkInBaggage': {'weight': 23,
#         'unit': 'N',
#         'piece': 1,
#         'size': None,
#         'sizeType': None,
#         'text': '每人1件，每件23公斤。'},
#        'carryOnBaggage': {'weight': 10,
#         'unit': 'N',
#         'piece': 1,
#         'size': None,
#         'sizeType': None,
#         'text': '每人1件，每件10公斤，長寬高不可超過56*36*23公分。'},
#        'route': None}],
#      'penaltyFormat': None,
#      'baggageTag': '行李每成人1*23KG',
#      'penaltyFlag': 2,
#      'penaltyTag': '退票罰金另詢',
#      'FarePenaltiesFlag': 2,
#      'Penalties': None,
#      'Baggages': [{'Segment': '台北-河內', 'Text': '每人1件，每件23公斤。'},
#       {'Segment': '河內-大阪', 'Text': '每人1件，每件23公斤。'},
#       {'Segment': '大阪-河內', 'Text': '每人1件，每件23公斤。'},
#       {'Segment': '河內-台北', 'Text': '每人1件，每件23公斤。'}],
#      'NationDisallowed': '',
#      'NationAllowed': '',
#      'CityAllowed': '',
#      'Remark': None},
#     'easeTag': None,
#     'ticketType': 'ADULT',
#     'license': None}],
#   'flightDetails': [{'departureFullDate': '20230605',
#     'departureDate': '6月5日',
#     'arrivalDate': '6月5日',
#     'goDate': '2023-06-05',
#     'departureTime': '14:40',
#     'toDate': '2023-06-05',
#     'arrivalTime': '16:50',
#     'isRedEye': False,
#     'durationMinutes': 190,
#     'transferStayMinutes': 460,
#     'departureCity': 'TPE',
#     'departureCityCode': 'TPE',
#     'departureCityName': '台北',
#     'arrivalCity': 'HAN',
#     'arrivalCityCode': 'HAN',
#     'arrivalCityName': '河內',
#     'airlineCode': 'VN',
#     'airline': '越南航空',
#     'flightNo': 'VN3587',
#     'operatingAirlineCode': 'CI',
#     'operatingAirline': '中華航空',
#     'operatingFlightNo': None,
#     'craft': {'craftType': '32Q',
#      'enName': None,
#      'widthLevel': None,
#      'minSeats': None,
#      'maxSeats': None,
#      'craftName': None},
#     'transitType': 1,
#     'departureAirportCode': 'TPE',
#     'departureAirportName': '桃園國際機場',
#     'departureTerminal': 'T1',
#     'arrivalAirportCode': 'HAN',
#     'arrivalAirportName': '河內機場',
#     'arrivalTerminal': 'T2',
#     'cabinType': 'tourist',
#     'cabinDesc': '經濟艙',
#     'bookingClass': 'M',
#     'crossDays': 0,
#     'stopList': [],
#     'transfer': {'isCrossday': True,
#      'isChangeAirport': False,
#      'isChangeTerminal': False,
#      'TransitType': 1,
#      'TransferCity': '河內',
#      'TransferSpan': '7h40m'},
#     'seqNo': 1,
#     'segmentNo': 1,
#     'sequenceNo': 1,
#     'baggageStraight': 0,
#     'dterminal': 'T1',
#     'dport': 'TPE',
#     'aterminal': 'T2',
#     'aport': 'HAN'},
#    {'departureFullDate': '20230606',
#     'departureDate': '6月6日',
#     'arrivalDate': '6月6日',
#     'goDate': '2023-06-06',
#     'departureTime': '00:30',
#     'toDate': '2023-06-06',
#     'arrivalTime': '06:40',
#     'isRedEye': True,
#     'durationMinutes': 250,
#     'transferStayMinutes': None,
#     'departureCity': 'HAN',
#     'departureCityCode': 'HAN',
#     'departureCityName': '河內',
#     'arrivalCity': 'OSA',
#     'arrivalCityCode': 'OSA',
#     'arrivalCityName': '大阪',
#     'airlineCode': 'VN',
#     'airline': '越南航空',
#     'flightNo': 'VN330',
#     'operatingAirlineCode': None,
#     'operatingAirline': None,
#     'operatingFlightNo': None,
#     'craft': {'craftType': '350',
#      'enName': None,
#      'widthLevel': None,
#      'minSeats': None,
#      'maxSeats': None,
#      'craftName': None},
#     'transitType': 0,
#     'departureAirportCode': 'HAN',
#     'departureAirportName': '河內機場',
#     'departureTerminal': 'T2',
#     'arrivalAirportCode': 'KIX',
#     'arrivalAirportName': '關西機場',
#     'arrivalTerminal': 'T1',
#     'cabinType': 'tourist',
#     'cabinDesc': '經濟艙',
#     'bookingClass': 'T',
#     'crossDays': 0,
#     'stopList': [],
#     'transfer': None,
#     'seqNo': 2,
#     'segmentNo': 1,
#     'sequenceNo': 2,
#     'baggageStraight': 0,
#     'dterminal': 'T2',
#     'dport': 'HAN',
#     'aterminal': 'T1',
#     'aport': 'KIX'}],
#   'stuTicketGrp': False},
#  {'flightKey': 'CX479CX596',
#   'departureDate': '6月5日',
#   'departureTime': '21:15',
#   'arrivalDate': '6月6日',
#   'arrivalTime': '13:00',
#   'crossDays': 1,
#   'departureCityCode': 'TPE',
#   'arrivalCityCode': 'OSA',
#   'departureCityName': '台北',
#   'arrivalCityName': '大阪',
#   'departureAirportCode': 'TPE',
#   'departureAirportName': '桃園國際機場',
#   'arrivalAirportCode': 'KIX',
#   'arrivalAirportName': '關西機場',
#   'departureTerminal': 'T1',
#   'arrivalTerminal': 'T1',
#   'stopType': 1,
#   'transit': {'isCrossday': True,
#    'isChangeAirport': False,
#    'isChangeTerminal': False,
#    'TransitType': 1,
#    'TransferCity': '香港',
#    'TransferSpan': '9h5m'},
#   'airlineName': '國泰航空',
#   'airlineFlitername': '國泰航空',
#   'airlineCode': 'CX',
#   'validatingAirlineCode': 'CX',
#   'seats': [{'seatCount': 5,
#     'seatType': 'EzTravel',
#     'feeConfirm': True,
#     'currencyCode': 'TWD',
#     'price': 23676,
#     'averagePrice': 23676,
#     'averagePriceNoTax': 18792,
#     'priceWithoutTax': 18792,
#     'priceWithTax': 23676,
#     'adultPrice': 18792,
#     'adultCnt': 1,
#     'adultTax': 4884,
#     'childPrice': 0,
#     'childTax': 0,
#     'childCnt': 0,
#     'infantPrice': 0,
#     'infantTax': 0,
#     'infantCnt': 0,
#     'selectedFlightParas': '{"OutBoundToken":"2bd07a4a1cce060d","RouteSearchToken":"fd0d5130-14b8-4ec1-aa17-2000e438609f|75|50:3"}',
#     'selectedFlightInfo': '{"Airline":{"Code":"CX","Name":"國泰航空"},"ArrivalAirport":{"Code":"KIX","Name":"關西機場","Terminal":"T1","change":false,"country":"JP"},"ArrivalDate":1686027600000,"DepartureAirport":{"Code":"TPE","Name":"桃園國際機場","Terminal":"T1","change":false,"country":"TW"},"DepartureDate":1685970900000,"FlightNo":"CX479 CX596","FromAirport":"桃園國際機場","GoTime":"2023年06月05日 21:15","ToAirport":"關西機場","ToTime":"2023年06月06日 13:00","TransitDesc":"1程中轉"}',
#     'displayCategory': 5,
#     'classType': '經濟艙',
#     'allClassType': None,
#     'engineType': 'Amadeus',
#     'remarkId': 'fd0d5130-14b8-4ec1-aa17-2000e438609f|75|50:3',
#     'fareInfo': None,
#     'planCategory': 'EZTRAVEL',
#     'resourceName': '易遊優選',
#     'resourceDesc': '享快速出票+線上更改/退票申請服務',
#     'freeBaggage': 3,
#     'productDesc': '',
#     'ticketingDesc': '付款後5分鐘出票',
#     'ticketingCode': 1,
#     'ageRestriction': '限12歲-31歲購買',
# ...
#      'widthLevel': None,
#      'minSeats': 256,
#      'maxSeats': 412,
#      'craftName': '空中巴士 330-300'},
#     'transitType': 0,
#     'departureAirportCode': 'TPE',
#     'departureAirportName': '桃園國際機場',
#     'departureTerminal': 'T2',
#     'arrivalAirportCode': 'KIX',
#     'arrivalAirportName': '關西機場',
#     'arrivalTerminal': 'T1',
#     'cabinType': 'tourist',
#     'cabinDesc': '經濟艙',
#     'bookingClass': 'N',
#     'crossDays': 0,
#     'stopList': [],
#     'transfer': None,
#     'seqNo': 1,
#     'segmentNo': 1,
#     'sequenceNo': 1,
#     'baggageStraight': 0,
#     'dterminal': 'T2',
#     'dport': 'TPE',
#     'aterminal': 'T1',
#     'aport': 'KIX'}],
#   'stuTicketGrp': True},
#  {'flightKey': 'MU3546MU3567',
#   'departureDate': '6月5日',
#   'departureTime': '12:25',
#   'arrivalDate': '6月5日',
#   'arrivalTime': '20:15',
#   'crossDays': 0,
#   'departureCityCode': 'TPE',
#   'arrivalCityCode': 'OSA',
#   'departureCityName': '台北',
#   'arrivalCityName': '大阪',
#   'departureAirportCode': 'TPE',
#   'departureAirportName': '桃園國際機場',
#   'arrivalAirportCode': 'KIX',
#   'arrivalAirportName': '關西機場',
#   'departureTerminal': 'T1',
#   'arrivalTerminal': 'T1',
#   'stopType': 1,
#   'transit': {'isCrossday': False,
#    'isChangeAirport': False,
#    'isChangeTerminal': False,
#    'TransitType': 1,
#    'TransferCity': '上海',
#    'TransferSpan': '2h30m'},
#   'airlineName': '中國東方航空',
#   'airlineFlitername': '中國東方航空',
#   'airlineCode': 'MU',
#   'validatingAirlineCode': 'MU',
#   'seats': [{'seatCount': 4,
#     'seatType': 'EzTravel',
#     'feeConfirm': True,
#     'currencyCode': 'TWD',
#     'price': 48770,
#     'averagePrice': 48770,
#     'averagePriceNoTax': 43364,
#     'priceWithoutTax': 43364,
#     'priceWithTax': 48770,
#     'adultPrice': 43364,
#     'adultCnt': 1,
#     'adultTax': 5406,
#     'childPrice': 0,
#     'childTax': 0,
#     'childCnt': 0,
#     'infantPrice': 0,
#     'infantTax': 0,
#     'infantCnt': 0,
#     'selectedFlightParas': '{"OutBoundToken":"18efdf64194fdb7e","RouteSearchToken":"fd0d5130-14b8-4ec1-aa17-2000e438609f|103|24:15"}',
#     'selectedFlightInfo': '{"Airline":{"Code":"MU","Name":"中國東方航空"},"ArrivalAirport":{"Code":"KIX","Name":"關西機場","Terminal":"T1","change":false,"country":"JP"},"ArrivalDate":1685967300000,"DepartureAirport":{"Code":"TPE","Name":"桃園國際機場","Terminal":"T1","change":false,"country":"TW"},"DepartureDate":1685939100000,"FlightNo":"MU3546 MU3567","FromAirport":"桃園國際機場","GoTime":"2023年06月05日 12:25","ToAirport":"關西機場","ToTime":"2023年06月05日 20:15","TransitDesc":"1程中轉"}',
#     'displayCategory': 99,
#     'classType': '經濟艙',
#     'allClassType': None,
#     'engineType': 'Amadeus',
#     'remarkId': 'fd0d5130-14b8-4ec1-aa17-2000e438609f|103|24:15',
#     'fareInfo': None,
#     'planCategory': 'EZTRAVEL',
#     'resourceName': '易遊優選',
#     'resourceDesc': '享快速出票+線上更改/退票申請服務',
#     'freeBaggage': 3,
#     'productDesc': '',
#     'ticketingDesc': '付款後5分鐘出票',
#     'ticketingCode': 1,
#     'ageRestriction': '',
#     'passportTag': '',
#     'companionFare': None,
#     'combineTag': None,
#     'FarePenaltiesFlag': 2,
#     'FarePenalties': {'baggageFormats': [{'segmentNo': 1,
#        'sequenceNo': 1,
#        'fromCity': {'code': 'TPE',
#         'country': None,
#         'lineType': None,
#         'Name': '台北'},
#        'toCity': {'code': 'SHA',
#         'country': None,
#         'lineType': None,
#         'Name': '上海'},
#        'passengerType': 'Adult',
#        'checkInBaggage': {'weight': 23,
#         'unit': 'N',
#         'piece': 2,
#         'size': None,
#         'sizeType': None,
#         'text': '每人2件，每件23公斤。'},
#        'carryOnBaggage': {'weight': None,
#         'unit': None,
#         'piece': 0,
#         'size': None,
#         'sizeType': None,
#         'text': '依航空公司規定。'},
#        'route': None},
#       {'segmentNo': 1,
#        'sequenceNo': 2,
#        'fromCity': {'code': 'SHA',
#         'country': None,
#         'lineType': None,
#         'Name': '上海'},
#        'toCity': {'code': 'OSA',
#         'country': None,
#         'lineType': None,
#         'Name': '大阪'},
#        'passengerType': 'Adult',
#        'checkInBaggage': {'weight': 23,
#         'unit': 'N',
#         'piece': 2,
#         'size': None,
#         'sizeType': None,
#         'text': '每人2件，每件23公斤。'},
#        'carryOnBaggage': {'weight': None,
#         'unit': None,
#         'piece': 0,
#         'size': None,
#         'sizeType': None,
#         'text': '依航空公司規定。'},
#        'route': None},
#       {'segmentNo': 2,
#        'sequenceNo': 1,
#        'fromCity': {'code': 'OSA',
#         'country': None,
#         'lineType': None,
#         'Name': '大阪'},
#        'toCity': {'code': 'TPE',
#         'country': None,
#         'lineType': None,
#         'Name': '台北'},
#        'passengerType': 'Adult',
#        'checkInBaggage': {'weight': 23,
#         'unit': 'N',
#         'piece': 2,
#         'size': None,
#         'sizeType': None,
#         'text': '每人2件，每件23公斤。'},
#        'carryOnBaggage': {'weight': 7,
#         'unit': 'N',
#         'piece': 1,
#         'size': None,
#         'sizeType': None,
#         'text': '每人1件，每件7公斤，長寬高不可超過56*36*23公分。'},
#        'route': None}],
#      'penaltyFormat': None,
#      'baggageTag': '行李每成人2*23KG',
#      'penaltyFlag': 2,
#      'penaltyTag': '退票罰金另詢',
#      'FarePenaltiesFlag': 2,
#      'Penalties': None,
#      'Baggages': [{'Segment': '台北-上海', 'Text': '每人2件，每件23公斤。'},
#       {'Segment': '上海-大阪', 'Text': '每人2件，每件23公斤。'},
#       {'Segment': '大阪-台北', 'Text': '每人2件，每件23公斤。'}],
#      'NationDisallowed': '',
#      'NationAllowed': '',
#      'CityAllowed': '',
#      'Remark': None},
#     'easeTag': None,
#     'ticketType': 'ADULT',
#     'license': None}],
#   'flightDetails': [{'departureFullDate': '20230605',
#     'departureDate': '6月5日',
#     'arrivalDate': '6月5日',
#     'goDate': '2023-06-05',
#     'departureTime': '12:25',
#     'toDate': '2023-06-05',
#     'arrivalTime': '14:30',
#     'isRedEye': False,
#     'durationMinutes': 125,
#     'transferStayMinutes': 150,
#     'departureCity': 'TPE',
#     'departureCityCode': 'TPE',
#     'departureCityName': '台北',
#     'arrivalCity': 'SHA',
#     'arrivalCityCode': 'SHA',
#     'arrivalCityName': '上海',
#     'airlineCode': 'MU',
#     'airline': '中國東方航空',
#     'flightNo': 'MU3546',
#     'operatingAirlineCode': 'HO',
#     'operatingAirline': '上海吉祥航空',
#     'operatingFlightNo': None,
#     'craft': {'craftType': '32S',
#      'enName': None,
#      'widthLevel': None,
#      'minSeats': 107,
#      'maxSeats': 220,
#      'craftName': '空中巴士 A319'},
#     'transitType': 1,
#     'departureAirportCode': 'TPE',
#     'departureAirportName': '桃園國際機場',
#     'departureTerminal': 'T1',
#     'arrivalAirportCode': 'PVG',
#     'arrivalAirportName': '上海浦東機場',
#     'arrivalTerminal': 'T2',
#     'cabinType': 'tourist',
#     'cabinDesc': '經濟艙',
#     'bookingClass': 'N',
#     'crossDays': 0,
#     'stopList': [],
#     'transfer': {'isCrossday': False,
#      'isChangeAirport': False,
#      'isChangeTerminal': False,
#      'TransitType': 1,
#      'TransferCity': '上海',
#      'TransferSpan': '2h30m'},
#     'seqNo': 1,
#     'segmentNo': 1,
#     'sequenceNo': 1,
#     'baggageStraight': 0,
#     'dterminal': 'T1',
#     'dport': 'TPE',
#     'aterminal': 'T2',
#     'aport': 'PVG'},
#    {'departureFullDate': '20230605',
#     'departureDate': '6月5日',
#     'arrivalDate': '6月5日',
#     'goDate': '2023-06-05',
#     'departureTime': '17:00',
#     'toDate': '2023-06-05',
#     'arrivalTime': '20:15',
#     'isRedEye': False,
#     'durationMinutes': 135,
#     'transferStayMinutes': None,
#     'departureCity': 'SHA',
#     'departureCityCode': 'SHA',
#     'departureCityName': '上海',
#     'arrivalCity': 'OSA',
#     'arrivalCityCode': 'OSA',
#     'arrivalCityName': '大阪',
#     'airlineCode': 'MU',
#     'airline': '中國東方航空',
#     'flightNo': 'MU3567',
#     'operatingAirlineCode': 'HO',
#     'operatingAirline': '上海吉祥航空',
#     'operatingFlightNo': None,
#     'craft': {'craftType': '789',
#      'enName': None,
#      'widthLevel': None,
#      'minSeats': 250,
#      'maxSeats': 290,
#      'craftName': '波音 787-9'},
#     'transitType': 0,
#     'departureAirportCode': 'PVG',
#     'departureAirportName': '上海浦東機場',
#     'departureTerminal': 'T2',
#     'arrivalAirportCode': 'KIX',
#     'arrivalAirportName': '關西機場',
#     'arrivalTerminal': 'T1',
#     'cabinType': 'tourist',
#     'cabinDesc': '經濟艙',
#     'bookingClass': 'S',
#     'crossDays': 0,
#     'stopList': [],
#     'transfer': None,
#     'seqNo': 2,
#     'segmentNo': 1,
#     'sequenceNo': 2,
#     'baggageStraight': 0,
#     'dterminal': 'T2',
#     'dport': 'PVG',
#     'aterminal': 'T1',
#     'aport': 'KIX'}],
#   'stuTicketGrp': False},
#  {'flightKey': 'CX489CX566',
#   'departureDate': '6月5日',
#   'departureTime': '10:55',
#   'arrivalDate': '6月6日',
#   'arrivalTime': '06:35',
#   'crossDays': 1,
#   'departureCityCode': 'TPE',
#   'arrivalCityCode': 'OSA',
#   'departureCityName': '台北',
#   'arrivalCityName': '大阪',
#   'departureAirportCode': 'TPE',
#   'departureAirportName': '桃園國際機場',
#   'arrivalAirportCode': 'KIX',
#   'arrivalAirportName': '關西機場',
#   'departureTerminal': 'T1',
#   'arrivalTerminal': 'T1',
#   'stopType': 1,
#   'transit': {'isCrossday': True,
#    'isChangeAirport': False,
#    'isChangeTerminal': False,
#    'TransitType': 1,
#    'TransferCity': '香港',
#    'TransferSpan': '12h55m'},
#   'airlineName': '國泰航空',
#   'airlineFlitername': '國泰航空',
#   'airlineCode': 'CX',
#   'validatingAirlineCode': 'CX',
#   'seats': [{'seatCount': 5,
#     'seatType': 'EzTravel',
#     'feeConfirm': True,
#     'currencyCode': 'TWD',
#     'price': 19137,
#     'averagePrice': 19137,
#     'averagePriceNoTax': 14724,
#     'priceWithoutTax': 14724,
#     'priceWithTax': 19137,
#     'adultPrice': 14724,
#     'adultCnt': 1,
#     'adultTax': 4413,
#     'childPrice': 0,
#     'childTax': 0,
#     'childCnt': 0,
#     'infantPrice': 0,
#     'infantTax': 0,
#     'infantCnt': 0,
#     'selectedFlightParas': '{"OutBoundToken":"7a7ad0a7cf460df4","RouteSearchToken":"fd0d5130-14b8-4ec1-aa17-2000e438609f|35|28:3"}',
#     'selectedFlightInfo': '{"Airline":{"Code":"CX","Name":"國泰航空"},"ArrivalAirport":{"Code":"KIX","Name":"關西機場","Terminal":"T1","change":false,"country":"JP"},"ArrivalDate":1686004500000,"DepartureAirport":{"Code":"TPE","Name":"桃園國際機場","Terminal":"T1","change":false,"country":"TW"},"DepartureDate":1685933700000,"FlightNo":"CX489 CX566","FromAirport":"桃園國際機場","GoTime":"2023年06月05日 10:55","ToAirport":"關西機場","ToTime":"2023年06月06日 06:35","TransitDesc":"1程中轉"}',
#     'displayCategory': 99,
#     'classType': '經濟艙',
#     'allClassType': None,
#     'engineType': 'Abacus',
#     'remarkId': 'fd0d5130-14b8-4ec1-aa17-2000e438609f|35|28:3',
#     'fareInfo': None,
#     'planCategory': 'EZTRAVEL',
#     'resourceName': '易遊優選',
#     'resourceDesc': '享快速出票+線上更改/退票申請服務',
#     'freeBaggage': 3,
#     'productDesc': '',
#     'ticketingDesc': '付款後5分鐘出票',
#     'ticketingCode': 1,
#     'ageRestriction': '',
#     'passportTag': '',
#     'companionFare': None,
#     'combineTag': None,
#     'FarePenaltiesFlag': 2,
#     'FarePenalties': {'baggageFormats': [{'segmentNo': 1,
#        'sequenceNo': 1,
#        'fromCity': {'code': 'TPE',
#         'country': None,
#         'lineType': None,
#         'Name': '台北'},
#        'toCity': {'code': 'HKG',
#         'country': None,
#         'lineType': None,
#         'Name': '香港'},
#        'passengerType': 'Adult',
#        'checkInBaggage': {'weight': 23,
#         'unit': 'N',
#         'piece': 1,
#         'size': None,
#         'sizeType': None,
#         'text': '每人1件，每件23公斤。'},
#        'carryOnBaggage': {'weight': 7,
#         'unit': 'N',
#         'piece': 1,
#         'size': None,
#         'sizeType': None,
#         'text': '每人1件，每件7公斤，長寬高不可超過56*36*23公分。'},
#        'route': None},
#       {'segmentNo': 1,
#        'sequenceNo': 2,
#        'fromCity': {'code': 'HKG',
#         'country': None,
#         'lineType': None,
#         'Name': '香港'},
#        'toCity': {'code': 'OSA',
#         'country': None,
#         'lineType': None,
#         'Name': '大阪'},
#        'passengerType': 'Adult',
#        'checkInBaggage': {'weight': 23,
#         'unit': 'N',
#         'piece': 1,
#         'size': None,
#         'sizeType': None,
#         'text': '每人1件，每件23公斤。'},
#        'carryOnBaggage': {'weight': 7,
#         'unit': 'N',
#         'piece': 1,
#         'size': None,
#         'sizeType': None,
#         'text': '每人1件，每件7公斤，長寬高不可超過56*36*23公分。'},
#        'route': None},
#       {'segmentNo': 2,
#        'sequenceNo': 1,
#        'fromCity': {'code': 'OSA',
#         'country': None,
#         'lineType': None,
#         'Name': '大阪'},
#        'toCity': {'code': 'TPE',
#         'country': None,
#         'lineType': None,
#         'Name': '台北'},
#        'passengerType': 'Adult',
#        'checkInBaggage': {'weight': 23,
#         'unit': 'N',
#         'piece': 1,
#         'size': None,
#         'sizeType': None,
#         'text': '每人1件，每件23公斤。'},
#        'carryOnBaggage': {'weight': 7,
#         'unit': 'N',
#         'piece': 1,
#         'size': None,
#         'sizeType': None,
#         'text': '每人1件，每件7公斤，長寬高不可超過56*36*23公分。'},
#        'route': None}],
#      'penaltyFormat': None,
#      'baggageTag': '行李每成人1*23KG',
#      'penaltyFlag': 2,
#      'penaltyTag': '退票罰金另詢',
#      'FarePenaltiesFlag': 2,
#      'Penalties': None,
#      'Baggages': [{'Segment': '台北-香港', 'Text': '每人1件，每件23公斤。'},
#       {'Segment': '香港-大阪', 'Text': '每人1件，每件23公斤。'},
#       {'Segment': '大阪-台北', 'Text': '每人1件，每件23公斤。'}],
#      'NationDisallowed': '',
#      'NationAllowed': '',
#      'CityAllowed': '',
#      'Remark': None},
#     'easeTag': None,
#     'ticketType': 'ADULT',
#     'license': None}],
#   'flightDetails': [{'departureFullDate': '20230605',
#     'departureDate': '6月5日',
#     'arrivalDate': '6月5日',
#     'goDate': '2023-06-05',
#     'departureTime': '10:55',
#     'toDate': '2023-06-05',
#     'arrivalTime': '12:55',
#     'isRedEye': False,
#     'durationMinutes': 120,
#     'transferStayMinutes': 775,
#     'departureCity': 'TPE',
#     'departureCityCode': 'TPE',
#     'departureCityName': '台北',
#     'arrivalCity': 'HKG',
#     'arrivalCityCode': 'HKG',
#     'arrivalCityName': '香港',
#     'airlineCode': 'CX',
#     'airline': '國泰航空',
#     'flightNo': 'CX489',
#     'operatingAirlineCode': None,
#     'operatingAirline': None,
#     'operatingFlightNo': None,
#     'craft': {'craftType': '32Q',
#      'enName': None,
#      'widthLevel': None,
#      'minSeats': None,
#      'maxSeats': None,
#      'craftName': None},
#     'transitType': 1,
#     'departureAirportCode': 'TPE',
#     'departureAirportName': '桃園國際機場',
#     'departureTerminal': 'T1',
#     'arrivalAirportCode': 'HKG',
#     'arrivalAirportName': '香港國際機場',
#     'arrivalTerminal': 'T1',
#     'cabinType': 'tourist',
#     'cabinDesc': '經濟艙',
#     'bookingClass': 'S',
#     'crossDays': 0,
#     'stopList': [],
#     'transfer': {'isCrossday': True,
#      'isChangeAirport': False,
#      'isChangeTerminal': False,
#      'TransitType': 1,
#      'TransferCity': '香港',
#      'TransferSpan': '12h55m'},
#     'seqNo': 1,
#     'segmentNo': 1,
#     'sequenceNo': 1,
#     'baggageStraight': 0,
#     'dterminal': 'T1',
#     'dport': 'TPE',
#     'aterminal': 'T1',
#     'aport': 'HKG'},
#    {'departureFullDate': '20230606',
#     'departureDate': '6月6日',
#     'arrivalDate': '6月6日',
#     'goDate': '2023-06-06',
#     'departureTime': '01:50',
#     'toDate': '2023-06-06',
#     'arrivalTime': '06:35',
#     'isRedEye': True,
#     'durationMinutes': 225,
#     'transferStayMinutes': None,
#     'departureCity': 'HKG',
#     'departureCityCode': 'HKG',
#     'departureCityName': '香港',
#     'arrivalCity': 'OSA',
#     'arrivalCityCode': 'OSA',
#     'arrivalCityName': '大阪',
#     'airlineCode': 'CX',
#     'airline': '國泰航空',
#     'flightNo': 'CX566',
#     'operatingAirlineCode': None,
#     'operatingAirline': None,
#     'operatingFlightNo': None,
#     'craft': {'craftType': '359',
#      'enName': None,
#      'widthLevel': None,
#      'minSeats': 314,
#      'maxSeats': 475,
#      'craftName': '空中巴士 A359'},
#     'transitType': 0,
#     'departureAirportCode': 'HKG',
#     'departureAirportName': '香港國際機場',
#     'departureTerminal': 'T1',
#     'arrivalAirportCode': 'KIX',
#     'arrivalAirportName': '關西機場',
#     'arrivalTerminal': 'T1',
#     'cabinType': 'tourist',
#     'cabinDesc': '經濟艙',
#     'bookingClass': 'S',
#     'crossDays': 0,
#     'stopList': [],
#     'transfer': None,
#     'seqNo': 2,
#     'segmentNo': 1,
#     'sequenceNo': 2,
#     'baggageStraight': 0,
#     'dterminal': 'T1',
#     'dport': 'HKG',
#     'aterminal': 'T1',
#     'aport': 'KIX'}],
#   'stuTicketGrp': False}]

# %%
print(len(new_datas))
# Out:
# 50

# %%
# 拆除最外層的列表
# flat_list = new_datas[0]
col.insert_many(new_datas)

# %%
import pandas as pd
df = pd.read_csv('crawler.csv')
df
# Out:
#                           _id airlineCode airlineFlitername airlineName  \
# 0    64623b57049781f013573eaf          CX              國泰航空        國泰航空
# 1    64623b57049781f013573eb0          JL              日本航空        日本航空
# 2    64623b57049781f013573eb1          JL              日本航空        日本航空
# 3    64623b57049781f013573eb2       multi              多個航司        多個航司
# 4    64623b57049781f013573eb3          BR              長榮航空        長榮航空
# ..                        ...         ...               ...         ...
# 276  64623e78049781f013573fc3          FM              上海航空        上海航空
# 277  64623e78049781f013573fc4          NH             全日空航空       全日空航空
# 278  64623e78049781f013573fc5          CI              中華航空        中華航空
# 279  64623e78049781f013573fc6          MU            中國東方航空      中國東方航空
# 280  64623e78049781f013573fc7          CX              國泰航空        國泰航空
#
#     arrivalAirportCode arrivalAirportName arrivalCityCode arrivalCityName  \
# 0                  KIX               關西機場             OSA              大阪
# 1                  ITM             大阪伊丹機場             OSA              大阪
# 2                  KIX               關西機場             OSA              大阪
# 3                  ITM             大阪伊丹機場             OSA              大阪
# 4                  KIX               關西機場             OSA              大阪
# ..                 ...                ...             ...             ...
# 276                KIX               關西機場             OSA              大阪
# 277                ITM             大阪伊丹機場             OSA              大阪
# 278                KIX               關西機場             OSA              大阪
# 279                KIX               關西機場             OSA              大阪
# 280                KIX               關西機場             OSA              大阪
#
#     arrivalDate arrivalTerminal  ...  \
# 0         5月30日              T1  ...
# 1         5月29日             NaN  ...
# 2         5月29日              T1  ...
# 3         5月30日             NaN  ...
# 4         5月29日              T1  ...
# ..          ...             ...  ...
# 276        6月5日              T1  ...
# 277        6月5日             NaN  ...
# 278        6月5日              T1  ...
# 279        6月5日              T1  ...
# 280        6月6日              T1  ...
#
#                                                  seats  stopType stuTicketGrp  \
# 0    [{"seatCount":3,"seatType":"Ct","feeConfirm":t...         1        False
# 1    [{"seatCount":9,"seatType":"Ct","feeConfirm":t...         1        False
# 2    [{"seatCount":8,"seatType":"Ct","feeConfirm":t...         1        False
# 3    [{"seatCount":9,"seatType":"Ct","feeConfirm":t...         1        False
# 4    [{"seatCount":9,"seatType":"Ct","feeConfirm":t...         0        False
# ..                                                 ...       ...          ...
# 276  [{"seatCount":9,"seatType":"EzTravel","feeConf...         1        False
# 277  [{"seatCount":6,"seatType":"EzTravel","feeConf...         1        False
# 278  [{"seatCount":5,"seatType":"EzTravel","feeConf...         0         True
# 279  [{"seatCount":4,"seatType":"EzTravel","feeConf...         1        False
# 280  [{"seatCount":5,"seatType":"EzTravel","feeConf...         1        False
#
#     transit.TransferCity transit.TransferSpan transit.TransitType  \
# 0                     香港               15h55m                   1
# 1                     東京                1h40m                   1
# 2                     東京                2h20m                   1
# 3                     東京               10h15m                   1
# 4                    NaN                  NaN                   0
# ..                   ...                  ...                 ...
# 276                   上海                1h55m                   1
# 277                   東京                1h30m                   1
# 278                  NaN                  NaN                   0
# 279                   上海                2h30m                   1
# 280                   香港               12h55m                   1
#
#     transit.isChangeAirport transit.isChangeTerminal transit.isCrossday  \
# 0                     False                    False               True
# 1                     False                     True              False
# 2                     False                     True              False
# 3                     False                     True               True
# 4                       NaN                      NaN                NaN
# ..                      ...                      ...                ...
# 276                   False                    False              False
# 277                   False                     True              False
# 278                     NaN                      NaN                NaN
# 279                   False                    False              False
# 280                   False                    False               True
#
#     validatingAirlineCode
# 0                      CX
# 1                      JL
# 2                      JL
# 3                   MULTI
# 4                      BR
# ..                    ...
# 276                    FM
# 277                    NH
# 278                    CI
# 279                    MU
# 280                    CX
#
# [281 rows x 31 columns]
